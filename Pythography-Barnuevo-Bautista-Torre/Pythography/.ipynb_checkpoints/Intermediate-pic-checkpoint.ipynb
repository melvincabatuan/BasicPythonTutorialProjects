# %%
from tkinter import *

root = Tk()
root.title("GUI Project")
root.geometry("700x750")
root.config(background="#ffffff")

img1 = PhotoImage(file = "img1.png")
smallImage = img1.subsample(3, 3)
IlblImage = Label(root, image=smallImage, background="#ffffff")
IlblImage.pack()

ILbl0 = Label(root, 
              text = "Numpy is the fundamental package for scientific computing in Python.\n"
              "It is a Python library that provides a multidimensional array object, various derived objects,\n"
              "and an assortment of routines for fast operations on arrays."
              "First import numpy as np \n"
              "This is to use “np” in the program instead of the word “numpy”\n", 
              background = "#ffffff")
            
ILbl0.pack()

Iimage2 = PhotoImage(file = "numpy1.png")
IsmallImage2 = Iimage2.subsample(1, 1)
IlblImage2 = Label(root, image = IsmallImage2, background="#ffffff")
IlblImage2.pack()

IB0 = Button(root, text = "Lezgo", command = Ilesson)
IB0.pack()

def Ilesson():
    global ILbl1
    global IEntryBox1
    global IB1, IB2
    global Iframe1
    
    IlblImage.destroy()
    ILbl0.destroy()
    IlblImage2.destroy()
    IB0.destroy()
    
    ILbl1 = Label(root, 
                    text = "Multiply A by B \n"
                    "It is a Python library that provides a multidimensional array object, various derived objects,\n"
                    "Use matmul(), this is the matrix product of two arrays\n"
                    "Example: c=np.matmul(A,B)\n"
                    "Your turn: Multiply B by A. Use the variable c (c = #Your Code Here)\n")
    ILbl1.pack()

    IEntryBox1 = Entry(root, width = 50)
    IEntryBox1.pack()
    IB1 = Button(root, text = "Enter", command = Iexercise1)
    IB1.pack()
    IB2 = Button(root ,text = "Next Lesson: Matrix Addition", command = Ilesson2, state = DISABLED)
    IB2.pack()
    Iframe1 = Frame(root)
    Iframe1.pack()

def Iexercise1():
    global IEntryBox1
    global IB2
    global Iframe1
    
    if IEntryBox1.get() == "c=np.matmul(B,A)": 
        ILbldef1 = Label(Iframe1, text = "Nice one!")
        ILbldef1.pack()
        IB2.config(state = NORMAL)
    elif IEntryBox1.get() == "":
        ILbldef2 = Label(Iframe1, text = "I couldn't see your answer...")
        ILbldef2.pack()
    else:
        ILbldef3 = Label(Iframe1, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef3.pack()
        
#----------------------------MATMUL-----------------------

#----------------------------add--------------------------
def Ilesson2():
    global ILbl1, ILbl2, ILbl3
    global IEntryBox1, IEntryBox2
    global IB1, IB2, IB3, IB4
    global Iframe1, Iframe2
    
    ILbl1.destroy()
    IEntryBox1.destroy()
    IB1.destroy()
    IB2.destroy
    Iframe1.destroy
    
    ILbl2 = Label(root, 
                  text = "Add A and B or “A+B”")
    ILbl2.pack()
    
    ILbl3 = Label(root, 
                  text = "Use numpy.add() function. This function is used when we want to compute the addition of two arrays.\n"
                  "Use the variable c (c = #Your Code Here)\n", 
                  background = "#ffffff")
    ILbl3.pack()   
    
    IEntryBox2 = Entry(root, width = 50)
    IEntryBox2.pack()
    IB3 = Button(root, text = "Enter", command = Iexercise2)
    IB3.pack()
    IB4 = Button(root, text = "Next Lesson: Matrix Subtraction", command = Ilesson2_1, state = DISABLED)
    IB4.pack()
    Iframe2 = Frame(root)
    Iframe2.pack()
    
def Iexercise2():
    global IEntryBox2
    global IB4
    global Iframe2
    
    if IEntryBox2.get() == "c=np.add(A,B)":
        ILbldef4 = Label(Iframe2, text = "then print(c)....Correct!")
        ILbldef4.pack()
        IB4.config(state = NORMAL)
    else:
        ILbldef5 = Label(Iframe2, text = "Incorrect, Hint: use np.add() function")
        ILbldef5.pack()
#----------------------------add-----------------------

#---------------------------subtract----------------------

def Ilesson2_1():
    global ILbl2, ILbl3, ILb4, ILbl5
    global IEntryBox2, IEntryBox3
    global IB3, IB4, IB5, IB6
    global Iframe2
    
    ILbl2.destroy()
    ILbl3.destroy()
    IEntryBox2.destroy()
    IB3.destroy()
    IB4.destroy()
    Iframe2.destroy()
    
    ILbl4 = Label(root,
                 text = "Using np.subtract()")
    ILbl4.pack()
    ILbl5 = Label(root,
                 text = "The numpy.subtract() function is used when we want to compute the difference of two arrays.\n"
                  "Use the variable c (c = #Your Code Here)\n",
                 background = "#ffffff")
    ILbl5.pack()
    IQ1 = Label(root, text= "Subtract B from A or A-B")
    IQ1.pack()

    IEntryBox3 = Entry(root, width = 50)
    IEntryBox3.pack()
    IB5 = Button(root, text = "Enter", command = subtract)
    IB5.pack()
   
    IB6 = Button(root, text = "Next Lesson", command = Ilesson3_1) 
    IB6.pack()
    
#---------------------------subtract----------------------
    
#--------------------------linalg--------------------------------

Iimage2 = PhotoImage(file = "numpy2.png")
smallImage2 = Iimage2.subsample(2, 2)
IlblImage2 = Label(root, image=smallImage2, background="#ffffff")

def Ilesson3_1():
    global IEntryBox8
    
    
    ILbl7 = Label(root,
                text = "The np.linalg.inv() function is to compute the (multiplicative) inverse of a matrix.\n Use the variable c (c = #Your Code Here)\n")
    
    ILbl7.pack()
    
    
    IlblImage2.pack()
    IQ8 = Label(root,
                 text = "Use np.linalg.inv() function",
                 background = "#ffffff")
    IQ8.pack()
    
    IEntryBox8 = Entry(root, width = 50)
    IEntryBox8.pack()
    IB6 = Button(root, text = "Enter", command = linalg)
    IB6.pack()
    
    IB7 = Button(root, text = "Next Lesson", command = Ilesson4)
    IB7.pack()
    
    
def linalg():
    global IEntryBox8
    
    if IEntryBox8.get() == "c=np.linalg.inv(A)": 
        ILbldef7 = Label(root, text = "then print(c)....Correct!")
        ILbldef7.pack()
    elif IEntryBox1.get() == "":
        ILbldef8 = Label(root, text = "I couldn't see your answer...")
        ILbldef8.pack()
    else:
        ILbldef9 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef9.pack()

    
#--------------------------linalg--------------------------------   

#----------------------------------------transpose-------------------------- 

Iimage3 = PhotoImage(file = "numpy3.png")
smallImage3 = Iimage3.subsample(2, 2)
IlblImage3 = Label(root, image=smallImage3, background="#ffffff")
def Ilesson4():
    global IEntryBox9
    
    
    
    ILbl8 = Label(root,
                text = "Using np.transpose")
    
    ILbl8.pack()
    
    IQ9 = Label(root,
                 text = "The np.transpose() function can transpose the 2-D arrays and it has no effect on 1-D arrays.\n",
                 background = "#ffffff")
    IQ9.pack()
    
    IlblImage3.pack()
    
    label9 = Label(root, text = "Transpose the array A. Use the variable c (c = #Your Code Here)\n")
    label9.pack
    
    
    IEntryBox9 = Entry(root, width = 50)
    IEntryBox9.pack()
    IB8 = Button(root, text = "Enter", command = transpose)
    IB8.pack()
    
    IB9 = Button(root, text = "Next Lesson", command = Ilesson5)
    IB9.pack()
    
    
def transpose():
    global IEntryBox9
    
   
    
    if IEntryBox9.get() == "c=np.transpose(A)": 
        ILbldef7 = Label(root, text = "then print(c)....Correct!")
        ILbldef7.pack()
    elif IEntryBox1.get() == "":
        ILbldef8 = Label(root, text = "I couldn't see your answer...")
        ILbldef8.pack()
    else:
        ILbldef9 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef9.pack()
        
#---------------------------------------transpose-------------------------- 
#----------------------------------------------------linalg&matmul--------------------

Iimage4 = PhotoImage(file = "numpy4.png")
smallImage4 = Iimage4.subsample(2, 2)
IlblImage4 = Label(root, image=smallImage4, background="#ffffff")

def Ilesson5():
    global IEntryBox10
    
    
    
    ILbl9 = Label(root,
                text = "Using np.linalg() and np.matmul() function\n")
    
    ILbl9.pack()
    
    IlblImage4.pack()
    
    IQ10 = Label(root,
                 text = "Apply what you have learned in the previous lessons:\n"
                 "c=np.linalg.inv(A)\n"
                 "c=np.matmul(A,?)",
                 background = "#ffffff")
    IQ10.pack()
    
    IEntryBox10 = Entry(root, width = 50)
    IEntryBox10.pack()
    IB10 = Button(root, text = "Enter", command = linalgmatmul)
    IB10.pack()
    
    IB11 = Button(root, text = "Next Lesson", command = Ilesson6)
    IB11.pack()
    
def linalgmatmul():
    global IEntryBox10
    
   
    
    if IEntryBox10.get() == "c": 
        ILbldef10 = Label(root, text = "Correct! Since you need to multiply the inverse of a matrix to A using matmul function ")
        ILbldef10.pack()
    elif IEntryBox10.get() == "":
        ILbldef9 = Label(root, text = "I couldn't see your answer...")
        ILbldef9.pack()
    else:
        ILbldef10 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef10.pack()
#--------------------------------------------------linalg&matmul--------------------

#-------------------------------------------------multi-------------------

def Ilesson6():
    global IEntryBox11
    
    
    
    ILbl10 = Label(root,
                text = "Element-wise multiplication of A and B\n"
                        "Just simply let “C = A*B” then “print(C)\n"
                         "\n"
                        "Element-wise division of A and B\n"
                        "Just simply let “C = A / B” then “print(C)\n")
    
    ILbl10.pack()
    
    IQ11 = Label(root, text = "Multiplication of A 1st column and B 2nd row\n",background = "#ffffff")
    IQ11.pack()
    
    IEntryBox11 = Entry(root, width = 50)
    IEntryBox11.pack()
    IB11 = Button(root, text = "Enter", command = multi)
    IB11.pack()
    
    IB12 = Button(root, text = "Next Lesson", command = Ilesson7)
    IB12.pack()
    
def multi():
    global IEntryBox11
    
   
    
    if IEntryBox11.get() == "c=A[:,0]*B[1]": 
        ILbldef11 = Label(root, text = "then print(C) Correct! This means that A[:,0] will read the first column in set A and B[1] will read the second row in set B")
        ILbldef11.pack()
    elif IEntryBox10.get() == "":
        ILbldef10 = Label(root, text = "I couldn't see your answer...")
        ILbldef10.pack()
    else:
        ILbldef11 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef11.pack()

#-------------------------------------------------multi-------------------

#---------------------------------------------question1----------------
Iimage5 = PhotoImage(file = "numpy5.png")
smallImage5 = Iimage5.subsample(2, 2)
IlblImage5 = Label(root, image=smallImage5, background="#ffffff")

Iimage6 = PhotoImage(file = "numpy6.png")
smallImage6 = Iimage6.subsample(2, 2)
IlblImage6 = Label(root, image=smallImage6, background="#ffffff")

Iimage7 = PhotoImage(file = "numpy7.png")
smallImage7 = Iimage7.subsample(2, 2)
IlblImage7 = Label(root, image=smallImage7, background="#ffffff")

Iimage8 = PhotoImage(file = "numpy8.png")
smallImage8 = Iimage8.subsample(2, 2)
IlblImage8 = Label(root, image=smallImage8, background="#ffffff")

Iimage9 = PhotoImage(file = "numpy9.png")
smallImage9 = Iimage9.subsample(2, 2)
IlblImage9 = Label(root, image=smallImage9, background="#ffffff")

Iimage10 = PhotoImage(file = "numpy10.png")
smallImage10 = Iimage10.subsample(2, 2)
IlblImage10 = Label(root, image=smallImage10, background="#ffffff")

Iimage11 = PhotoImage(file = "numpy11.png")
smallImage11 = Iimage11.subsample(2, 2)
IlblImage11 = Label(root, image=smallImage11, background="#ffffff")


def Ilesson7():
    global IEntryBox12
    
    
    label2 = Label(root, text = "Other Applications of Numpy", font="bold")
    label2.pack()
    
    label3 = Label(root, text = "Numpy can be used to show truth tables. Symbols for bitwise are used for numpy.\n")
    label3.pack()
    
    IlblImage5.pack()
        
    label4 = Label(root, text = "Truth Tables\n", font="bold")
    label4.pack()
    
    IlblImage6.pack()
    IlblImage7.pack()
    IlblImage8.pack()
    IlblImage9.pack()
    
    IQ12 = Label(root,
                text = "Complete the function that creates/returns a Truth Table array for Negation operation\n"
                 "Please refer to the Truth Table above\n"
                 "Utilize Boolean 1 and 0, as in the above example, e.g. p = np.array([1, 0], dtype=bool).\n"
                 "Complete the code."
                        
                         
                 ,  )
    IQ12.pack()
    
    IlblImage10.pack()
    IlblImage11.pack()
    
    IEntryBox12 = Entry(root, width = 50)
    IEntryBox12.pack()
    IB12 = Button(root, text = "Enter", command = question1)
    IB12.pack()
    
    IB13 = Button(root, text = "Next Lesson", command = Ilesson8)
    IB13.pack()
    
def question1():
    global IEntryBox12
    
   
    
    if IEntryBox12.get() == "~p": 
        ILbldef12 = Label(root, text = "Correct!")
        ILbldef12.pack()
    elif IEntryBox12.get() == "":
        ILbldef11 = Label(root, text = "I couldn't see your answer...")
        ILbldef11.pack()
    else:
        ILbldef12 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef12.pack()
#---------------------------------------------question1-----------------

#---------------------------------------------question2-----------------
Iimage12 = PhotoImage(file = "numpy12.png")
smallImage12 = Iimage12.subsample(2, 2)
IlblImage12 = Label(root, image=smallImage12, background="#ffffff")

Iimage13 = PhotoImage(file = "numpy13.png")
smallImage13 = Iimage13.subsample(2, 2)
IlblImage13 = Label(root, image=smallImage13, background="#ffffff")


def Ilesson8():
    global IEntryBox13
    
    
    
    IQ13 = Label(root,
                 text = "Write a function that creates/returns \n"
                 "a Truth Table array for Disjunction or OR logical operation.\n"
                   "Please refer to the Truth Table above. Complete the code." 
,

                 background = "#ffffff")
    IQ13.pack()
    
    IlblImage12.pack()
    IlblImage13.pack()
    
    IEntryBox13 = Entry(root, width = 50)
    IEntryBox13.pack()
    IB13 = Button(root, text = "Enter", command = question2)
    IB13.pack()
    
    IB14 = Button(root, text = "Next Lesson", command = Ilesson9)
    IB14.pack()
    
def question2():
    global IEntryBox13
    
   
    
    if IEntryBox13.get() == "p|q": 
        ILbldef13 = Label(root, text = "Correct!")
        ILbldef13.pack()
    elif IEntryBox13.get() == "":
        ILbldef12 = Label(root, text = "I couldn't see your answer...")
        ILbldef12.pack()
    else:
        ILbldef13 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef13.pack()

#---------------------------------------------question2-----------------


#---------------------------------------------question3-----------------
Iimage14 = PhotoImage(file = "numpy14.png")
smallImage14 = Iimage14.subsample(2, 2)
IlblImage14 = Label(root, image=smallImage14, background="#ffffff")

Iimage15 = PhotoImage(file = "numpy15.png")
smallImage15 = Iimage15.subsample(2, 2)
IlblImage15 = Label(root, image=smallImage15, background="#ffffff")

def Ilesson9():
    global IEntryBox14
    
    
    
    IQ14 = Label(root,
                 text = "Write a function that creates/returns a Truth Table array for Exclusive-Or or XOR logical operation.\n"
                 "Please refer to the Truth Table above. Complete the code." ,

                 background = "#ffffff")
    IQ14.pack()
    
    IlblImage14.pack() 
    IlblImage15.pack()
    
    IEntryBox14 = Entry(root, width = 50)
    IEntryBox14.pack()
    IB15 = Button(root, text = "Enter", command = question3)
    IB15.pack()
    
    IB16 = Button(root, text = "Next Lesson", command = Ilesson10)
    IB16.pack()
    
def question3():
    global IEntryBox14
    
   
    
    if IEntryBox14.get() == "p^q": 
        ILbldef14 = Label(root, text = "Correct!")
        ILbldef14.pack()
    elif IEntryBox14.get() == "":
        ILbldef14 = Label(root, text = "I couldn't see your answer...")
        ILbldef14.pack()
    else:
        ILbldef14 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef14.pack()

#---------------------------------------------question3-----------------


#---------------------------------------------question4-----------------
Iimage16 = PhotoImage(file = "numpy16.png")
smallImage16 = Iimage16.subsample(2, 2)
IlblImage16 = Label(root, image=smallImage16, background="#ffffff")

Iimage17 = PhotoImage(file = "numpy17.png")
smallImage17 = Iimage17.subsample(2, 2)
IlblImage17 = Label(root, image=smallImage17, background="#ffffff")

def Ilesson10():
    global IEntryBox15
    
    
    
    IQ15 = Label(root,
                 text = "Write a function that creates/returns a Truth Table array for Conditional or Implication logical operation.\n"
                 "Please refer to the Truth Table above. Complete the code." 
,

                 background = "#ffffff")
    IQ15.pack()
    
    IlblImage16.pack()
    IlblImage17.pack()
    
    
    IEntryBox15 = Entry(root, width = 50)
    IEntryBox15.pack()
    IB17 = Button(root, text = "Enter", command = question4)
    IB17.pack()
    
    IB18 = Button(root, text = "Next Lesson", command = Ilesson11
                 )
    IB18.pack()
    
def question4():
    global IEntryBox15
    
   
    
    if IEntryBox15.get() == "~p|q": 
        ILbldef15 = Label(root, text = "Correct!")
        ILbldef15.pack()
    elif IEntryBox15.get() == "":
        ILbldef15 = Label(root, text = "I couldn't see your answer...")
        ILbldef15.pack()
    else:
        ILbldef15 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef15.pack()

#---------------------------------------------question4-----------------

#---------------------------------------------question5-----------------
Iimage18 = PhotoImage(file = "numpy18.png")
smallImage18 = Iimage18.subsample(2, 2)
IlblImage18 = Label(root, image=smallImage18, background="#ffffff")

def Ilesson11():
    global IEntryBox16
    
    
    
    IQ16 = Label(root,
                 text = "Write a function that creates/return a Truth Table array for Biconditional logical operation.\n"
                 "Please refer to the Truth Table above. Complete the code." ,

                 background = "#ffffff")
    IQ16.pack()
    
    IlblImage18.pack()
    
    IEntryBox16 = Entry(root, width = 50)
    IEntryBox16.pack()
    IB19 = Button(root, text = "Enter", command = question5)
    IB19.pack()
    
    IB20 = Button(root, text = "Next Lesson", command = lesson2)
    IB20.pack()
    
def question5():
    global IEntryBox16
    
   
    
    if IEntryBox16.get() == "~(p^q)": 
        ILbldef16 = Label(root, text = "Correct!")
        ILbldef16.pack()
    elif IEntryBox16.get() == "":
        ILbldef16 = Label(root, text = "I couldn't see your answer...")
        ILbldef16.pack()
    else:
        ILbldef16 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef16.pack()

#---------------------------------------------question5-----------------
    
def subtract():
    global IEntryBox3
    
    if IEntryBox3.get() == "c=np.subtract(A,B)":
        ILbldef7 = Label(root, text = "Correct!")
        ILbldef7.pack()
    else:
        ILbldef8 = Label(root, text = "Please check your answer")
        ILbldef8.pack()    


root.mainloop()

# %%
int(5.3)
# Out:
# 5

# %%
user_input = input("Enter something:")

try:
   val = int(user_input)
except ValueError:
   print("That's not an int!")
# Out:
# Enter something:dfs
# That's not an int!

# %%
import tkinter as tk

root = tk.Tk()
root.geometry("300x200")


def onclick(event=None):
    print("You clicked the button")

root.bind('<Return>', onclick)

button = tk.Button(root, text="click me", command=onclick)
button.pack()

root.mainloop()
# Out:
# You clicked the button
# You clicked the button
# You clicked the button
# You clicked the button
# You clicked the button

# %%
5 > 10
# Out:
# False
