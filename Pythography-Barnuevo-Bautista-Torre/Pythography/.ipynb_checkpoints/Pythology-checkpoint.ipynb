# %%
from tkinter import *
import random

root = Tk()
root.title("Pythography: Python Tutorial")
root.geometry("700x600")
root.config(background="#ffdf00")
root.resizable(width = False, height = False)

img0 = PhotoImage(file="pythonlogo.png")
smallerImage = img0.subsample(4,4)
labelImage = Label(root, 
                   image=smallerImage, 
                   background="#FFDF00")
labelImage.pack(pady=(10, 20))

labelText2 = Label(root,
                   text="Python Questionnaire", 
                   font=("Agency FB", 24), 
                   background="#FFDF00")
labelText2.pack()

img1 = PhotoImage(file = "img1.png") #Ito para maread niya yung image file
smallImage = img1.subsample(2,2) #Para paliitin yung size nung image kasi ang laki

def runBEGINNER():
    global rootBeginner, lblImage, Lbl1, EntryBox1, B1, B2, frame1
    
    rootBeginner = Toplevel(root)               
    rootBeginner.title("Pythography: Beginner Tutorial") 
    rootBeginner.geometry("800x775")  
    rootBeginner.config(background="#1974D2")
    
    lblImage = Label(rootBeginner, image=smallImage, background="#1974D2") #Para madisplay yung image using Label
    lblImage.pack()
    
    Lbl1 = Label(rootBeginner,
                text = "For your first lesson, I am going to teach you how to print in Python\n"
                "To do this, we use the command PRINT\n"
                "For example:\n" 
                "The input is: print(\"Hello World!\")\n"
                "The output is: Hello World!\n\n"
                "Now, to test your skill, try and print the word APPLE (all in uppercase). Enter your answer below.\n",font=("Times", 14),
                background = "#FFDF00",foreground="#1974D2")
    Lbl1.pack()
    
    EntryBox1 = Entry(rootBeginner, width = 50)
    EntryBox1.pack()
    B1 = Button(rootBeginner, text = "Enter", command = exercise1)
    B1.pack()
    B2 = Button(rootBeginner, text = "Next Lesson", command = lesson2, state = DISABLED)
    B2.pack()
    frame1 = Frame(rootBeginner)
    frame1.pack()

def exercise1():
    global Lbldef1, Lbldef2, Lbldef3 #etong global di to kailangan wag niyo pansinin
    
    global B2
    
    if EntryBox1.get() == "print" + "(" + "\"APPLE\"" + ")": 
        Lbldef1 = Label(frame1, text = "Nice one!")
        Lbldef1.pack()
        B2.config(state = NORMAL)
    elif EntryBox1.get() == "":
        Lbldef2 = Label(frame1, text = "I couldn't see your answer...")
        Lbldef2.pack()
    else:
        Lbldef3 = Label(frame1, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef3.pack()

        
Bimage1 = PhotoImage(file = "beginner1.png") 
BsmallImage1 = Bimage1.subsample(1,1) 

def lesson2():
    global Lbldef1, Lbldef2, Lbldef3, Lbl2, Lbl3, Lbl4
    global EntryBox2
    global B3, B4
    global frame2
    global BlblImage1
    
    frame1.destroy()
    lblImage.destroy()
    Lbl1.destroy()
    EntryBox1.destroy()
    B1.destroy()
    B2.destroy()
    
    Lbl2 = Label(rootBeginner,
                text = "For your second lesson, I am going to teach you the different DATA TYPES.\n"
                "There are INTEGERS and FLOAT (numeric data types), TRUE or FALSE (boolean data type), "
                "\nSTRING, LIST, and TUPLE (sequence data types)\n",font=("Times", 12),background = "#FFDF00",foreground="#1974D2"
                )
    Lbl2.pack()
    
    BlblImage1 = Label(rootBeginner, image=BsmallImage1, background="#1974D2") 
    BlblImage1.pack()
    
    Lbl3 = Label(rootBeginner,
                text = "By definition, INTEGERS are the positive and negative numbers.\n"
                "This includes 1, 5, 69, -20, 0, and more.\n"
                "But in Python, there is a special numeric data type called FLOAT.\n"
                "A FLOAT is a number with decimals. This includes 1.34, 8.43, -2.32, and more\n"
                "\nTo determine a data type, we use the syntax TYPE()\n"
                "For instance, if the input is TYPE(5), the output will be INT (or integer)\n"
                "But if the input is TYPE(5.1), the output will be FLOAT",font=("Times", 12),background = "#FFDF00",foreground="#1974D2")
    Lbl3.pack()
    
    Lbl4 = Label(rootBeginner,
                text = "Try it yourself! Enter a value to determine if INTEGER or FLOAT..",font=("Times", 12),background = "#FFDF00",foreground="#1974D2")
    Lbl4.pack()
    
    EntryBox2 = Entry(rootBeginner, width = 50)
    EntryBox2.pack()
    B3 = Button(rootBeginner, text = "Enter", command = exercise2)
    B3.pack()
    B4 = Button(rootBeginner, text = "Next Lesson", command = lesson2_1, state = DISABLED)
    B4.pack()
    frame2 = Frame(rootBeginner)
    frame2.pack()

def exercise2():
    global EntryBox2
    global B4
    global frame2
    

    if (float(EntryBox2.get()).is_integer()) == True:
        Lbldef4 = Label(frame2, text = "That is an INTEGER")
        Lbldef4.pack()
        B4.config(state = NORMAL)
    elif (float(EntryBox2.get()).is_integer()) == False:
        Lbldef5 = Label(frame2, text = "That is a FLOAT")
        Lbldef5.pack()
        B4.config(state = NORMAL)
    else:
        Lbldef6 = Label(frame2, text = "I don't recognize that data type, but that's neither INTEGER nor FLOAT")
        Lbldef6.pack()
        
Bimage2 = PhotoImage(file = "beginner2.png") 
BsmallImage2 = Bimage2.subsample(1,1) 

def lesson2_1():
    global EntryBox3
    global Lbl5, Lbl6
    global B5, B6
    global frame3
    global Q1
    global BlblImage2
    
    BlblImage1.destroy()
    EntryBox2.destroy()
    Lbl2.destroy()
    Lbl3.destroy()
    Lbl4.destroy()
    frame2.destroy()
    B3.destroy()
    B4.destroy()
    
    Lbl5 = Label(rootBeginner,
                 text = "Another data type is the boolean data type, consisting of TRUE or FALSE values.\n"
                 "TRUE can be equal to 1, while FALSE can be equal to 0.\n"
                 "For example, 5 = 5 should return TRUE while 5 = 5.21 should return FALSE.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Lbl5.pack()
    
    BlblImage2 = Label(rootBeginner, image=BsmallImage2, background="#1974D2") 
    BlblImage2.pack()
    
    Lbl6 = Label(rootBeginner,
                 text = "Try it yourself! There is an equation given, write True or False",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Lbl6.pack()
    
    Q1 = Label(rootBeginner,
               text = "1092 = 1092",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Q1.pack()
    
    EntryBox3 = Entry(rootBeginner, width = 50)
    EntryBox3.pack()
    B5 = Button(rootBeginner, text = "Enter", command = TrueorFalse)
    B5.pack()
    B6 = Button(rootBeginner, text = "Next Lesson", command = lesson2_2, state = DISABLED)
    B6.pack()
    frame3 = Frame(rootBeginner)
    frame3.pack()
    
def TrueorFalse():
    global EntryBox3
    global B5
    global frame3
    
    if EntryBox3.get() == "True":
        Lbldef7 = Label(frame3, text = "Correct!")
        Lbldef7.pack()
        B6.config(state = NORMAL)
    else:
        Lbldef8 = Label(frame3, text = "Please check your answer")
        Lbldef8.pack()
        
def lesson2_2():
    global EntryBox4
    global Lbl7, Lbl8
    global B7, B8
    global frame4
    
    
    BlblImage2.destroy()
    EntryBox3.destroy()
    Lbl5.destroy()
    Lbl6.destroy()
    B5.destroy()
    B6.destroy()
    frame3.destroy()
    Q1.destroy()
    
    Lbl7 = Label(rootBeginner,
                text = "Lastly are the sequence data types. This includes the STRING, LIST, AND TUPLE.\n"
                "STRINGS are enclosed by quotation marks \"\" \n"
                "LISTS are enclosed by square brackets []\n"
                "TUPLES are enclosed by parentheses ()\n"
                "\nFor example, \"Hello World!\" is a string, [1, 2, 3] is a list, and (1, 2, 3) is a tuple.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Lbl7.pack()
    Lbl8 = Label(rootBeginner,
                text = "Try it yourself! Input a string, a list, or a tuple.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Lbl8.pack()
    
    EntryBox4 = Entry(rootBeginner, width = 50)
    EntryBox4.pack()
    B7 = Button(rootBeginner, text = "Enter", command = whatDataType)
    B7.pack()
    B8 = Button(rootBeginner, text = "Next Lesson: Basic Arithmetic", command = Lesson3, state = DISABLED)
    B8.pack()
    frame4 = Frame(rootBeginner)
    frame4.pack()
    
def whatDataType():
    global EntryBox4
    global B8
    global frame4
    
    if EntryBox4.get()[0] == "\"" and EntryBox4.get()[-1] == "\"":
        Lbldef9 = Label(frame4, text = "That is a string")
        Lbldef9.pack()
        B8.config(state = NORMAL)
    elif EntryBox4.get()[0] == "[" and EntryBox4.get()[-1] == "]":
        Lbldef10 = Label(frame4, text = "That is a list")
        Lbldef10.pack()
        B8.config(state = NORMAL)
    elif EntryBox4.get()[0] == "(" and EntryBox4.get()[-1] == ")":
        Lbldef11 = Label(frame4, text = "That is a tuple")
        Lbldef11.pack()
        B8.config(state = NORMAL)
    else:
        Lbldef12 = Label(frame4, text = "I do not recognize that")
        Lbldef12.pack()

Bimage3 = PhotoImage(file = "beginner3.png") 
BsmallImage3 = Bimage3.subsample(1,1) 

def Lesson3():
    global Lbl2, Lbl3, Lbl4, Lbl5, Lbl6, Lbl7, Lbl8, Lbl9
    global EntryBox2, EntryBox3, EntryBox4, EntryBox5
    global B3, B4, B5, B6, B7, B8, B9, B10
    global frame2, frame3, frame4, frame5
    global Q1, Q2
    global BlblImage3
   
    Lbl7.destroy()
    Lbl8.destroy()
    EntryBox4.destroy()
    B6.destroy()
    B7.destroy()
    B8.destroy()   
    frame4.destroy()
    
    Lbl9 = Label(rootBeginner, text = "In this lesson, you will be able to get numerical values\n"
           "by using the basic arithmetic operations such as \n"
           "ADDITION, SUBTRACTION, MULTIPLICATION, DIVISION, EXPONENTIATION and SQUARE rootBeginnerS.\n\n"
           "The following operators are used:\n"
           "Addition: +\n"
           "Subtraction: -\n"
           "Multiplication: *\n"
           "Division: /\n"
           "Exponentiation: **\n"
           "Square rootBeginners: **0.5\n (Note that raising a number to one-half is equal to its square rootBeginner.)",font=("Times", 12),background = "#FFDF00",foreground="#1974D2")
    Lbl9.pack()
    
    BlblImage3 = Label(rootBeginner, image=BsmallImage3, background="#1974D2") 
    BlblImage3.pack()
    
    Q2 = Label(rootBeginner,
              text = "Calculate the hypotenuse of a right triangle\n"
               "with a = 5 and b = 8. Use the Pythagorean Theorem c squared = a squared + b squared (c^2=a^2+b^2)",font=("Times", 12),background = "#FFDF00",foreground="#1974D2")
    Q2.pack()
    
    EntryBox5 = Entry(rootBeginner, width = 50)
    EntryBox5.pack()
    B9 = Button(rootBeginner, text = "Enter", command = basicArithmetic)
    B9.pack()
    B10 = Button(rootBeginner, text = "Next Lesson: Integer Division", command = lesson4, state = DISABLED)
    B10.pack()
    frame5 = Frame(rootBeginner)
    frame5.pack()
    
def basicArithmetic():
    global EntryBox5
    global frame5
    global B10
    
    if EntryBox5.get() == "((5**2)+(8**2))**0.5" or EntryBox5.get() == "((8**2)+(5**2))**0.5": 
        Lbldef13 = Label(frame5, text = "Nice one!")
        Lbldef13.pack()
        B10.config(state = NORMAL)
    elif EntryBox5.get() == "":
        Lbldef14 = Label(frame5, text = "I couldn't see your answer...")
        Lbldef14.pack()
    else:
        Lbldef15 = Label(frame5, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef15.pack()
#-------inserrt image for question7--------------

Bimage4 = PhotoImage(file = "beginner4.png") 
BsmallImage4 = Bimage4.subsample(1,1) 

def lesson4():
    global Lbl9, Lbl10
    global EntryBox5, EntryBox6
    global frame5, frame6
    global B9, B10, B11, B12
    global Q2, Q3
    global BlblImage4
    
    BlblImage3.destroy()
    Lbl9.destroy()
    Q2.destroy()
    EntryBox5.destroy()
    B9.destroy()
    B10.destroy()
    frame5.destroy()
    
    Lbl10 = Label(rootBeginner, 
                  text = "The division taught to you in the previous topic,\n" 
                 "Basic Arithmetic, the symbol used was a single slash \ \n"
                 "For this lesson, you will learn another type of division, which is integer division.\n"
                 "Integers are whole numbers (without decimals). Similar to this, integer division divides \n"
                 "the numbers but only takes the whole number of the answer and disregards the decimals.\n"
                 "It uses the symbol of double slash “//” \nExample:\n\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    
    Lbl10.pack()
    
    BlblImage4 = Label(rootBeginner, image=BsmallImage4, background="#1974D2") 
    BlblImage4.pack()
    
    Q3 = Label(rootBeginner, 
               text = "3 divided by 2 is 1.5. This is the answer when a single slash “/” was used \n"
               "but when integer division was used using the double slash “//” the decimal, .5 was not considered in the output,\n"
               "which is why the output is 1.\n"
               "Recreate the program using integer division",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Q3.pack()
    
    EntryBox6 = Entry(rootBeginner, width = 50)
    EntryBox6.pack()
    B11 = Button(rootBeginner, text = "Enter", command = integerDivision)
    B11.pack()
    B12 = Button(rootBeginner, text = "Next Lesson: Math Module", command = lesson5, state = DISABLED)
    B12.pack()
    frame6 = Frame(rootBeginner)
    frame6.pack()
    
def integerDivision():
    global EntryBox6
    global frame6
    global B12
    
    if EntryBox6.get() == "3//2" or EntryBox6.get() == "3 // 2": 
        Lbldef16 = Label(frame6, text = "1, correct!")
        Lbldef16.pack()
        B12.config(state = NORMAL)
    elif EntryBox6.get() == "":
        Lbldef17 = Label(frame6, text = "I couldn't see your answer...")
        Lbldef17.pack()
    else:
        Lbldef18 = Label(frame6, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef18.pack()
#------------------mathmodule------------
Bimage5 = PhotoImage(file = "beginner5.png") 
BsmallImage5 = Bimage5.subsample(1,1) 

Bimage6 = PhotoImage(file = "beginner6.png") 
BsmallImage6 = Bimage6.subsample(1,1) 

def lesson5():
    global Lbl10, Lbl11
    global EntryBox6
    global frame6, frame7
    global B11, B12,  B14
    global Q3
    global BlblImage5, lblImage6
    
    BlblImage4.destroy()
    Lbl10.destroy()
    Q3.destroy()
    EntryBox6.destroy()
    B11.destroy()
    B12.destroy()
    frame6.destroy()
    
    Lbl11 = Label(rootBeginner, 
                  text = "There are special codes that can be accessed by importing. One of them is the MATH MODULE.\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2") 
                        
    Lbl11.pack()
    
    BlblImage5 = Label(rootBeginner, image=BsmallImage5, background="#1974D2") 
    BlblImage5.pack()
    BlblImage6 = Label(rootBeginner, image=BsmallImage6, background="#1974D2") 
    BlblImage6.pack()
    
    B14 = Button(rootBeginner, text = "Continue", command = lesson5b, )
    B14.pack()

Bimage7 = PhotoImage(file = "beginner7.png") 
BsmallImage7 = Bimage7.subsample(1,1) 
 
def lesson5b():
    global Lbl10, Lbl11
    global EntryBox6, EntryBox7
    global frame6, frame7
    global B11, B12, B13,B14, B14a
    global Q4
    global BlblImage7
    
    BlblImage5.destroy()
    BlblImage6.destroy()
    B14.destroy()
    
    BlblImage7 = Label(rootBeginner, image=BsmallImage7, background="#1974D2") 
    BlblImage7.pack()
    Q4 = Label(rootBeginner, 
               text = "Try it yourself, using math module, find the square rootBeginner calculation of 28",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Q4.pack()
    
    EntryBox7 = Entry(rootBeginner, width = 50)
    EntryBox7.pack()
    B13 = Button(rootBeginner, text = "Enter", command = mathModule)
    B13.pack()
    B14a = Button(rootBeginner, text = "Next Lesson: Variables", command = lesson6, state = DISABLED)
    B14a.pack()
    frame7 = Frame(rootBeginner)
    frame7.pack()
    
def mathModule():
    global EntryBox7
    global frame7
    global B14
    
    if EntryBox7.get() == "math.sqrt(28)" or EntryBox7.get() == "math.sqrt( 28 )": 
        Lbldef19 = Label(frame7, text = "5.291502622129181, correct!")
        Lbldef19.pack()
        B14a.config(state = NORMAL)
    elif EntryBox7.get() == "":
        Lbldef20 = Label(frame7, text = "I couldn't see your answer...")
        Lbldef20.pack()
    else:
        Lbldef21 = Label(frame7, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef21.pack()

Bimage8 = PhotoImage(file = "beginner8.png") 
BsmallImage8 = Bimage8.subsample(1,1) 

def lesson6():
    global Lbl11, Lbl12
    global EntryBox7, EntryBox8
    global frame7, frame8
    global B13, B14, B15, B16
    global Q4, Q5
    global BlblImage8
    
    BlblImage5.destroy()
    BlblImage6.destroy()
    BlblImage7.destroy()
    Lbl11.destroy()
    Q4.destroy()
    EntryBox7.destroy()
    B13.destroy()
    B14.destroy()
    B14a.destroy()
    frame7.destroy()
    
    Lbl12 = Label(rootBeginner, 
                  text = "You can store a specific value or object with the use of a variable.\n"
                         "You should also bear in mind that all numbers, functions, modules and files are considered as objects. Example:\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
                    
    Lbl12.pack()
    
    BlblImage8= Label(rootBeginner, image=BsmallImage8, background="#1974D2")
    BlblImage8.pack()
    
    Q5 = Label(rootBeginner, 
               text = "y=?\n\n"
               "y + 222\n"
               "What should be the value of y to get the answer 333?",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Q5.pack()
    
    EntryBox8 = Entry(rootBeginner, width = 50)
    EntryBox8.pack()
    B15= Button(rootBeginner, text = "Enter", command = variables)
    B15.pack()
    B16 = Button(rootBeginner, text = "Next Lesson: Increments", command = lesson7, state = DISABLED)
    B16.pack()
    frame8 = Frame(rootBeginner)
    frame8.pack()
    
def variables():
    global EntryBox8
    global frame8
    global B16
   
    if EntryBox8.get() == "111": 
        Lbldef22 = Label(frame8, text = "Correct!")
        Lbldef22.pack()
        B16.config(state = NORMAL)
    elif EntryBox8.get() == "":
        Lbldef23 = Label(frame8, text = "I couldn't see your answer...")
        Lbldef23.pack()
    else:
        Lbldef24 = Label(rootBeginner, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef24.pack()

Bimage9 = PhotoImage(file = "beginner9.png") 
BsmallImage9 = Bimage9.subsample(1,1) 

Bimage10 = PhotoImage(file = "beginner10.png") 
BsmallImage10 = Bimage10.subsample(1,1) 

def lesson7():
    global Lbl12, Lbl13,Labell13
    global EntryBox8, EntryBox9
    global frame8, frame9
    global B15, B16, B17, B18
    global Q5,Q6
    global BlblImage9, BlblImage10
    
    BlblImage8.destroy()
    Lbl12.destroy()
    Q5.destroy()
    EntryBox8.destroy()
    B15.destroy()
    B16.destroy()
    frame8.destroy()
    
    Lbl13 = Label(rootBeginner, 
                  text = "There is no x++ expression in python, instead use +=, -=, *=.\n"
                  "The expression a += b is equivalent to the expression a = a + b. Example:\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2"
                       
                        )
    
    Lbl13.pack()
    
    BlblImage9= Label(rootBeginner, image=BsmallImage9, background="#ffffff") 
    BlblImage9.pack()
    
    Labell13 = Label(rootBeginner, 
                  text ="Starting from the variable x = 0, the value will add 1 to the value of x because of the expression x+=1. ",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Labell13.pack()
    
    Q6 = Label(rootBeginner, 
               text = "What would be the output of the program below?",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    Q6.pack()
    
    BlblImage10= Label(rootBeginner, image=BsmallImage10, background="#1974D2") 
    BlblImage10.pack()
    
    EntryBox9 = Entry(rootBeginner, width = 50)
    EntryBox9.pack()
    B17 = Button(rootBeginner, text = "Enter", command = increment)
    B17.pack()
    B18 = Button(rootBeginner, text = "Next Lesson: If-Else Statements", command = lesson8, state = DISABLED)
    B18.pack()
    frame9 = Frame(rootBeginner)
    frame9.pack()
    
def increment():
    global EntryBox9
    global frame9
    global B18
    
    if EntryBox9.get() == "20": 
        Lbldef25 = Label(frame9, text = "Correct!")
        Lbldef25.pack()
        B18.config(state = NORMAL)
    elif EntryBox9.get() == "":
        Lbldef26 = Label(frame9, text = "I couldn't see your answer...")
        Lbldef26.pack()
    else:
        Lbldef27 = Label(frame9, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef27.pack()

Bimage11 = PhotoImage(file = "beginner11.png") 
BsmallImage11 = Bimage11.subsample(1,1)  
        
def lesson8():
    global Labell13
    global EntryBox9, EntryBox10
    global frame9, frame10
    global B17, B18, B20
    global Q6
    global BlblImage11
    
    
    BlblImage9.destroy()
    BlblImage10.destroy()
    Labell13.destroy()
    Q6.destroy()
    Lbl13.destroy()
    EntryBox9.destroy()
    B17.destroy()
    B18.destroy()
    frame9.destroy()
    
    Lbl14 = Label(rootBeginner,
                  text = "The IF statements will only execute the instruction or code if the condition is true.\n"
"The IF statements should contain the condition statement and end with a colon (if condition:)\n"
"The code is indented on the next line.\n\n"
"The ELSE statement will execute the code if it did not satisfy the first condition (if condition).\n"
"The ELSE statements should contain the else keyword followed by colon (else :).\n"
"Like the if statement, the code is also indented on the next line.\n\n"
"The ELIF statement always follows an if or another elif statement.\n" 
"This statement provides another condition that is checked only if all of the previous conditions were false.\n"
"The ELIF statements should contain the elif keyword, a condition that evaluates to true or false, and end with a colon(:).\n"
"The code is indented on the next line.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2"
                        )
    
    Lbl14.pack()
    
    BlblImage11= Label(rootBeginner, image=BsmallImage11, background="#1974D2")
    BlblImage11.pack()
    
    #Q7 = Label(rootBeginner,
               #  text = "e=7\n"
#"f=7\n"
#"\n"
#"if e<f:\n"
#"    print(\"e is less than f\")\n"
#"\n"
#"_______:\n"
#"    print(\"e is equal to f\")\n"
#"\n"
#"else:\n"
#"    print(\"e is greater than f\")\n"
#"\n"
#"output: e is equal to f"
#"\n"
#"Complete the program.(Hint: elif statement)"
#,
#
   #              background = "#ffffff")
#    Q7.pack()
    
    EntryBox10 = Entry(rootBeginner, width = 50)
    EntryBox10.pack()
    B19 = Button(rootBeginner, text = "Enter", command = ifElse)
    B19.pack()
    B20 = Button(rootBeginner, text = "EXIT PROGRAM", command = rootBeginner.destroy, state = DISABLED)
    B20.pack()
    
def ifElse():
    global EntryBox10
    global B20
    
    if EntryBox10.get() == "elif e==f": 
        Lbldef28 = Label(rootBeginner, text = "Correct!")
        Lbldef28.pack()
        B20.config(state = NORMAL)
    elif EntryBox10.get() == "":
        Lbldef29 = Label(rootBeginner, text = "I couldn't see your answer...")
        Lbldef29.pack()
    else:
        Lbldef30 = Label(rootBeginner, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef30.pack()
        
Iimg = PhotoImage(file = "img1.png")
IsmallImage = Iimg.subsample(4, 4)

Iimg1 = PhotoImage(file = "numpy1.png")
IsmallImage1 = Iimg1.subsample(1,1)
def runINTERMEDIATE():
    global rootIntermediate, ILblImage, ILbl0, ILblImage1, IB0
    
    rootIntermediate = Toplevel(root)
    rootIntermediate.title("Pythography: Intermediate Tutorial")
    rootIntermediate.geometry("800x775")
    rootIntermediate.config(background = "#1974D2")
    
    ILblImage = Label(rootIntermediate, image = IsmallImage, bg = "#1974D2")
    ILblImage.pack()

    ILbl0 = Label(rootIntermediate,
               text = "Numpy is the fundamental package for scientific computing in Python.\n"
                  "It is a Python library that provides a multidimensional array object, various derived objects,\n"
                  "and an assortment of routines for fast operations on arrays."
                  "First import numpy as np \n"
                  "This is to use “np” in the program instead of the word “numpy”\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl0.pack()

    ILblImage1 = Label(rootIntermediate, image = IsmallImage1, bg = "white")
    ILblImage1.pack()

    IB0 = Button(rootIntermediate, text = "LEZGO", command = Ilesson)
    IB0.pack()

def Ilesson():
    global ILbl1
    global IEntryBox1
    global IB1, IB2
    global Iframe1
    
    ILblImage.destroy()
    ILbl0.destroy()
    ILblImage1.destroy()
    IB0.destroy()
    
    ILbl1 = Label(rootIntermediate, 
                    text = "Multiply A by B \n"
                    "It is a Python library that provides a multidimensional array object, various derived objects,\n"
                    "Use matmul(), this is the matrix product of two arrays\n\n"
                    "Example: c=np.matmul(A,B)\n"
                    "Your turn: Multiply B by A. Use the variable c (c = #Your Code Here)\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl1.pack()

    IEntryBox1 = Entry(rootIntermediate, width = 50)
    IEntryBox1.pack()
    IB1 = Button(rootIntermediate, text = "Enter", command = Iexercise1)
    IB1.pack()
    IB2 = Button(rootIntermediate ,text = "Next Lesson: Matrix Addition", command = Ilesson2, state = DISABLED)
    IB2.pack()
    Iframe1 = Frame(rootIntermediate)
    Iframe1.pack()

Iimg1a = PhotoImage(file = "answernumpy1.png")
IsmallImage1a = Iimg1a.subsample(1,1)

def Iexercise1():
    global IEntryBox1,Iimg1a,ILblImage1a
    global IB2
    global Iframe1
    
    if IEntryBox1.get() == "c=np.matmul(B,A)": 
        ILbldef1 = Label(Iframe1, text = "Nice one!")
        ILbldef1.pack()
        ILblImage1a = Label(rootIntermediate, image = IsmallImage1a, bg = "#1974D2")
        ILblImage1a.pack()
        IB2.config(state = NORMAL)
    elif IEntryBox1.get() == "":
        ILbldef2 = Label(Iframe1, text = "I couldn't see your answer...")
        ILbldef2.pack()
    else:
        ILbldef3 = Label(Iframe1, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef3.pack()

def Ilesson2():
    global ILbl1, ILbl2, ILbl3
    global IEntryBox1, IEntryBox2
    global IB1, IB2, IB3, IB4
    global Iframe1, Iframe2
    
    ILbl1.destroy()
    IEntryBox1.destroy()
    IB1.destroy()
    IB2.destroy()
    Iframe1.destroy()
    ILblImage1a.destroy()
    
    ILbl2 = Label(rootIntermediate, 
                  text = "Add A and B or “A+B”",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl2.pack()
    
    ILbl3 = Label(rootIntermediate, 
                  text = "Use numpy.add() function. This function is used when we want to compute the addition of two arrays.\n"
                  "Use the variable c (c = #Your Code Here)\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl3.pack()   
    
    IEntryBox2 = Entry(rootIntermediate, width = 50)
    IEntryBox2.pack()
    IB3 = Button(rootIntermediate, text = "Enter", command = Iexercise2)
    IB3.pack()
    IB4 = Button(rootIntermediate, text = "Next Lesson: Matrix Subtraction", command = Ilesson2_1, state = DISABLED)
    IB4.pack()
    Iframe2 = Frame(rootIntermediate)
    Iframe2.pack()
    
Iimg1b = PhotoImage(file = "answernumpy2.png")
IsmallImage1b = Iimg1b.subsample(1,1)
    
def Iexercise2():
    global IEntryBox2,Iimg1b,ILblImage1b
    global IB4
    global Iframe2
    
    if IEntryBox2.get() == "c=np.add(A,B)":
        ILbldef4 = Label(Iframe2, text = "Correct!")
        ILbldef4.pack()
        ILblImage1b = Label(rootIntermediate, image = IsmallImage1b, bg = "#1974D2")
        ILblImage1b.pack()
        IB4.config(state = NORMAL)
    else:
        ILbldef5 = Label(Iframe2, text = "Incorrect, Hint: use np.add() function")
        ILbldef5.pack()

def Ilesson2_1():
    global ILbl2, ILbl3, ILbl4, ILbl5
    global IEntryBox2, IEntryBox3
    global IB3, IB4, IB5, IB6
    global Iframe2, Iframe3
    global IQ1
    
    ILbl2.destroy()
    ILbl3.destroy()
    IEntryBox2.destroy()
    IB3.destroy()
    IB4.destroy()
    Iframe2.destroy()
    ILblImage1b.destroy()
    
    ILbl4 = Label(rootIntermediate,
                 text = "Using np.subtract()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl4.pack()
    ILbl5 = Label(rootIntermediate,
                 text = "The numpy.subtract() function is used when we want to compute the difference of two arrays.\n"
                  "Use the variable c (c = #Your Code Here)\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl5.pack()
    IQ1 = Label(rootIntermediate, text= "Subtract B from A or A-B",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ1.pack()

    IEntryBox3 = Entry(rootIntermediate, width = 50)
    IEntryBox3.pack()
    IB5 = Button(rootIntermediate, text = "Enter", command = subtract)
    IB5.pack()
    IB6 = Button(rootIntermediate, text = "Next Lesson: Matrix Inverse", command = Ilesson3_1, state = DISABLED) 
    IB6.pack()
    Iframe3 = Frame(rootIntermediate)
    Iframe3.pack()
    
Iimg1c = PhotoImage(file = "answernumpy3.png")
IsmallImage1c = Iimg1c.subsample(1,1)
    
def subtract():
    global IEntryBox3,Iim1ca,ILblImage1c
    global IB6
    global Iframe3
    
    if IEntryBox3.get() == "c=np.subtract(A,B)":
        ILbldef6 = Label(Iframe3, text = "Correct!")
        ILbldef6.pack()
        ILblImage1c = Label(rootIntermediate, image = IsmallImage1c, bg = "#1974D2")  
        ILblImage1c.pack()
        IB6.config(state = NORMAL)
    else:
        ILbldef7 = Label(Iframe3, text = "Please check your answer")
        ILbldef7.pack() 
        
Iimage2 = PhotoImage(file = "numpy2.png")
IsmallImage2 = Iimage2.subsample(1, 1)

def Ilesson3_1():
    global ILbl4, ILbl5, ILbl6
    global IEntryBox3, IEntryBox4
    global IB5, IB6, IB7, IB8
    global IQ1, IQ2
    global Iframe3, Iframe4
    global IlblImage2
    
    ILbl4.destroy()
    ILbl5.destroy()
    IQ1.destroy()
    IEntryBox3.destroy()
    IB5.destroy()
    IB6.destroy()
    Iframe3.destroy()
    ILblImage1c.destroy()
    

    ILbl6 = Label(rootIntermediate,
                text = "The np.linalg.inv() function is to compute the (multiplicative) inverse of a matrix.\n Use the variable c (c = #Your Code Here)\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    
    ILbl6.pack()
    
    IlblImage2 = Label(rootIntermediate, image = Iimage2, background = "#ffffff")
    IlblImage2.pack()
    
    IQ2 = Label(rootIntermediate,
                 text = "Use np.linalg.inv() function on array A",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ2.pack()
    
    IEntryBox4 = Entry(rootIntermediate, width = 50)
    IEntryBox4.pack()
    IB7 = Button(rootIntermediate, text = "Enter", command = linalg)
    IB7.pack()
    IB8 = Button(rootIntermediate, text = "Next Lesson: Matrix Transposition", command = Ilesson4, state = DISABLED)
    IB8.pack()
    Iframe4 = Frame(rootIntermediate)
    Iframe4.pack()
    
Iimg1d = PhotoImage(file = "answernumpy4.png")
IsmallImage1d = Iimg1d.subsample(1,1)

def linalg():
    global IEntryBox4,Iimg1d,ILblImage1d
    global Iframe4
    global IB8
    
    if IEntryBox4.get() == "c=np.linalg.inv(A)": 
        ILbldef8 = Label(Iframe4, text = "Correct!")
        ILbldef8.pack()
        ILblImage1d = Label(rootIntermediate, image = IsmallImage1d, bg = "#1974D2")
        ILblImage1d.pack()
        IB8.config(state = NORMAL)
    elif IEntryBox4.get() == "":
        ILbldef9 = Label(Iframe4, text = "I couldn't see your answer...")
        ILbldef9.pack()
    else:
        ILbldef10 = Label(Iframe4, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef10.pack()
        
Iimage3 = PhotoImage(file = "numpy3.png")
IsmallImage3 = Iimage3.subsample(1, 1)

def Ilesson4():
    global ILbl6, ILbl7, ILbl8
    global IEntryBox4, IEntryBox5
    global IB7, IB8, IB9, IB10
    global IQ2, IQ3
    global Iframe4, Iframe5
    global IlblImage2, IlblImage3
    
    ILblImage1d.destroy()
    ILbl6.destroy()
    IlblImage2.destroy()
    IQ2.destroy()
    IEntryBox4.destroy()
    IB7.destroy()
    IB8.destroy()
    Iframe4.destroy()
    
    ILbl7 = Label(rootIntermediate,
                text = "Using np.transpose",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    
    ILbl7.pack()
    
    IQ3 = Label(rootIntermediate,
                 text = "The np.transpose() function can transpose the 2-D arrays and it has no effect on 1-D arrays.\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ3.pack()
    
    IlblImage3 = Label(rootIntermediate, image = IsmallImage3, background = "#ffffff")
    IlblImage3.pack()
    
    ILbl8 = Label(rootIntermediate, text = "Transpose the array A. Use the variable c (c = #Your Code Here)\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl8.pack()
    
    
    IEntryBox5 = Entry(rootIntermediate, width = 50)
    IEntryBox5.pack()
    IB9 = Button(rootIntermediate, text = "Enter", command = transpose)
    IB9.pack()
    IB10 = Button(rootIntermediate, text = "Next Lesson: ", command = Ilesson5, state = DISABLED)
    IB10.pack()
    Iframe5 = Frame(rootIntermediate)
    Iframe5.pack()
    
Iimg1e = PhotoImage(file = "answernumpy5.png")
IsmallImage1e = Iimg1e.subsample(1,1)

def transpose():
    global IEntryBox5,Iimg1e,ILblImage1e
    global IB10
    global Iframe5
    
    if IEntryBox5.get() == "c=np.transpose(A)": 
        ILbldef11 = Label(Iframe5, text = "Correct!")
        ILbldef11.pack()
        ILblImage1e = Label(rootIntermediate, image = IsmallImage1e, bg = "#1974D2")
        ILblImage1e.pack()
        IB10.config(state = NORMAL)
    elif IEntryBox5.get() == "":
        ILbldef12 = Label(Iframe5, text = "I couldn't see your answer...")
        ILbldef12.pack()
    else:
        ILbldef13 = Label(Iframe5, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef13.pack()
        
Iimage4 = PhotoImage(file = "numpy4.png")
IsmallImage4 = Iimage4.subsample(1, 1)

def Ilesson5():
    global ILbl7, ILbl8, ILbl9
    global IEntryBox5, IEntryBox6
    global IB9, IB10, IB11, IB12
    global IQ3, IQ4
    global Iframe5, Iframe6
    global IlblImage3, IlblImage4
    ILblImage1e.destroy()
    ILbl7.destroy()
    IQ3.destroy()
    IlblImage3.destroy()
    ILbl8.destroy()
    IEntryBox5.destroy()
    IB9.destroy()
    IB10.destroy()
    Iframe5.destroy()

    ILbl9 = Label(rootIntermediate,
                text = "Using np.linalg() and np.matmul() function\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    
    ILbl9.pack()
    
    IlblImage4 = Label(rootIntermediate, image = IsmallImage4, background = "#ffffff")
    IlblImage4.pack()
    
    IQ4 = Label(rootIntermediate,
                 text = "Apply what you have learned in the previous lessons:\n"
                 "c=np.linalg.inv(A)\n"
                 "c=np.matmul(A,?)",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ4.pack()
    
    IEntryBox6 = Entry(rootIntermediate, width = 50)
    IEntryBox6.pack()
    IB11 = Button(rootIntermediate, text = "Enter", command = linalgmatmul)
    IB11.pack()
    IB12 = Button(rootIntermediate, text = "Next Lesson: Element-wise Multiplication/Division", command = Ilesson6, state = DISABLED)
    IB12.pack()
    Iframe6 = Frame(rootIntermediate)
    Iframe6.pack()
    
Iimg1f = PhotoImage(file = "answernumpy6.png")
IsmallImage1f = Iimg1f.subsample(1,1)

def linalgmatmul():
    global IEntryBox6,Iimg1f,ILblImage1f
    global IB12
    global Iframe6

    if IEntryBox6.get() == "c": 
        ILbldef14 = Label(Iframe6, text = "Correct! Since you need to multiply the inverse of a matrix to A using matmul function ")
        ILbldef14.pack()
        ILblImage1f = Label(rootIntermediate, image = IsmallImage1f, bg = "#1974D2") 
        ILblImage1f.pack()
        IB12.config(state = NORMAL)
    elif IEntryBox6.get() == "":
        ILbldef15 = Label(Iframe6, text = "I couldn't see your answer...")
        ILbldef15.pack()
    else:
        ILbldef16 = Label(Iframe6, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef16.pack()
        
def Ilesson6():
    global ILbl9, ILbl10
    global IEntryBox6, IEntryBox7
    global IB11, IB12, IB13, IB14
    global IQ4, IQ5
    global Iframe6, Iframe7
    global IlblImage4 
    ILblImage1f.destroy()
    ILbl9.destroy()
    IlblImage4.destroy()
    IQ4.destroy()
    IEntryBox6.destroy()
    IB11.destroy()
    IB12.destroy()
    Iframe6.destroy()
    
    ILbl10 = Label(rootIntermediate,
                text = "Element-wise multiplication of A and B\n"
                        "Just simply let “C = A*B” then “print(C)\n"
                         "\n"
                        "Element-wise division of A and B\n"
                        "Just simply let “C = A / B” then “print(C)\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    
    ILbl10.pack()
    
    IQ5 = Label(rootIntermediate, text = "Multiplication of A 1st column and B 2nd row\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ5.pack()
    
    IEntryBox7 = Entry(rootIntermediate, width = 50)
    IEntryBox7.pack()
    IB13 = Button(rootIntermediate, text = "Enter", command = multi)
    IB13.pack()
    IB14 = Button(rootIntermediate, text = "Next Lesson: Other Applications of Numpy", command = Ilesson7, state = DISABLED)
    IB14.pack()
    Iframe7 = Frame(rootIntermediate)
    Iframe7.pack()
    
Iimg1g = PhotoImage(file = "answernumpy7.png")
IsmallImage1g = Iimg1g.subsample(1,1)

def multi():
    global IEntryBox7,Iimg1g,ILblImage1g
    global Iframe7
    global IB14
    
    if IEntryBox7.get() == "c=A[:,0]*B[1]": 
        ILbldef17 = Label(Iframe7, text = "Correct! This means that A[:,0] will read the first column in set A and B[1] will read the second row in set B")
        ILbldef17.pack()
        ILblImage1g = Label(rootIntermediate, image = IsmallImage1g, bg = "#1974D2") 
        ILblImage1g.pack()
        IB14.config(state = NORMAL)
    elif IEntryBox7.get() == "":
        ILbldef18 = Label(Iframe7, text = "I couldn't see your answer...")
        ILbldef18.pack()
    else:
        ILbldef19 = Label(Iframe7, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef19.pack()
        
Iimage5 = PhotoImage(file = "numpy5.png")
smallImage5 = Iimage5.subsample(1, 1)

def Ilesson7():
    global ILbl10, ILbl11, ILbl12
    global IEntryBox7
    global IQ5
    global IB13, IB14
    global IlblImage5
    global Button1
    ILblImage1g.destroy()
    ILbl10.destroy()
    IQ5.destroy()
    IEntryBox7.destroy()
    IB13.destroy()
    IB14.destroy()
    Iframe7.destroy()
    
    ILbl11 = Label(rootIntermediate, text = "Other Applications of Numpy",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl11.pack()
    ILbl12 = Label(rootIntermediate, text = "Numpy can be used to show truth tables. Symbols for bitwise are used for numpy.\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl12.pack()
    
    IlblImage5 = Label(rootIntermediate, image=smallImage5, background="#ffffff")
    IlblImage5.pack()
    
    Button1 = Button(rootIntermediate, text = "Next", command = TruthTable)
    Button1.pack()
    
Iimage6 = PhotoImage(file = "numpy6.png")
smallImage6 = Iimage6.subsample(1, 1)

Iimage7 = PhotoImage(file = "numpy7.png")
smallImage7 = Iimage7.subsample(1, 1)

def TruthTable():
    global ILbl11, ILbl12, ILbl13
    global IlblImage5, IlblImage6, IlblImage7
    global Button1, Button2

    ILbl11.destroy()
    ILbl12.destroy()
    IlblImage5.destroy()
    Button1.destroy()
    
    
    ILbl13 = Label(rootIntermediate, text = "Truth Tables\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ILbl13.pack()
    
    IlblImage6 = Label(rootIntermediate, image=smallImage6, background="#ffffff")
    IlblImage6.pack()
    IlblImage7 = Label(rootIntermediate, image=smallImage7, background="#ffffff")
    IlblImage7.pack()
    
    
    Button2 = Button(rootIntermediate, text = "Next", command = TruthTable2)
    Button2.pack()
    
Iimage8 = PhotoImage(file = "numpy8.png")
smallImage8 = Iimage8.subsample(1, 1)

Iimage9 = PhotoImage(file = "numpy9.png")
smallImage9 = Iimage9.subsample(1, 1)

def TruthTable2():
    global ILbl13
    global IlblImage6, IlblImage7, IlblImage8, IlblImage9
    global Button2, Button3
    
    ILbl13.destroy()
    IlblImage6.destroy()
    IlblImage7.destroy()
    Button2.destroy()
    
    IlblImage8 = Label(rootIntermediate, image=smallImage8, background="#ffffff")
    IlblImage8.pack()
    IlblImage9 = Label(rootIntermediate, image=smallImage9, background="#ffffff")
    IlblImage9.pack()
    
    Button3 = Button(rootIntermediate, text = "Next", command = Question1)
    Button3.pack()
    
Iimage10 = PhotoImage(file = "numpy10.png")
smallImage10 = Iimage10.subsample(1, 1)

Iimage11 = PhotoImage(file = "numpy11.png")
smallImage11 = Iimage11.subsample(1, 1)

def Question1():
    global IlblImage8, IlblImage9, IlblImage10, IlblImage11
    global Button3
    global IQ6
    global IEntryBox8
    global IB15, IB16
    global Iframe8
    
    IlblImage8.destroy()
    IlblImage9.destroy()
    Button3.destroy()
    
    IQ6 = Label(rootIntermediate,
                text = "Complete the function that creates/returns a Truth Table array for Negation operation\n"
                 "Please refer to the Truth Table above\n"
                 "Utilize Boolean 1 and 0, as in the above example, e.g. p = np.array([1, 0], dtype=bool).\n"
                 "Complete the code.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")  
    IQ6.pack()
    
    IlblImage10 = Label(rootIntermediate, image=smallImage10, background="#ffffff")
    IlblImage10.pack()
    IlblImage11 = Label(rootIntermediate, image=smallImage11, background="#ffffff")
    IlblImage11.pack()
    
    IEntryBox8 = Entry(rootIntermediate, width = 50)
    IEntryBox8.pack()
    IB15 = Button(rootIntermediate, text = "Enter", command = question1)
    IB15.pack()
    IB16 = Button(rootIntermediate, text = "Next Question: Question 2", command = Ilesson8, state = DISABLED)
    IB16.pack()
    Iframe8 = Frame(rootIntermediate)
    Iframe8.pack()

def question1():
    global IEntryBox8
    global Iframe8
    global IB16
   
    if IEntryBox8.get() == "~p": 
        ILbldef20 = Label(Iframe8, text = "Correct!")
        ILbldef20.pack()
        IB16.config(state = NORMAL)
    elif IEntryBox8.get() == "":
        ILbldef21 = Label(Iframe8, text = "I couldn't see your answer...")
        ILbldef21.pack()
    else:
        ILbldef22 = Label(Iframe8, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef22.pack()
        
Iimage12 = PhotoImage(file = "numpy12.png")
smallImage12 = Iimage12.subsample(1, 1)

Iimage13 = PhotoImage(file = "numpy13.png")
smallImage13 = Iimage13.subsample(1, 1)

def Ilesson8():
    global IEntryBox8, IEntryBox9
    global IlblImage10, IlblImage11, IlblImage12, IlblImage13
    global IQ6, IQ7
    global IB15, IB16, IB17, IB18
    global Iframe8, Iframe9
    
    IQ6.destroy()
    IlblImage10.destroy()
    IlblImage11.destroy()
    IEntryBox8.destroy()
    IB15.destroy()
    IB16.destroy()
    Iframe8.destroy()
    
    
    IQ7 = Label(rootIntermediate,
                 text = "Write a function that creates/returns \n"
                 "a Truth Table array for Disjunction or OR logical operation.\n"
                   "Please refer to the Truth Table above. Complete the code.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ7.pack()
    
    IlblImage12 = Label(rootIntermediate, image=smallImage12, background="#ffffff")
    IlblImage12.pack()
    IlblImage13 = Label(rootIntermediate, image=smallImage13, background="#ffffff")
    IlblImage13.pack()
    
    IEntryBox9 = Entry(rootIntermediate, width = 50)
    IEntryBox9.pack()
    IB17 = Button(rootIntermediate, text = "Enter", command = question2)
    IB17.pack()
    IB18 = Button(rootIntermediate, text = "Next Question: Question 3", command = Ilesson9, state  = DISABLED)
    IB18.pack()
    Iframe9 = Frame(rootIntermediate)
    Iframe9.pack()
    
def question2():
    global IEntryBox9
    global Iframe9
    global IB18
    
    if IEntryBox9.get() == "p|q": 
        ILbldef23 = Label(Iframe9, text = "Correct!")
        ILbldef23.pack()
        IB18.config(state = NORMAL)
    elif IEntryBox9.get() == "":
        ILbldef24 = Label(Iframe9, text = "I couldn't see your answer...")
        ILbldef24.pack()
    else:
        ILbldef25 = Label(Iframe9, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef25.pack()
        
Iimage14 = PhotoImage(file = "numpy14.png")
smallImage14 = Iimage14.subsample(1, 1)

Iimage15 = PhotoImage(file = "numpy15.png")
smallImage15 = Iimage15.subsample(1, 1)

def Ilesson9():
    global IQ7, IQ8
    global IlblImage12, IlblImage13, IlblImage14, IlblImage15
    global IEntryBox9, IEntryBox10
    global IB17, IB18, IB19, IB20
    global Iframe9, Iframe10
    
    IQ7.destroy()
    IlblImage12.destroy()
    IlblImage13.destroy()
    IEntryBox9.destroy()
    IB17.destroy()
    IB18.destroy()
    Iframe9.destroy()
    
    IQ8 = Label(rootIntermediate,
                 text = "Write a function that creates/returns a Truth Table array for Exclusive-Or or XOR logical operation.\n"
                 "Please refer to the Truth Table above. Complete the code." ,font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ8.pack()
    
    IlblImage14 = Label(rootIntermediate, image=smallImage14, background="#ffffff")
    IlblImage14.pack() 
    IlblImage15 = Label(rootIntermediate, image=smallImage15, background="#ffffff")
    IlblImage15.pack()
    
    IEntryBox10 = Entry(rootIntermediate, width = 50)
    IEntryBox10.pack()
    IB19 = Button(rootIntermediate, text = "Enter", command = question3)
    IB19.pack()
    IB20 = Button(rootIntermediate, text = "Next Question: Question 4", command = Ilesson10, state = DISABLED)
    IB20.pack()
    Iframe10 = Frame(rootIntermediate)
    Iframe10.pack()
    
def question3():
    global IEntryBox10
    global Iframe10
    global IB20
    
    if IEntryBox10.get() == "p^q": 
        ILbldef26 = Label(Iframe10, text = "Correct!")
        ILbldef26.pack()
        IB20.config(state = NORMAL)
    elif IEntryBox10.get() == "":
        ILbldef27 = Label(Iframe10, text = "I couldn't see your answer...")
        ILbldef27.pack()
    else:
        ILbldef28 = Label(Iframe10, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef28.pack()

Iimage16 = PhotoImage(file = "numpy16.png")
smallImage16 = Iimage16.subsample(1, 1)

Iimage17 = PhotoImage(file = "numpy17.png")
smallImage17 = Iimage17.subsample(1, 1)

def Ilesson10():
    global IQ8, IQ9
    global IlblImage14, IlblImage15, IlblImage16, IlblImage17
    global IEntryBox10, IEntryBox11 
    global IB19, IB20, IB21, IB22
    global Iframe10, Iframe11
    
    IQ8.destroy()
    IlblImage14.destroy()
    IlblImage15.destroy()
    IEntryBox10.destroy()
    IB19.destroy()
    IB20.destroy()
    Iframe10.destroy()
    
    IQ9 = Label(rootIntermediate,
                 text = "Write a function that creates/returns a Truth Table array for Conditional or Implication logical operation.\n"
                 "Please refer to the Truth Table above. Complete the code.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ9.pack()
    
    IlblImage16 = Label(rootIntermediate, image=smallImage16, background="#ffffff")
    IlblImage16.pack()
    IlblImage17 = Label(rootIntermediate, image=smallImage17, background="#ffffff")
    IlblImage17.pack()
    
    
    IEntryBox11 = Entry(rootIntermediate, width = 50)
    IEntryBox11.pack()
    IB21 = Button(rootIntermediate, text = "Enter", command = question4)
    IB21.pack()
    IB22 = Button(rootIntermediate, text = "Next Question: Question 5", command = Ilesson11, state = DISABLED)
    IB22.pack()
    Iframe11 = Frame(rootIntermediate)
    Iframe11.pack()
    
def question4():
    global IEntryBox11
    global Iframe11
    global IB22
    
    if IEntryBox11.get() == "~p|q": 
        ILbldef29 = Label(Iframe11, text = "Correct!")
        ILbldef29.pack()
        IB22.config(state = NORMAL)
    elif IEntryBox11.get() == "":
        ILbldef30 = Label(Iframe11, text = "I couldn't see your answer...")
        ILbldef30.pack()
    else:
        ILbldef31 = Label(Iframe11, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef31.pack()
        
Iimage18 = PhotoImage(file = "numpy18.png")
smallImage18 = Iimage18.subsample(1, 1)

def Ilesson11():
    global IQ9, IQ10
    global IlblImage16, IlblImage17, IlblImage18
    global IEntryBox11, IEntryBox12
    global IB21, IB22, IB23, IB24
    global Iframe11, Iframe12
    
    IQ9.destroy()
    IlblImage16.destroy()
    IlblImage17.destroy()
    IEntryBox11.destroy()
    IB21.destroy()
    IB22.destroy()
    Iframe11.destroy()
    
    IQ10 = Label(rootIntermediate,
                 text = "Write a function that creates/return a Truth Table array for Biconditional logical operation.\n"
                 "Please refer to the Truth Table above. Complete the code.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    IQ10.pack()
    
    IlblImage18 = Label(rootIntermediate, image=smallImage18, background="#ffffff")
    IlblImage18.pack()
    
    IEntryBox12 = Entry(rootIntermediate, width = 50)
    IEntryBox12.pack()
    IB23 = Button(rootIntermediate, text = "Enter", command = question5)
    IB23.pack()
    IB24 = Button(rootIntermediate, text = "END TUTORIAL", command = rootIntermediate.destroy, state = DISABLED)
    IB24.pack()
    Iframe12 = Frame(rootIntermediate)
    Iframe12.pack()
    
def question5():
    global IEntryBox12
    global Iframe12
    global IB24
    
    if IEntryBox12.get() == "~(p^q)": 
        ILbldef32 = Label(Iframe12, text = "Correct!")
        ILbldef32.pack()
        IB24.config(state = NORMAL)
    elif IEntryBox12.get() == "":
        ILbldef33 = Label(Iframe12, text = "I couldn't see your answer...")
        ILbldef33.pack()
    else:
        ILbldef34 = Label(Iframe12, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef34.pack()
        
Eimage1 = PhotoImage(file = "Expert1.png")
EsmallImage1 = Eimage1.subsample(1, 1)
def runEXPERT():
    global rootExpert, ELbl1, ELbl2, ElblImage1, EB1
    
    rootExpert = Toplevel(root)
    rootExpert.title("Pythography: Expert Tutorial")
    rootExpert.geometry("800x775")
    rootExpert.config(background = "#1974D2")
    rootExpert.resizable(width = False, height = False)
    
    ELbl1 = Label(rootExpert,
             text = "A sequence is a collection of objects that are positionally ordered.\n"
              "Their order is from left to right. The objects are stored and fetched depending on their relative position.\n"
              "This sequence data types includes  strings, lists, range objects returned by range(), and tuples.\n"
              "Some common operations can work both for mutable and immutable sequences.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl1.pack()

    ELbl2 = Label(rootExpert, text = "Operations (Both Mutable and Immutable):\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl2.pack(pady=(20, 10))

    
    ElblImage1 = Label(rootExpert, image=EsmallImage1, background="#ffffff")
    ElblImage1.pack()

    EB1 = Button(rootExpert, text = "Next", command = OperationsMutableOnly)
    EB1.pack()

Eimage2 = PhotoImage(file = "Expert2.png")
EsmallImage2 = Eimage2.subsample(1, 1)
def OperationsMutableOnly():
    global ELbl3
    global ElblImage2
    global EB2
    
    ELbl1.destroy()
    ELbl2.destroy()
    ElblImage1.destroy()
    EB1.destroy()
    
    ELbl3 = Label(rootExpert, text = "Operations (Mutable Only):\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl3.pack()
    
    ElblImage2 = Label(rootExpert, image=EsmallImage2, background="#FFDF00")
    ElblImage2.pack()
    
    EB2 = Button(rootExpert, text = "Next Lesson: Strings Addition (Concatenation)", command = Elesson2)
    EB2.pack()
    
Eimage3 = PhotoImage(file = "Expert3.png")
EsmallImage3 = Eimage3.subsample(1, 1)

def Elesson2():
    global ELbl3, ELbl4, ELbl5, ELbl6
    global EEntryBox1
    global ElblImage2, ElblImage3
    global EB2, EB3, EB4
    global Eframe1
    
    ELbl3.destroy()
    ElblImage2.destroy()
    EB2.destroy()
    
    ELbl4 = Label(rootExpert,
                text = "Strings\n"
                  "Addition (Concatenation)",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl4.pack()
    
    ELbl5 = Label(rootExpert,
                text = "A program can record textual information as well as arbitrary collections of bytes with the use of strings.\n"
                  "In Python, just enclose the character in single quotes ('') or double quotes (" ").",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl5.pack()
    
    ElblImage3 = Label(rootExpert, image=EsmallImage3, background="#ffffff")
    ElblImage3.pack()
    
    ELbl6 = Label(rootExpert,
                text = "What would be the output of the program above?\n"
                        "a. Hello Philippines\n"
                        "  Hello World!\n"
                        "b. Hello World!\n"
                        "     Hello Philippines\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl6.pack()
    
    EEntryBox1 = Entry(rootExpert, width = 50)
    EEntryBox1.pack()
    EB3 = Button(rootExpert, text = "Enter", command = Strings)
    EB3.pack()
    EB4 = Button(rootExpert, text = "Next Lesson: Multiplication (Repetition)", command = Elesson2_1, state = DISABLED)
    EB4.pack()
    Eframe1 = Frame(rootExpert)
    Eframe1.pack()
    
def Strings():
    global EEntryBox1
    global Eframe1
    global EB4
    
    if EEntryBox1.get() == "a":
        ELbldef1 = Label(Eframe1, text = "Correct!")
        ELbldef1.pack()
        EB4.config(state = NORMAL)
    elif EEntryBox1.get() == "b":
        ELbldef2 = Label(Eframe1, text = "Incorrect")
        ELbldef2.pack()
    else:
        ELbldef3 = Label(Eframe1, text = "I don't recognize that answer.")
        ELbldef3.pack()
        
Eimage4 = PhotoImage(file = "Expert4.png")
EsmallImage4 = Eimage4.subsample(1, 1)

def Elesson2_1():
    global ELbl4, ELbl5, ELbl6, ELbl7, ELbl8
    global ElblImage3, ElblImage4
    global EEntryBox1, EEntryBox2
    global EB3, EB4, EB5, EB6
    global EQ1
    global Eframe1, Eframe2
    
    ELbl4.destroy()
    ELbl5.destroy()
    ElblImage3.destroy()
    ELbl6.destroy()
    EEntryBox1.destroy()
    EB3.destroy()
    EB4.destroy()
    Eframe1.destroy()
    
    ELbl7 = Label(rootExpert,
                 text = "Multiplication (Repetition)",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl7.pack()
    ELbl8 = Label(rootExpert,
                 text = "In Python, you can have your string multiplied by a multiplier(of int data type). \n"
                  "The output will display the original string repeated by the amount of multiplier.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl8.pack()
    
    ElblImage4 = Label(rootExpert, image=EsmallImage4, background="#FFDF00")
    ElblImage4.pack()
    
    EQ1 = Label(rootExpert,
                text= "What would be the output of the program above?\n"
                        "a. Pythology Pythology Pythology  Learn Python\n"
                        "b. PythologyPythologyPythologyLearnPython\n"
                        "c. Pythology Pythology Learn Python",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    EQ1.pack()
    
    EEntryBox2 = Entry(rootExpert, width = 50)
    EEntryBox2.pack()
    EB5 = Button(rootExpert, text = "Enter", command = multiplication)
    EB5.pack()
    EB6 = Button(rootExpert, text = "Next Lesson: Indexing", command = Elesson3, state = DISABLED) 
    EB6.pack()
    Eframe2 = Frame(rootExpert)
    Eframe2.pack()
    
def multiplication():
    global EEntryBox2
    global Eframe2
    global EB6
    
    if EEntryBox2.get() == "a":
        ELbldef4 = Label(Eframe2, text = "Correct!")
        ELbldef4.pack()
        EB6.config(state = NORMAL)
    else:
        ELbldef5 = Label(Eframe2, text = "Please check your answer")
        ELbldef5.pack()
        
Eimage5 = PhotoImage(file = "Expert5.png")
EsmallImage5 = Eimage5.subsample(1, 1)

def Elesson3():
    global ELbl7, ELbl8, ELbl9, ELbl10
    global ElblImage4, ElblImage5
    global EQ1, EQ2
    global EEntryBox22, EEntryBox3
    global EB5, EB6, EB7, EB8
    global Eframe2, Eframe3
    
    ELbl7.destroy()
    ELbl8.destroy()
    ElblImage4.destroy()
    EQ1.destroy()
    EEntryBox2.destroy()
    EB5.destroy()
    EB6.destroy()
    Eframe2.destroy()
    
    ELbl9 = Label(rootExpert,
                 text = "Indexing",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl9.pack()
    ELbl10 = Label(rootExpert,
                 text = "To access a specific letter in a word, indexing can be used. For example, str[index] will give an output of the character at the position index in the string str.\n"
                  "The index starts at 0 meaning the first character has an index of 0.\n"
                  "Example:",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl10.pack()
    
    ElblImage5 = Label(rootExpert, image=EsmallImage5, background="#FFDF00")
    ElblImage5.pack()
    
    EQ2 = Label(rootExpert,
                text= 
"hello = \"Pythology\"\n"
"print(hello[5])\n"
"\n"
"What would be the output of the program?",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    EQ2.pack()
    
    EEntryBox3 = Entry(rootExpert, width = 50)
    EEntryBox3.pack()
    EB7 = Button(rootExpert, text = "Enter", command = Indexing)
    EB7.pack()
    EB8 = Button(rootExpert, text = "Next Lesson: Slicing", command = Elesson4, state = DISABLED) 
    EB8.pack()
    Eframe3 = Frame(rootExpert)
    Eframe3.pack()

def Indexing():
    global EEntryBox3
    global Eframe3
    global EB8
    
    if EEntryBox3.get() == "l":
        ELbldef6 = Label(Eframe3, text = "Correct!")
        ELbldef6.pack()
        EB8.config(state = NORMAL)
    else:
        ELbldef7 = Label(Eframe3, text = "Please check your answer")
        ELbldef7.pack()
        
Eimage6 = PhotoImage(file = "Expert6.png")
EsmallImage6 = Eimage6.subsample(1, 1)
def Elesson4():
    global ELbl9, ELbl10, ELbl11, ELbl12
    global ElblImage5, ElblImage6
    global EEntryBox3, EEntryBox4
    global EQ2, EQ3
    global EB7, EB8, EB9, EB10
    global Eframe3, Eframe4
    
    ELbl9.destroy()
    ELbl10.destroy()
    ElblImage5.destroy()
    EQ2.destroy()
    EEntryBox3.destroy()
    EB7.destroy()
    EB8.destroy()
    Eframe3.destroy()
    
    ELbl11 = Label(rootExpert,
                 text = "Slicing",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl11.pack()
    ELbl12 = Label(rootExpert,
                 text = "In slicing, you need to put two indices(numbers) separated by a colon(:). Syntax: str[ind1:ind2]\n"
                "- str[start:end]`  items start through end-1\n"   
                "- str[start:]` items start through the rest of the array\n"   
                "- str[:end]`  items from the beginning through end-1 \n"  
                "- str[:]`  a copy of the whole array " 
                ,font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl12.pack()
    
    ElblImage6 = Label(rootExpert, image=EsmallImage6, background="#FFDF00")
    ElblImage6.pack()
    
    EQ3 = Label(rootExpert,
                text= "Enter what the output of the program is:",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    EQ3.pack()
    
    EEntryBox4 = Entry(rootExpert, width = 50)
    EEntryBox4.pack()
    EB9 = Button(rootExpert, text = "Enter", command = slicing)
    EB9.pack()
    EB10 = Button(rootExpert, text = "Next Lesson: String Length", command = Elesson5, state = DISABLED) 
    EB10.pack()
    Eframe4 = Frame(rootExpert)
    Eframe4.pack()
    
def slicing():
    global EEntryBox4
    global Eframe4
    global EB10
    
    if EEntryBox4.get() == "Project P":
        ELbldef8 = Label(Eframe4, text = "Correct!, it also counts the number of space/s")
        ELbldef8.pack()
        EB10.config(state = NORMAL)
    else:
        ELbldef9 = Label(Eframe4, text = "Please check your answer")
        ELbldef9.pack()
        
Eimage7 = PhotoImage(file = "Expert7.png")
EsmallImage7 = Eimage7.subsample(1, 1)

Eimage8 = PhotoImage(file = "Expert8a.png")
EsmallImage8 = Eimage8.subsample(1, 1)

def Elesson5():
    global ELbl11, ELbl12, ELbl13, ELbl14
    global ElblImage6, ElblImage7, ElblImage8
    global EQ3, EQ4
    global EEntryBox4, EEntryBox5
    global EB9, EB10, EB11, EB12
    global Eframe4, Eframe5
    
    ELbl11.destroy()
    ELbl12.destroy()
    ElblImage6.destroy()
    EQ3.destroy()
    EEntryBox4.destroy()
    EB9.destroy()
    EB10.destroy()
    Eframe4.destroy()
    
    ELbl13 = Label(rootExpert,
                 text = "Slicing",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl13.pack()
    ELbl14 = Label(rootExpert,
                 text = "The len() function is used in order to count the number of characters that a string contains.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl14.pack()
    
    ElblImage7 = Label(rootExpert, image=EsmallImage7, background="#FFDF00")
    ElblImage7.pack()
    
    EQ4 = Label(rootExpert,
                text= "Count the number of characters below.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    EQ4.pack()
    
    ElblImage8 = Label(rootExpert, image=EsmallImage8, background="#FFDF00")
    ElblImage8.pack()
    
    EEntryBox5 = Entry(rootExpert, width = 50)
    EEntryBox5.pack()
    EB11 = Button(rootExpert, text = "Enter", command = StringLength)
    EB11.pack()
    EB12 = Button(rootExpert, text = "Next Lesson: Backslash", command = Elesson6, state = DISABLED) 
    EB12.pack()
    Eframe5 = Frame(rootExpert)
    Eframe5.pack()
    
def StringLength():
    global EEntryBox5
    global Eframe5
    global EB12
    
    if EEntryBox5.get() == "print(len(countdis))":
        ELbldef10 = Label(Eframe5, text = "Correct!")
        ELbldef10.pack()
        EB12.config(state = NORMAL)
    else:
        ELbldef11 = Label(Eframe5, text = "Please check your answer")
        ELbldef11.pack()
        
Eimage9 = PhotoImage(file = "Expert9a.png")
EsmallImage9 = Eimage9.subsample(1, 1)

def Elesson6():
    global ELbl13, ELbl14, ELbl15, ELbl16
    global ElblImage7, ElblImage8, ElblImage9
    global EQ4
    global EEntryBox5, EEntryBox6
    global EB11, EB12, EB13, EB14
    global Eframe5, Eframe6
    
    ELbl13.destroy()
    ELbl14.destroy()
    ElblImage7.destroy()
    EQ4.destroy()
    ElblImage8.destroy()
    EEntryBox5.destroy()
    EB11.destroy()
    EB12.destroy()
    Eframe5.destroy()
    
    ELbl15 = Label(rootExpert,
                 text = "Back Slash",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl15.pack()
    ELbl16 = Label(rootExpert,
                 text = "This is used if you want to put single or double quotation marks. \n"
                   "The symbol '\n' is used to add a line break to the string.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl16.pack()
    
    ElblImage9 = Label(rootExpert, image=EsmallImage9, background="#FFDF00")
    ElblImage9.pack()
    
    EEntryBox6 = Entry(rootExpert, width = 50)
    EEntryBox6.pack()
    EB13 = Button(rootExpert, text = "Enter", command = backslash)
    EB13.pack()
    EB14= Button(rootExpert, text = "Next Lesson: The in operator", command = Elesson6a, state = DISABLED) 
    EB14.pack()
    Eframe6 = Frame(rootExpert)
    Eframe6.pack()
    
def backslash():
    global EEntryBox6
    global Eframe6
    global EB14
    
    if EEntryBox6.get() == "print(" + "\"" + "\\" + "\"Programming" + "\\" + "\"" + "\"" + ")" :
        ELbldef12 = Label(Eframe6, text = "Correct!")
        ELbldef12.pack()
        EB14.config(state = NORMAL)
    else:
        ELbldef13 = Label(Eframe6, text = "Please check your answer")
        ELbldef13.pack()
        
Eimage9b = PhotoImage(file = "Expert9ab.png")
EsmallImage9b = Eimage9b.subsample(1, 1)

Eimage9b2 = PhotoImage(file = "Expert9ab2.png")
EsmallImage9b2 = Eimage9b2.subsample(1, 1)

def Elesson6a():
    global ELbl15, ELbl16, ELbl15b, ELbl16b
    global ElblImage9,ElblImage9b,ElblImage9b2
    
    global  EEntryBox6,EEntryBox6b
    global EB13, EB14,EB13b, EB14b
    global Eframe6,Eframe6b
    
    ELbl15.destroy()
    ELbl16.destroy()
    ElblImage9.destroy()
    EEntryBox6.destroy()
    EB13.destroy()
    EB14.destroy()
    Eframe6.destroy()
    
    
    
    ELbl15b = Label(rootExpert,
                 text = "The in operator",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl15b.pack()
    ELbl16b = Label(rootExpert,
                 text = "The in keyword can be used in order to check whether a specific letter is present in a string.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl16b.pack()
    
    ElblImage9b = Label(rootExpert, image=EsmallImage9b, background="#FFDF00")
    ElblImage9b.pack()
    ElblImage9b2 = Label(rootExpert, image=EsmallImage9b2, background="#FFDF00")
    ElblImage9b2.pack()
    
    EEntryBox6b = Entry(rootExpert, width = 50)
    EEntryBox6b.pack()
    EB13b = Button(rootExpert, text = "Enter", command = theinoperator)
    EB13b.pack()
    EB14b= Button(rootExpert, text = "Next Lesson: Range object", command = Elesson7, state = DISABLED) 
    EB14b.pack()
    Eframe6b = Frame(rootExpert)
    Eframe6b.pack() 
    
def theinoperator():
    global EEntryBox6b
    global Eframe6b
    global EB14b
    
    if EEntryBox6b.get() == "Stay Home!" :
        ELbldef12b = Label(Eframe6b, text = "Correct!")
        ELbldef12b.pack()
        EB14b.config(state = NORMAL)
    else:
        ELbldef13b = Label(Eframe6b, text = "Please check your answer")
        ELbldef13b.pack()
        
Eimage10 = PhotoImage(file = "Expert10.png")
EsmallImage10 = Eimage10.subsample(1, 1)

Eimage11 = PhotoImage(file = "Expert11.png")
EsmallImage11 = Eimage11.subsample(1, 1)

Eimage12 = PhotoImage(file = "Expert12.png")
EsmallImage12 = Eimage12.subsample(1, 1)

Eimage13 = PhotoImage(file = "Expert13.png")
EsmallImage13 = Eimage13.subsample(1, 1)

def Elesson7():
    global ELbl15, ELbl16, ELbl17, ELbl18
    global ElblImage9, ElblImage10, ElblImage11, ElblImage12, ElblImage13
    global EEntryBox6, EEntryBox7
    global EB13, EB14, EB15, EB16
    global Eframe6, Eframe7
    global EQ5
    
    ELbl15b.destroy()
    ELbl16b.destroy()
    ElblImage9b.destroy()
    EEntryBox6b.destroy()
    EB13b.destroy()
    EB14b.destroy()
    Eframe6b.destroy()
    ElblImage9b2.destroy()
    
    ELbl17 = Label(rootExpert,
                 text = "Range Object",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl17.pack()
    ELbl18 = Label(rootExpert,
                 text = "The range type is representing an immutable sequence of numbers and is used in for loops. \n"
                   "The range() function enables to make a range type object.\n"
                   "Examples:",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl18.pack()
    
    ElblImage10 = Label(rootExpert, image=EsmallImage10, background="#FFDF00")
    ElblImage10.pack()
    ElblImage11 = Label(rootExpert, image=EsmallImage11, background="#FFDF00")
    ElblImage11.pack()
    ElblImage12 = Label(rootExpert, image=EsmallImage12, background="#FFDF00")
    ElblImage12.pack()
    
    EQ5 = Label(rootExpert,
                text="Create a program that will display numbers 1 to 10",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    EQ5.pack()
    
    ElblImage13 = Label(rootExpert, image=EsmallImage13, background="#FFDF00")
    ElblImage13.pack()
    
    EEntryBox7 = Entry(rootExpert, width = 50)
    EEntryBox7.pack()
    EB15 = Button(rootExpert, text = "Enter", command = rangeobject)
    EB15.pack()
    EB16= Button(rootExpert, text = "Next Lesson: Heterogeneity", command = ElessonA, state = DISABLED) 
    EB16.pack()
    Eframe7 = Frame(rootExpert)
    Eframe7.pack()
    
def rangeobject():
    global EEntryBox7
    global Eframe7
    global EB16
    
    if EEntryBox7.get() == "b":
        ELbldef14 = Label(Eframe7, text = "Correct!")
        ELbldef14.pack()
        EB16.config(state = NORMAL)
    else:
        ELbldef15 = Label(Eframe7, text = "Please check your answer")
        ELbldef15.pack()
        
EimageA = PhotoImage(file = "Experta.png")
EsmallImageA = EimageA.subsample(1, 1)

def ElessonA():
    global ELbl17, ELbl18, ELbla, ELblb
    
    global ElblImage10, ElblImage11,ElblImageA
    global EB15,EB16,EBa, EEntryBox7
    global Eframea,Eframe7,EQ5
    ELbl17.destroy()
    ELbl18.destroy()
    ElblImage10.destroy()
    ElblImage11.destroy()
    ElblImage12.destroy()
    EQ5.destroy()
    ElblImage13.destroy()
    EEntryBox7.destroy()
    EB15.destroy()
    EB16.destroy()
    Eframe7.destroy()
    
    ELbla = Label(rootExpert,
                text = "Heterogeneity",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbla.pack()
    
    ELblb = Label(rootExpert,
                text = "The Python lists are considered as heterogeneous data structures, with this, they can store mixed types.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELblb.pack()
    
    ElblImageA = Label(rootExpert, image=EsmallImageA, background="#FFDF00")
    ElblImageA.pack()
    
    
    EBa = Button(rootExpert, text = "Next Lesson: Iteration ", command = ElessonB)
    EBa.pack()
    Eframea = Frame(rootExpert)
    Eframea.pack()
    
Eimageb = PhotoImage(file = "Expertb.png")
EsmallImageb = Eimageb.subsample(1, 1)

Eimagec = PhotoImage(file = "Expertc.png")
EsmallImagec = Eimagec.subsample(1, 1)

Eimaged = PhotoImage(file = "Expertd.png")
EsmallImaged = Eimaged.subsample(1, 1)

def ElessonB():
    global ELbla, ELblb, ELblc, ELbld,ELble
    global EEntryBoxA
    global ElblImageA, ElblImageb,ElblImagec,ElblImaged
    global EBa, EBb, EBc
    global Eframea,Eframeb, ELbldefa
    
    ELblb.destroy()
    ELbla.destroy()
    ElblImageA.destroy()

    EBa.destroy()
    Eframea.destroy()
    
    ELblc = Label(rootExpert,
                text = "Iteration",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELblc.pack()
    
    ELbld = Label(rootExpert,
                text = "Iteration is looping over every item in a list/sequence.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbld.pack()
    
    ElblImageb = Label(rootExpert, image=EsmallImageb, background="#FFDF00")
    ElblImageb.pack()
    

    ELble = Label(rootExpert,
                text = "The position of the elements can also be displayed together with the object.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELble.pack()
    ElblImagec = Label(rootExpert, image=EsmallImagec, background="#FFDF00")
    ElblImagec.pack()
    ElblImaged = Label(rootExpert, image=EsmallImaged, background="#FFDF00")
    ElblImaged.pack()
    
    EEntryBoxA = Entry(rootExpert, width = 50)
    EEntryBoxA.pack()
    EBb = Button(rootExpert, text = "Enter", command = iteration)
    EBb.pack()
    EBc = Button(rootExpert, text = "Next Lesson: Manipulating strings ", command = Elesson8)
    EBc.pack()
    Eframeb = Frame(rootExpert)
    Eframeb.pack()
    
def iteration():
    global EEntryBoxA, ELbldefa
    global Eframeb
    global EBb,EBc
    if EEntryBoxA.get() == "c":
        ELbldefa = Label(Eframeb, text = "Correct! It should be for i,letter in enumerate (alphabet):")
        ELbldefa.pack()
        EBc.config(state = NORMAL)
    elif EEntryBoxA.get() == "b"or"a"or"d" or "e":
        ELbldefa = Label(Eframeb, text = "Incorrect")
        ELbldefa.pack()
    else:
        ELbldefa = Label(Eframeb, text = "I don't recognize that answer.")
        ELbldefa.pack()
        
Eimage14 = PhotoImage(file = "Expert14.png")
EsmallImage14 = Eimage14.subsample(1, 1)

Eimage15 = PhotoImage(file = "Expert15.png")
EsmallImage15 = Eimage15.subsample(1, 1)

Eimage16 = PhotoImage(file = "Expert16.png")
EsmallImage16 = Eimage16.subsample(1, 1)
 
def Elesson8():
    global ELbla, ELbl1, ELbl19, ELbl20, ELbl21
    global EimageA, ElblImage14, ElblImage15, ElblImage16,ElblImagec,ElblImageb,ElblImaged
    global EQ5
    global EEntryBox7,EEntryBoxA
    global EBa1, EB16, EB17,ELblc,ELbld,ELble
    global Eframea,ELbldefa,EBb,EBc
    
    ElblImagec.destroy()
    EEntryBoxA.destroy()
    ELbldefa.destroy()        
    ELblc.destroy()
    ELbld.destroy()
    ElblImageb.destroy()
    ELble.destroy()
    ElblImaged.destroy()
    Eframeb.destroy()
    EBb.destroy()
    EBc.destroy()
    
    ELbl19 = Label(rootExpert,
                 text = "Manipulating List",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl19.pack()
    ELbl20 = Label(rootExpert,
                 text = "To arrange the list alphabetically, use listName.sort()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl20.pack()
    
    ElblImage14 = Label(rootExpert, image=EsmallImage14, background="#FFDF00")
    ElblImage14.pack()
    
    ELbl21 = Label(rootExpert,
                 text = "To remove an element, use listName.pop(index) while to add an element, use listName.append(“desired element to be added”)",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl21.pack()
    
    ElblImage15 = Label(rootExpert, image=EsmallImage15, background="#FFDF00")
    ElblImage15.pack()
    ElblImage16 = Label(rootExpert, image=EsmallImage16, background="#FFDF00")
    ElblImage16.pack()

    EB17 = Button(rootExpert, text = "Next Lesson: Manipulating Lists (Part 2)", command = Elesson8_2) 
    EB17.pack()
    
Eimage17 = PhotoImage(file = "Expert17.png")
EsmallImage17 = Eimage17.subsample(1, 1)

Eimage18 = PhotoImage(file = "Expert18.png")
EsmallImage18 = Eimage18.subsample(1, 1)

def Elesson8_2():
    global ELbl19, ELbl20, ELbl21, ELbl22, ELbl23
    global ElblImge14, ElblImage15, ElblImage16, ElblImage17, ElblImage18
    global EB17, EB18
    
    ELbl19.destroy()
    ELbl20.destroy()
    ElblImage14.destroy()
    ELbl21.destroy()
    ElblImage15.destroy()
    ElblImage16.destroy()
    EB17.destroy()
    
    ELbl22 = Label(rootExpert,
                 text = "Lists can also be combined into a single list through using (+)",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl22.pack()
    
    ElblImage17 = Label(rootExpert, image=EsmallImage17, background="#FFDF00")
    ElblImage17.pack()
    
    ELbl23 = Label(rootExpert,
                 text = "A group of lists can also be created by using the variable used in the separate lists as elements in the new list.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")

    ELbl23.pack()
    
    ElblImage18 = Label(rootExpert, image=EsmallImage18, background="#FFDF00")
    ElblImage18.pack()
    
    EB18= Button(rootExpert, text = "Last Lesson: Raw Strings", command = Elesson9) 
    EB18.pack()
    
Eimage19 = PhotoImage(file = "Expert19.png")
EsmallImage19 = Eimage19.subsample(1, 1)

def Elesson9():
    global ELbl22, ELbl23,ELbl24,ELbl25
    global ElblImage17, ElblImage18
    global EB18
    
    ELbl22.destroy()
    ElblImage17.destroy()
    ELbl23.destroy()
    ElblImage18.destroy()
    EB18.destroy()
    
    ELbl24 = Label(rootExpert,
                 text = "Raw Strings",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl24.pack()
    ELbl25 = Label(rootExpert,
                 text = "A programmer can make a raw string by placing a letter (r) before the beginning quotation mark of a string. \n"
                   "This completely ignores all escape characters and prints any backslash that appears in the string.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl25.pack()
   
    ElblImage19 = Label(rootExpert, image=EsmallImage19, background="#FFDF00")
    ElblImage19.pack()

    EB18 = Button(rootExpert, text = "Next Lesson: Multiline Strings with Triple Quotes", command = Elesson10) 
    EB18.pack()
    
Eimage20 = PhotoImage(file = "Expert20.png")
EsmallImage20 = Eimage20.subsample(1, 1)

def Elesson10():
    global ELbl24, ELbl25,ELbl26, ELbl27, EB20
    global ElblImage17, ElblImage18, ElblImage20
    global EB18
    
    ELbl24.destroy()
    ELbl25.destroy()
    ElblImage19.destroy()
    EB18.destroy()
    
    ELbl26 = Label(rootExpert,
                text = " Multiline Strings with Triple Quotes",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl26.pack()
    
    ELbl27 = Label(rootExpert,
                text = "A multiline string in Python begins and ends with either three single quotes or three double quotes.\n"
                 "All the things within the triple quotes are considered part of the string.\n"
                 "The indentation rules do not apply inside the multiline string.\n",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl27.pack()
    
    ElblImage20 = Label(rootExpert, image=EsmallImage20, background="#FFDF00")
    ElblImage20.pack()
    
   
    EB20 = Button(rootExpert, text = "Next Lesson: Putting Strings Inside Other Strings ", command = Elesson11)
    EB20.pack()
    
Eimage21 = PhotoImage(file = "Expert21.png")
EsmallImage21 = Eimage21.subsample(1, 1)

def Elesson11():
    global ELbl26, ELbl27,ELbl28, ELbl28,ELbl29,ELbl30,ELbl31,EEntryBox20
    global ElblImage20,ElblImage21
    global ELbl19, EB20b
    
    ELbl26.destroy()
    ELbl27.destroy()
    ElblImage20.destroy()
    EB20.destroy()
    
    ELbl28 = Label(rootExpert,
                text = " Putting Strings Inside Other Strings",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl28.pack()
    
    ELbl29 = Label(rootExpert,
                text = "String interpolation is a simple approach wherein the %s operator inside the string serves as a marker, which will be replaced by values following the string. ",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl29.pack()
    
    ElblImage21 = Label(rootExpert, image=EsmallImage21, background="#FFDF00")
    ElblImage21.pack()
    EB20b = Button(rootExpert, text = "Continue ", command = Elesson11c)
    EB20b.pack()
    
Eimage23 = PhotoImage(file = "Expert23.png")
EsmallImage23 = Eimage23.subsample(1, 1)

Eimage22 = PhotoImage(file = "Expert22.png")
EsmallImage22 = Eimage22.subsample(1, 1)

def Elesson11c():
    global ELbl26, ELbl27,ELbl28, ELbl28,ELbl29,ELbl30,ELbl31
    global ElblImage20,ElblImage21,ElblImage22,ElblImage23
    global ELbl19, EB20b, EB20c,EB20
    
    ELbl29.destroy()
    ElblImage21.destroy()
    EB20b.destroy()
    
    ELbl30 = Label(rootExpert,
                text = "Here are the examples on how to align your text:",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl30.pack()
    ElblImage23 = Label(rootExpert, image=EsmallImage23, background="#FFDF00")
    ElblImage22.pack()
    ElblImage22 = Label(rootExpert, image=EsmallImage22, background="#FFDF00")
    ElblImage23.pack()
    EB20c = Button(rootExpert, text = "Continue ", command = Elesson11b)
    EB20c.pack()
    
Eimage24 = PhotoImage(file = "Expert24.png")
EsmallImage24 = Eimage24.subsample(1, 1)

def Elesson11b():
    global ELbl26, ELbl27,ELbl28, ELbl28,ELbl29,ELbl30,ELbl31,  EEntryBox20,  Eframe20
    global ElblImage20,ElblImage21,ElblImage22,ElblImage23,ElblImage24
    global ELbl19, EB20b, EB20c, EB20, EB19
    
    ElblImage23.destroy()
    EB20c.destroy()
    ELbl30.destroy()
   
    
    ELbl31 = Label(rootExpert,
                text = "FIll in the codes. Replace the blank with the codes that will put grade = 4.00000 that will show the result below (center-aligned with adding 10 spaces).",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl31.pack()
    ElblImage24 = Label(rootExpert, image=EsmallImage24, background="#FFDF00") 
    ElblImage24.pack()
    
    EEntryBox20 = Entry(rootExpert, width = 50)
    EEntryBox20.pack()
    EB19 = Button(rootExpert, text = "Enter", command = putstring)
    EB19.pack()
    EB20 = Button(rootExpert, text = "Next Lesson:Useful String methods ", command = Elesson12)
    EB20.pack()
    Eframe20 = Frame(rootExpert)
    Eframe20.pack()
    
def putstring():
    global EEntryBox20
    global Eframe20,EB20
    
    
    if EEntryBox20.get() == "d":
        ELbldef20 = Label(Eframe20, text = "Correct!")
        ELbldef20.pack()
        EB20.config(state = NORMAL)
    
    else:
        ELbldef21 = Label(Eframe20, text = "I don't recognize that answer.")
        ELbldef21.pack()
        
Eimage25 = PhotoImage(file = "Expert25.png")
EsmallImage25 = Eimage25.subsample(1, 1)

Eimage26 = PhotoImage(file = "Expert26.png")
EsmallImage26 = Eimage26.subsample(1, 1)

def Elesson12():
    global ELbl28,ELbl31,EEntryBox20,ELbl32,ELbl33,ELbl34,ELbl35,EEntryBox21
    global ElblImage22,ElblImage24,ElblImage25,ElblImage26
    global Eframe20,Eframe21, EB20,EB21, EB22, EB19
    
    ElblImage22.destroy()
    ElblImage24.destroy()
    EB19.destroy()
    ELbl31.destroy()
    EB20.destroy()
    Eframe20.destroy()
    ELbl28.destroy()
    EEntryBox20.destroy()
    
    ELbl32 = Label(rootExpert,
                text = " Useful String methods: Lesson 1",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl32.pack()
    
    ELbl33 = Label(rootExpert,
                text = "Upper() and lower() ",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl33.pack()
    
    ELbl34 = Label(rootExpert,
                text = "The upper() and lower() string methods return a new string where all the letters in the original string have been converted to uppercase or lowercase, respectively.\n"
                   "The upper() and lower() methods are helpful if you need to make a caseinsensitive comparison.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl34.pack()
    
    ElblImage25 = Label(rootExpert, image=EsmallImage25, background="#FFDF00")
    ElblImage25.pack()
    ElblImage26 = Label(rootExpert, image=EsmallImage26, background="#FFDF00")
    ElblImage26.pack()
    
    ELbl35 = Label(rootExpert,
                text = "Try it yourself! Change \'goodmorning\' into \'GOODMORNING\'",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl35.pack()
    
    EEntryBox21 = Entry(rootExpert, width = 50)
    EEntryBox21.pack()
    EB21 = Button(rootExpert, text = "Enter", command = upper)
    EB21.pack()
    EB22 = Button(rootExpert, text = "Next Lesson: Useful String methods: Lesson 2 ", command = Elesson13)
    EB22.pack()
    Eframe21 = Frame(rootExpert)
    Eframe21.pack()
    
def upper():
    global EEntryBox21
    global Eframe21,EB21,EB22,ELbldef22,ELbldef23
    
    
    if EEntryBox21.get() == "\"goodmorning\".upper()":
        ELbldef22 = Label(Eframe21, text = "Correct!")
        ELbldef22.pack()
        EB22.config(state = NORMAL)
    
    else:
        ELbldef23 = Label(Eframe21, text = "I don't recognize that answer.")
        ELbldef23.pack()
        
Eimage27 = PhotoImage(file = "Expert27.png")
EsmallImage27 = Eimage27.subsample(1, 1)

def Elesson13():
    global ELbl31,ELbl32,ELbl33,ELbl34,ELbl35,EEntryBox21, EB21,EB22,Eframe21,ELbl36,ELbl37,ELbl38,ELbl39
    global Eframe22,EB24,EB23,EEntryBox22
    global ElblImage24,ElblImage25,ElblImage26,ElblImage27
    global Eframe20,EB19
    
    EB19.destroy()
    ELbl31.destroy()
    ELbl32.destroy()
    ELbl33.destroy()
    ELbl34.destroy()
    ELbl35.destroy()
    EEntryBox21.destroy()
    EB21.destroy()
    EB22.destroy()
    Eframe21.destroy()
    ElblImage25.destroy()
    ElblImage26.destroy()
    
    
    ELbl36 = Label(rootExpert,
                text = " Useful String methods: Lesson 2",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl36.pack()
    
    ELbl37 = Label(rootExpert,
                text = "Join ()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl37.pack()
    
    ELbl38 = Label(rootExpert,
                text = "The join() method is useful when you have a list of strings that need to be joined together into a single string value.\n"
                   "The join() method is called on a string, gets passed a list of strings, and returns a string.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl38.pack()
    
    ElblImage27 = Label(rootExpert, image=EsmallImage27, background="#FFDF00")
    ElblImage27.pack()
    
    
    ELbl39 = Label(rootExpert,
                text = "Try it yourself! Combine \"@dlsu.edu.ph_\" to the students’ names: Rafael, Marga,and Joshua\n"
                   "Hint: Add ,'' after the last student and no spaces",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl39.pack()
    
    EEntryBox22 = Entry(rootExpert, width = 50)
    EEntryBox22.pack()
    EB23 = Button(rootExpert, text = "Enter", command = join)
    EB23.pack()
    EB24 = Button(rootExpert, text = "Next Lesson:Useful String methods: Lesson 3 ", command = Elesson14)
    EB24.pack()
    Eframe22 = Frame(rootExpert)
    Eframe22.pack()
    
def join():
    global EEntryBox22
    global Eframe22,EB24,ELbldef23
    
    
    if EEntryBox22.get() == "\"@dlsu.edu.ph_\".join(['Rafael','Marga','Joshua',''])":
        ELbldef23 = Label(Eframe22, text = "Correct!")
        ELbldef23.pack()
        EB24.config(state = NORMAL)
    
    else:
        ELbldef23 = Label(Eframe22, text = "I don't recognize that answer.")
        ELbldef23.pack()
        
Eimage28 = PhotoImage(file = "Expert28.png")
EsmallImage28 = Eimage28.subsample(1, 1)

def Elesson14():
    global ELbl36,ELbl37,ELbl38,ELbl39,ELbl40,ELbl41,ELbl42,ELbl43,EB25,EB26,Eframe23
    global Eframe22,EB24,EB23,EEntryBox22,EEntryBox23
    global ElblImage27,ElblImage28
    global Eframe20
    
    EB24.destroy()
    EB23.destroy()
    ELbl36.destroy()
    ELbl37.destroy()
    ELbl38.destroy()
    ELbl39.destroy()
    ELbl35.destroy()
    EEntryBox22.destroy()
    EB21.destroy()
    EB22.destroy()
    Eframe22.destroy()
    ElblImage27.destroy()
    
    
    ELbl40 = Label(rootExpert,
                text = " Useful String methods: Lesson 3",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl40.pack()
    
    ELbl41 = Label(rootExpert,
                text = "Split()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl41.pack()
    
    ELbl42 = Label(rootExpert,
                text = "The split() method does the opposite: It’s called on a string value and returns a list of strings.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl42.pack()
    
    ElblImage28 = Label(rootExpert, image=EsmallImage28, background="#FFDF00")
    ElblImage28.pack()

    
    ELbl43 = Label(rootExpert,
                text = "Try it yourself! Split the string “Animo Lasalle! this is the function of split()” using the split function.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl43.pack()
    
    EEntryBox23 = Entry(rootExpert, width = 50)
    EEntryBox23.pack()
    EB25= Button(rootExpert, text = "Enter", command = splitt)
    EB25.pack()
    EB26 = Button(rootExpert, text = "Next Lesson: Useful String methods: Lesson 5", command = Elesson15)
    EB26.pack()
    Eframe23 = Frame(rootExpert)
    Eframe23.pack()

def splitt():
    global EEntryBox23
    global Eframe23,EB25,ELbldef25,EB26
    
    if EEntryBox23.get() == "'Animo Lasalle!'.split()":
        ELbldef25 = Label(Eframe23, text = "Correct!")
        ELbldef25.pack()
        EB26.config(state = NORMAL)
    else:
        ELbldef25 = Label(Eframe23, text = "I don't recognize that answer.")
        ELbldef25.pack()
                    
Eimage29 = PhotoImage(file = "Expert29.png")
EsmallImage29 = Eimage29.subsample(1, 1)

Eimage30 = PhotoImage(file = "Expert30.png")
EsmallImage30 = Eimage30.subsample(1, 1)

def Elesson15():
    global ELbl40,ELbl41,ELbl42,ELbl43,EB25,EB26,Eframe23,ELbl44,ELbl45,ELbl46,ELbl47
    global EEntryBox23,EEntryBox24,EB27,EB28
    global ElblImage28,ElblImage29,ElblImage30
    global Eframe23,Eframe24
    
    EB25.destroy()
    EB26.destroy()
    ELbl40.destroy()
    ELbl41.destroy()
    ELbl42.destroy()
    ELbl43.destroy()
    ELbl35.destroy()
    EEntryBox23.destroy()
    EB21.destroy()
    EB22.destroy()
    Eframe23.destroy()
    ElblImage28.destroy()
    
    
    ELbl44 = Label(rootExpert,
                text = " Useful String methods: Lesson 4",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl44.pack()
    
    ELbl45 = Label(rootExpert,
                text = "Replace()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl45.pack()
    
    ELbl46 = Label(rootExpert,
                text = "The replace() method accepts two arguments: (1) the string to be replaced and (2) the string to be substituted.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl46.pack()
                    
    ElblImage29 = Label(rootExpert, image=EsmallImage29, background="#FFDF00")
    ElblImage29.pack()
    
    
    ELbl47 = Label(rootExpert,
                text = "Try it yourself! Replace \”python\” with \“pythology\” in the string \"I learned about the replace function in python tutorial.\"",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl47.pack()
                    
    ElblImage30 = Label(rootExpert, image=EsmallImage30, background="#FFDF00")
    ElblImage30.pack()
    
    EEntryBox24 = Entry(rootExpert, width = 50)
    EEntryBox24.pack()
    EB27= Button(rootExpert, text = "Enter", command = replace)
    EB27.pack()
    EB28 = Button(rootExpert, text = "Next Lesson: Useful String methods: Lesson 5", command = Elesson16)
    EB28.pack()
    Eframe24 = Frame(rootExpert)
    Eframe24.pack()

def replace():
    global EEntryBox24
    global Eframe24,EB27,ELbldef26,EB28
    
    
    if EEntryBox24.get() == "change.replace(\'python\',\'pythology\')":
        ELbldef26 = Label(Eframe24, text = "Correct!")
        ELbldef26.pack()
        EB28.config(state = NORMAL)
    
    else:
        ELbldef26 = Label(Eframe24, text = "I don't recognize that answer.")
        ELbldef26.pack()
                    
Eimage31 = PhotoImage(file = "Expert31.png")
EsmallImage31 = Eimage31.subsample(1, 1)

def Elesson16():
    global ELbl44,ELbl45,ELbl46,ELbl47,ELbl48,ELbl49,ELbl50,ELbl51
    global EEntryBox24,EB27,EB28,EEntryBox25
    global ElblImage29,ElblImage30,ElblImage31
    global Eframe24,Eframe25,EB30,EB31
    
    EB25.destroy()
    EB26.destroy()
    ELbl44.destroy()
    ELbl45.destroy()
    ELbl46.destroy()
    ELbl47.destroy()
    EEntryBox24.destroy()
    EB27.destroy()
    EB28.destroy()
    Eframe24.destroy()
    ElblImage29.destroy()
    ElblImage30.destroy()
    
    ELbl48 = Label(rootExpert,
                text = " Useful String methods: Lesson 5",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl48.pack()
    
    ELbl49 = Label(rootExpert,
                text = "Partition()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl49.pack()
    
    ELbl50 = Label(rootExpert,
                text = "The partition() string method can split a string into the text before and after a separator string.\n"\
                   "This method searches the string it is called on for the separator string it is passed, \n"
                   "and returns a tuple of three substrings for the \"before,\" \"separator,\" and \"after\" substrings.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl50.pack()
                    
    ElblImage31 = Label(rootExpert, image=EsmallImage31, background="#FFDF00")
    ElblImage31.pack()
    
    
    ELbl51 = Label(rootExpert,
                text = "Try it yourself! Apply the partition () function in \"Hello Philippines, and Hello, World!\". Use .partition(\"l\")",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl51.pack()

    
    EEntryBox25 = Entry(rootExpert, width = 50)
    EEntryBox25.pack()
    EB30= Button(rootExpert, text = "Enter", command = partition)
    EB30.pack()
    EB31 = Button(rootExpert, text = "Next Lesson: Useful String methods: Lesson 6", command = Elesson17)
    EB31.pack()
    Eframe25 = Frame(rootExpert)
    Eframe25.pack()
    
Eimage32 = PhotoImage(file = "Expert32.png")
EsmallImage32 = Eimage32.subsample(1, 1)

def partition():
    global EEntryBox25
    global Eframe25,ELbldef27,EB31,ElblImage32
    
    
    if EEntryBox25.get() == "\"Hello Philippines, and Hello, World!\".partition(\'l\')":
        ELbldef27 = Label(Eframe25, text = "Correct!")
        ELbldef27.pack()
        EB31.config(state = NORMAL)
        ElblImage32 = Label(rootExpert, image=EsmallImage32, background="#FFDF00")
        ElblImage32.pack()
    
    else:
        ELbldef27 = Label(Eframe25, text = "I don't recognize that answer.")
        ELbldef27.pack()
                    
Eimage33 = PhotoImage(file = "Expert33.png")
EsmallImage33 = Eimage33.subsample(1, 1)

def Elesson17():
    global ELbl48,ELbl49, ELbldef27,ELbl50,ELbl51,ELbl52,ELbl53
    global EEntryBox25
    global ElblImage31,ElblImage32
    global Eframe24,Eframe25,EB30,EB31,EB32,Eframe26
    
    ELbldef27.destroy()
    ELbl48.destroy()
    ELbl49.destroy()
    ELbl50.destroy()
    ELbl51.destroy()
    EEntryBox25.destroy()
    EB30.destroy()
    EB31.destroy()
    Eframe24.destroy()
    ElblImage29.destroy()
    ElblImage31.destroy()
    ElblImage32.destroy()
    
    ELbl52 = Label(rootExpert,
                text = " Useful String methods: Lesson 6",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl52.pack()
    
    ELbl53 = Label(rootExpert,
                text = "rjust() and ljust()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl53.pack()
                    
    ElblImage33 = Label(rootExpert, image=EsmallImage33, background="#FFDF00")
    ElblImage33.pack()
    
    EB32 = Button(rootExpert, text = "Next Lesson: Useful String methods: Lesson 7", command = Elesson18)
    EB32.pack()
    Eframe26 = Frame(rootExpert)
    Eframe26.pack()
    
Eimage34 = PhotoImage(file = "Expert34.png")
EsmallImage34 = Eimage34.subsample(1, 1)

def Elesson18():
    global ELbl52,ELbl53,ELbl54
    global EEntryBox25
    global ElblImage31,ElblImage32
    global Eframe25,Eframe26,EB32,EB33
    
    
    ELbl52.destroy()
    ELbl53.destroy()
    EB27.destroy()
    EB28.destroy()
    Eframe25.destroy()
    EB32.destroy()
    ElblImage33.destroy()
    
    ELbl52 = Label(rootExpert,
                text = " Useful String methods: Lesson 7",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl52.pack()
    
    ELbl53 = Label(rootExpert,
                text = "strip()",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl53.pack()
    ELbl54 = Label(rootExpert,
                text = "Strip() removes any whitespace characters both at the beginning or end of the string.\n"
                   "lstrip() remove whitespace characters from the left while rstrip() remove whitespace characters from the right.",font=("Times", 14),background = "#FFDF00",foreground="#1974D2")
    ELbl54.pack()
                    
    ElblImage34 = Label(rootExpert, image=EsmallImage34, background="#FFDF00")
    ElblImage34.pack()
    
    EB32 = Button(rootExpert, text = "END TUTORIAL", command = rootExpert.destroy)
    EB32.pack()
                    
questions = [
    "Are you taking STEM?",
    "Would you take a computer-related course in college?",
    "Are you interested in programming?",
    "Did you have any programming classes in the past?",
    "Did you find your programming classes difficult in the past?",
    "Do you have any experience in creating programs using Python programming language?",
    "Did you find your past Python programming experience difficult?",
    "Do you search online for codes?",
    "Does watching online tutorials help you become a better programmer?",
]

answersChoice = [
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
    ["Yes", "No"],
]

answers = [0, 1, 1, 1, 0, 1, 0, 1, 1]
userAnswer = []
indexes = []

def gen():
    global indexes
    while(len(indexes) < 9):
        x = random.randint(0, 8)
        if x in indexes:
            continue 
        else:
            indexes.append(x)

def showresult(score):
    labelQuestion.destroy()
    r1.destroy()
    r2.destroy()
    labelresulttext = Label(root, font=("Agency FB", 20), background="green")
    labelresulttext.pack(pady=(265, 0))
    if score >= 31:
        labelresulttext.configure(text = "You're an ADVANCED programmer")
        advancedButton = Button(root, text="Proceed to ADVANCED tutorial", command=runEXPERT)
        advancedButton.pack()
        
    elif (score >= 16 and score < 30):
        labelresulttext.configure(text = "You're an INTERMEDIATE programmer")
        intermediateButton = Button(root, text="Proceed to INTERMEDIATE tutorial", command=runINTERMEDIATE)
        intermediateButton.pack()
        
    else:
        labelresulttext.configure(text = "You're a BEGINNER programmer")
        beginnerButton = Button(root, text="Proceed to BEGINNER tutorial", command=runBEGINNER)
        beginnerButton.pack()    
    
def calc():
    global indexes, userAnswer, answers
    x = 0
    score = 0
    for i  in indexes:
        if userAnswer[x] == answers[i]:
            score = score + 5
        x += 1
    print(score)
    showresult(score)  
    
ques = 1
def selected():
    global radioVar, userAnswer
    global labelQuestion, r1, r2
    global ques
    x = radioVar.get()
    userAnswer.append(x)
    radioVar.set(-1)
    if ques < 9:
        labelQuestion.config(text=questions[indexes[ques]])
        r1['text'] = answersChoice[indexes[ques]][0]
        r2['text'] = answersChoice[indexes[ques]][1]
        ques += 1
    else:
        calc()
    
def startQuiz():
    global labelQuestion, r1, r2
    labelQuestion = Label(root, 
                          text=questions[indexes[0]], 
                          font=16, 
                          width=500, 
                          justify="center", 
                          wraplength=400, 
                          background="#1974D2",
                          foreground="#ffffff")
    labelQuestion.pack(pady=(200, 30))
    
    global radioVar
    radioVar = IntVar()
    radioVar.set(-1)
    
    r1 = Radiobutton(root, 
                     text=answersChoice[indexes[0]][0], 
                     value=0, 
                     variable=radioVar, 
                     command=selected, 
                     background="#1974D2")
    r1.pack(pady=5)
    r2 = Radiobutton(root, 
                     text=answersChoice[indexes[0]][1], 
                     value=1, 
                     variable=radioVar, 
                     command=selected, 
                     background="#1974D2")
    r2.pack(pady=5)

def startIsPressed():
    labelImage.destroy()
    labelText2.destroy()
    buttonStart.destroy()
    labelRules.destroy()
    gen()
    startQuiz()
    
#Hover-in animation
def enter(e):
    img3 = PhotoImage(file="nextbutton1.png")
    smallerImage3 = img3.subsample(10, 10)
    buttonStart["image"] = smallerImage3
    buttonStart.image = smallerImage3
#Hover-out animation
def leave(e):
    img2 = PhotoImage(file="nextbutton.png")
    buttonStart["image"] = smallerImage2
    buttonStart.image = smallerImage2
    
img2 = PhotoImage(file="nextbutton.png")
smallerImage2 = img2.subsample(10, 10)
buttonStart = Button(root,
                     image=smallerImage2, 
                     relief=GROOVE, 
                     border=0, 
                     command=startIsPressed,
                     background = "#FFDF00")
buttonStart.pack(pady=(40, 0))
buttonStart.image = smallerImage2
buttonStart.bind("<Enter>", enter)
buttonStart.bind("<Leave>", leave)

labelRules = Label(root, 
                   text="This quiz contains 10 questions which will determine the extent of your programming knowledge\nGood luck!", 
                   width=100, 
                   font=("Times", 10), 
                   background="#1974D2", 
                   foreground="#faca2f")
labelRules.pack(pady=(80, 0))
root.mainloop()
# Out:
# 15
