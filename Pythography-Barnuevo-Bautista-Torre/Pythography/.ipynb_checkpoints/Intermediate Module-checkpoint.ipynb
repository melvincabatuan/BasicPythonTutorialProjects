# %%
from tkinter import *

root = Tk()
root.title("GUI Project")
root.geometry("1000x1000")
root.config(background="#ffffff")

img1 = PhotoImage(file = "img1.png")
smallImage = img1.subsample(2, 2)
IlblImage = Label(root, image=smallImage, background="#ffffff")
IlblImage.pack()





ILbl1 = Label(root,
            text = "Numpy is the fundamental package for scientific computing in Python.\n"
              "It is a Python library that provides a multidimensional array object, various derived objects,\n"
              "and an assortment of routines for fast operations on arrays."
              "First import numpy as np \n"
               "This is to use “np” in the program instead of the word “numpy”\n"
              "\n"
              "Multiply A by B \n"
               "Use matmul(), this is the matrix product of two arrays"
              "Example: c=np.matmul(A,B)\n"
              "Your turn: Multiply B by A"
              
 
              ,
            background = "#ffffff"
            )
ILbl1.pack()
IEntryBox1 = Entry(root, width = 50)
IEntryBox1.pack()
IB1 = Button(root, text = "Enter", command = Iexercise1)
IB1.pack()
IB2 = Button(root, text = "Next Lesson", command = Ilesson2)
IB2.pack()





def Iexercise1():
    global ILbldef1, ILbldef2, ILbldef3
    
    if IEntryBox1.get() == "c=np.matmul(B,A)": 
        ILbldef1 = Label(root, text = "Nice one!")
        ILbldef1.pack()
    elif IEntryBox1.get() == "":
        ILbldef2 = Label(root, text = "I couldn't see your answer...")
        ILbldef2.pack()
    else:
        ILbldef3 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef3.pack()
        
#----------------------------MATMUL-----------------------

#----------------------------add-----------------------
    
def Ilesson2():
    global ILbldef1, ILbldef2, ILbldef3
    global IEntryBox2
    
    IlblImage.destroy()
    ILbl1.destroy()
    IEntryBox1.destroy()
    IB1.destroy()
    IB2.destroy()
    #Lbldef1.destroy()
    #Lbldef2.destroy()
    #Lbldef3_1.destroy()
    #Lbldef4.destroy()
    
    
    ILbl2 = Label(root,
                text = "Add A and B or “A+B”",
                background = "#ffffff"
                )
    ILbl2.pack()
    
    ILbl3 = Label(root,
                text = "Use numpy.add() function. This function is used when we want to compute the addition of two arrays.")
    ILbl3.pack()
    
    ILbl4 = Label(root,
                text = "Try it yourself! Using the TYPE() syntax, enter a value.",
                background = "#ffffff")
    ILbl4.pack()
    
    IEntryBox2 = Entry(root, width = 50)
    IEntryBox2.pack()
    IB3 = Button(root, text = "Enter", command = Iexercise2)
    IB3.pack()
    IB4 = Button(root, text = "Next Lesson", command = Ilesson2_1)
    IB4.pack()

def Iexercise2():
    global IEntryBox2 
    
    try:
        if IEntryBox2.get() == "c=np.add(A,B)":
            ILbldef4 = Label(root, text = "then print(c)....Correct!")
            ILbldef4.pack()
        else:
            ILbldef5 = Label(root, text = "Incorrect, Hint: use np.add() function")
            ILbldef5.pack()
    except ValueError:
        ILbldef6 = Label(root, text = "I don't recognize that data type, but that's neither INTEGER nor FLOAT")
        ILbldef6.pack()
#----------------------------add-----------------------

#---------------------------subtract----------------------

def Ilesson2_1():
    global IEntryBox3
    
    
    ILbl5 = Label(root,
                 text = "Using np.subtract()")
    ILbl5.pack()
    ILbl6 = Label(root,
                 text = "The numpy.subtract() function is used when we want to compute the difference of two arrays",
                 background = "#ffffff")
    ILbl6.pack()
    IQ1 = Label(root,
               text= "Subtract B from A or A-B")
    IQ1.pack()
    
    IEntryBox3 = Entry(root, width = 50)
    IEntryBox3.pack()
    IB4 = Button(root, text = "Enter", command = subtract)
    IB4.pack()
   
    IB5 = Button(root, text = "Next Lesson", command = Ilesson3_1) 
    IB5.pack()
    
#---------------------------subtract----------------------
    
#--------------------------linalg--------------------------------
def Ilesson3_1():
    global IEntryBox8
    
    
    ILbl7 = Label(root,
                text = "The np.linalg.inv() function is to compute the (multiplicative) inverse of a matrix.")
    
    ILbl7.pack()
    
    IQ8 = Label(root,
                 text = "Use np.linalg.inv() function",
                 background = "#ffffff")
    IQ8.pack()
    
    IEntryBox8 = Entry(root, width = 50)
    IEntryBox8.pack()
    IB6 = Button(root, text = "Enter", command = linalg)
    IB6.pack()
    
    IB7 = Button(root, text = "Next Lesson", command = Ilesson4)
    IB7.pack()
    
    
def linalg():
    global IEntryBox8
    
    if IEntryBox8.get() == "c=np.linalg.inv(A)": 
        ILbldef7 = Label(root, text = "then print(c)....Correct!")
        ILbldef7.pack()
    elif IEntryBox1.get() == "":
        ILbldef8 = Label(root, text = "I couldn't see your answer...")
        ILbldef8.pack()
    else:
        ILbldef9 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef9.pack()

    
#--------------------------linalg--------------------------------   

#----------------------------------------transpose-------------------------- 
def Ilesson4():
    global IEntryBox9
    
    
    
    ILbl8 = Label(root,
                text = "Using np.transpose")
    
    ILbl8.pack()
    
    IQ9 = Label(root,
                 text = "The np.transpose() function can transpose the 2-D arrays and it has no effect on 1-D arrays.",
                 background = "#ffffff")
    IQ9.pack()
    
    IEntryBox9 = Entry(root, width = 50)
    IEntryBox9.pack()
    IB8 = Button(root, text = "Enter", command = transpose)
    IB8.pack()
    
    IB9 = Button(root, text = "Next Lesson", command = Ilesson5)
    IB9.pack()
    
    
def transpose():
    global IEntryBox9
    
   
    
    if IEntryBox9.get() == "c=np.transpose(A)": 
        ILbldef7 = Label(root, text = "then print(c)....Correct!")
        ILbldef7.pack()
    elif IEntryBox1.get() == "":
        ILbldef8 = Label(root, text = "I couldn't see your answer...")
        ILbldef8.pack()
    else:
        ILbldef9 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef9.pack()
        
#---------------------------------------transpose-------------------------- 
#----------------------------------------------------linalg&matmul--------------------
def Ilesson5():
    global IEntryBox10
    
    
    
    ILbl9 = Label(root,
                text = "Using np.linalg() and np.matmul() function\n"
                 "Apply what you have learned in the previous lessons:")
    
    ILbl9.pack()
    
    IQ10 = Label(root,
                 text = "c=np.linalg.inv(A)\n"
                         "c=np.matmul(A,?)",
                 background = "#ffffff")
    IQ10.pack()
    
    IEntryBox10 = Entry(root, width = 50)
    IEntryBox10.pack()
    IB10 = Button(root, text = "Enter", command = linalgmatmul)
    IB10.pack()
    
    IB11 = Button(root, text = "Next Lesson", command = Ilesson6)
    IB11.pack()
    
def linalgmatmul():
    global IEntryBox10
    
   
    
    if IEntryBox10.get() == "c": 
        ILbldef10 = Label(root, text = "Correct! Since you need to multiply the inverse of a matrix to A using matmul function ")
        ILbldef10.pack()
    elif IEntryBox10.get() == "":
        ILbldef9 = Label(root, text = "I couldn't see your answer...")
        ILbldef9.pack()
    else:
        ILbldef10 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef10.pack()
#--------------------------------------------------linalg&matmul--------------------

#-------------------------------------------------multi-------------------

def Ilesson6():
    global IEntryBox11
    
    
    
    ILbl10 = Label(root,
                text = "Element-wise multiplication of A and B\n"
                        "Just simply let “C = A*B” then “print(C)\n"
                         "\n"
                        "Element-wise division of A and B\n"
                        "Just simply let “C = A / B” then “print(C)\n")
    
    ILbl10.pack()
    
    IQ11 = Label(root,
                 text = "Multiplication of A 1st column and B 2nd row\n"
                         ,
                 background = "#ffffff")
    IQ11.pack()
    
    IEntryBox11 = Entry(root, width = 50)
    IEntryBox11.pack()
    IB11 = Button(root, text = "Enter", command = multi)
    IB11.pack()
    
    IB12 = Button(root, text = "Next Lesson", command = Ilesson7)
    IB12.pack()
    
def multi():
    global IEntryBox11
    
   
    
    if IEntryBox11.get() == "c=A[:,0]*B[1]": 
        ILbldef11 = Label(root, text = "then print(C) Correct! This means that A[:,0] will read the first column in set A and B[1] will read the second row in set B")
        ILbldef11.pack()
    elif IEntryBox10.get() == "":
        ILbldef10 = Label(root, text = "I couldn't see your answer...")
        ILbldef10.pack()
    else:
        ILbldef11 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef11.pack()

#-------------------------------------------------multi-------------------

#---------------------------------------------question1----------------

def Ilesson7():
    global IEntryBox12
    
    
    
  
    
    IQ12 = Label(root,
                 text = "Complete the function that creates/return a Truth Table array (similar to and_table() above) for Negation or NOT logical operation. Please refer to the Truth Table above.\n"
                 "Utilize Boolean 1 and 0, as in the above example, e.g. p = np.array([1, 0], dtype=bool)\n"
                 "\n"
                 "",

                 background = "#ffffff")
    IQ12.pack()
    
    IEntryBox12 = Entry(root, width = 50)
    IEntryBox12.pack()
    IB12 = Button(root, text = "Enter", command = question1)
    IB12.pack()
    
    IB13 = Button(root, text = "Next Lesson", command = Ilesson8)
    IB13.pack()
    
def question1():
    global IEntryBox12
    
   
    
    if IEntryBox12.get() == "~p": 
        ILbldef12 = Label(root, text = "Correct!")
        ILbldef12.pack()
    elif IEntryBox12.get() == "":
        ILbldef11 = Label(root, text = "I couldn't see your answer...")
        ILbldef11.pack()
    else:
        ILbldef12 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef12.pack()
#---------------------------------------------question1-----------------

#---------------------------------------------question2-----------------

def Ilesson8():
    global IEntryBox13
    
    
    
    IQ13 = Label(root,
                 text = "Write a function that creates/returns a Truth Table array (similar to and_table() above) for Disjunction or OR logical operation.\n"
                   "Please refer to the Truth Table above." 
,

                 background = "#ffffff")
    IQ13.pack()
    
    IEntryBox13 = Entry(root, width = 50)
    IEntryBox13.pack()
    IB13 = Button(root, text = "Enter", command = question2)
    IB13.pack()
    
    IB14 = Button(root, text = "Next Lesson", command = Ilesson9)
    IB14.pack()
    
def question2():
    global IEntryBox13
    
   
    
    if IEntryBox13.get() == "p|q": 
        ILbldef13 = Label(root, text = "Correct!")
        ILbldef13.pack()
    elif IEntryBox13.get() == "":
        ILbldef12 = Label(root, text = "I couldn't see your answer...")
        ILbldef12.pack()
    else:
        ILbldef13 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef13.pack()

#---------------------------------------------question2-----------------


#---------------------------------------------question3-----------------

def Ilesson9():
    global IEntryBox14
    
    
    
    IQ14 = Label(root,
                 text = "Write a function that creates/return a Truth Table array (similar to and_table() above) for Exclusive-Or or XOR logical operation.\n"
                 "Please refer to the Truth Table above." 
,

                 background = "#ffffff")
    IQ14.pack()
    
    IEntryBox14 = Entry(root, width = 50)
    IEntryBox14.pack()
    IB15 = Button(root, text = "Enter", command = question3)
    IB15.pack()
    
    IB16 = Button(root, text = "Next Lesson", command = Ilesson10)
    IB16.pack()
    
def question3():
    global IEntryBox14
    
   
    
    if IEntryBox14.get() == "p^q": 
        ILbldef14 = Label(root, text = "Correct!")
        ILbldef14.pack()
    elif IEntryBox14.get() == "":
        ILbldef14 = Label(root, text = "I couldn't see your answer...")
        ILbldef14.pack()
    else:
        ILbldef14 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef14.pack()

#---------------------------------------------question3-----------------


#---------------------------------------------question4-----------------

def Ilesson10():
    global IEntryBox15
    
    
    
    IQ15 = Label(root,
                 text = "Write a function that creates/returns a Truth Table array (similar to and_table() above) for Conditional or Implication logical operation.\n"
                 "Please refer to the Truth Table above." 
,

                 background = "#ffffff")
    IQ15.pack()
    
    IEntryBox15 = Entry(root, width = 50)
    IEntryBox15.pack()
    IB17 = Button(root, text = "Enter", command = question4)
    IB17.pack()
    
    IB18 = Button(root, text = "Next Lesson", command = lesson2)
    IB18.pack()
    
def question4():
    global IEntryBox15
    
   
    
    if IEntryBox15.get() == "~p|q": 
        ILbldef15 = Label(root, text = "Correct!")
        ILbldef15.pack()
    elif IEntryBox15.get() == "":
        ILbldef15 = Label(root, text = "I couldn't see your answer...")
        ILbldef15.pack()
    else:
        ILbldef15 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef15.pack()

#---------------------------------------------question4-----------------

#---------------------------------------------question5-----------------

def Ilesson11():
    global IEntryBox16
    
    
    
    IQ16 = Label(root,
                 text = "Write a function that creates/return a Truth Table array (similar to and_table() above) for Biconditional logical operation.\n"
                 "Please refer to the Truth Table above." 
,

                 background = "#ffffff")
    IQ16.pack()
    
    IEntryBox16 = Entry(root, width = 50)
    IEntryBox16.pack()
    IB19 = Button(root, text = "Enter", command = question5)
    IB19.pack()
    
    IB18 = Button(root, text = "Next Lesson", command = lesson2)
    IB18.pack()
    
def question5():
    global IEntryBox16
    
   
    
    if IEntryBox16.get() == "~(p^q)": 
        ILbldef16 = Label(root, text = "Correct!")
        ILbldef16.pack()
    elif IEntryBox16.get() == "":
        ILbldef16 = Label(root, text = "I couldn't see your answer...")
        ILbldef16.pack()
    else:
        ILbldef16 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        ILbldef16.pack()

#---------------------------------------------question5-----------------
    
def subtract():
    global IEntryBox3
    
    if IEntryBox3.get() == "c=np.subtract(A,B)":
        ILbldef7 = Label(root, text = "Correct!")
        ILbldef7.pack()
    else:
        ILbldef8 = Label(root, text = "Please check your answer")
        ILbldef8.pack()
    
        

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c92d3c5e38a4> in <module>
#      34 IEntryBox1 = Entry(root, width = 50)
#      35 IEntryBox1.pack()
# ---> 36 IB1 = Button(root, text = "Enter", command = Iexercise1)
#      37 IB1.pack()
#      38 IB2 = Button(root, text = "Next Lesson", command = Ilesson2)
#
# NameError: name 'Iexercise1' is not defined

# %%
int(5.3)
# Out:
# 5

# %%
user_input = input("Enter something:")

try:
   val = int(user_input)
except ValueError:
   print("That's not an int!")
# Out:
# Enter something:dfs
# That's not an int!

# %%
import tkinter as tk

root = tk.Tk()
root.geometry("300x200")


def onclick(event=None):
    print("You clicked the button")

root.bind('<Return>', onclick)

button = tk.Button(root, text="click me", command=onclick)
button.pack()

root.mainloop()
# Out:
# You clicked the button
# You clicked the button
# You clicked the button
# You clicked the button
# You clicked the button

# %%
5 > 10
# Out:
# False
