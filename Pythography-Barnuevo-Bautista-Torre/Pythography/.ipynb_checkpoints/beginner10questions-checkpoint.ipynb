# %%
from tkinter import *

root = Tk()
root.title("GUI Project")
root.geometry("1000x1000")
root.config(background="#ffffff")

img1 = PhotoImage(file = "img1.png")
smallImage = img1.subsample(2, 2)
lblImage = Label(root, image=smallImage, background="#ffffff")
lblImage.pack()

Lbl1 = Label(root,
            text = "For your first lesson, I am going to teach you how to print in Python\n"
            "To do this, we use the command PRINT\n"
            "For example:\n" 
            "The input is: print(\"Hello World!\")\n"
            "The output is: Hello World!\n\n"
            "Now, to test your skill, try and print the word APPLE (all in uppercase). Enter your answer below.",
            background = "#ffffff"
            )
Lbl1.pack()
EntryBox1 = Entry(root, width = 50)
EntryBox1.pack()


def exercise1():
    global Lbldef1, Lbldef2, Lbldef3
    
    if EntryBox1.get() == "print" + "(" + "\"APPLE\"" + ")": 
        Lbldef1 = Label(root, text = "Nice one!")
        Lbldef1.pack()
    elif EntryBox1.get() == "":
        Lbldef2 = Label(root, text = "I couldn't see your answer...")
        Lbldef2.pack()
    else:
        Lbldef3 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef3.pack()
    
def lesson2():
    global Lbldef1, Lbldef2, Lbldef3
    global EntryBox2
    
    lblImage.destroy()
    Lbl1.destroy()
    EntryBox1.destroy()
    B1.destroy()
    B2.destroy()
    #Lbldef1.destroy()
    #Lbldef2.destroy()
    #Lbldef3_1.destroy()
    #Lbldef4.destroy()
    
    
    Lbl2 = Label(root,
                text = "For your second lesson, I am going to teach you the different DATA TYPES.\n"
                "There are INTEGERS and FLOAT (numeric data types), TRUE or FALSE (boolean data type), "
                "\nSTRING, LIST, and TUPLE (sequence data types)\n",
                background = "#ffffff"
                )
    Lbl2.pack()
    
    Lbl3 = Label(root,
                text = "By definition, INTEGERS are the positive and negative numbers.\n"
                "This includes 1, 5, 69, -20, 0, and more.\n"
                "But in Python, there is a special numeric data type called FLOAT.\n"
                "A FLOAT is a number with decimals. This includes 1.34, 8.43, -2.32, and more\n"
                "\nTo determine a data type, we use the syntax TYPE()\n"
                "For instance, if the input is TYPE(5), the output will be INT (or integer)\n"
                "But if the input is TYPE(5.1), the output will be FLOAT")
    Lbl3.pack()
    
    Lbl4 = Label(root,
                text = "Try it yourself! Using the TYPE() syntax, enter a value.",
                background = "#ffffff")
    Lbl4.pack()
    
    EntryBox2 = Entry(root, width = 50)
    EntryBox2.pack()
    B3 = Button(root, text = "Enter", command = exercise2)
    B3.pack()
    B4 = Button(root, text = "Next Lesson", command = lesson2_1)
    B4.pack()

def exercise2():
    global EntryBox2 
    
    try:
        if (float(EntryBox2.get()).is_integer()) == True:
            Lbldef4 = Label(root, text = "That is an INTEGER")
            Lbldef4.pack()
        elif (float(EntryBox2.get()).is_integer()) == False:
            Lbldef5 = Label(root, text = "That is a FLOAT")
            Lbldef5.pack()
    except ValueError:
        Lbldef6 = Label(root, text = "I don't recognize that data type, but that's neither INTEGER nor FLOAT")
        Lbldef6.pack()

def lesson2_1():
    global EntryBox3
    
    
    Lbl5 = Label(root,
                 text = "Another data type is the boolean data type, consisting of TRUE or FALSE values.\n"
                 "TRUE can be equal to 1, while FALSE can be equal to 0.\n"
                 "For example, 5 = 5 should return TRUE while 5 = 5.21 should return FALSE.")
    Lbl5.pack()
    Lbl6 = Label(root,
                 text = "Try it yourself! There are two equations given, write True or False",
                 background = "#ffffff")
    Lbl6.pack()
    Q1 = Label(root,
               text= "1092 = 1092")
    Q1.pack()
    
    EntryBox3 = Entry(root, width = 50)
    EntryBox3.pack()
    B4 = Button(root, text = "Enter", command = TrueorFalse)
    B4.pack()
   
    B5 = Button(root, text = "Next Lesson", command = lesson3_1) 
    B5.pack()
    
#--------------------------Basic arithmetic--------------------------------
def lesson3_1():
    global EntryBox8
    
    
    Lbl7 = Label(root,
                text = "In this lesson, you will be able to get numerical value\n"
                 "by using the basic arithmetic operations such as \n"
                 "addition, subtraction, multiplication, division, exponentiation and square roots.")
    
    Lbl7.pack()
    
    Q8 = Label(root,
                 text = "Create a program that will Subtract 100 from 200",
                 background = "#ffffff")
    Q8.pack()
    
    EntryBox8 = Entry(root, width = 50)
    EntryBox8.pack()
    B6 = Button(root, text = "Enter", command = basicarithmetic)
    B6.pack()
    
    B7 = Button(root, text = "Next Lesson", command = lesson4)
    B7.pack()
    
    
def basicarithmetic():
    global EntryBox8
    
    if EntryBox8.get() == "200-100": 
        Lbldef7 = Label(root, text = "Nice one!")
        Lbldef7.pack()
    elif EntryBox1.get() == "":
        Lbldef8 = Label(root, text = "I couldn't see your answer...")
        Lbldef8.pack()
    else:
        Lbldef9 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef9.pack()


#----------------------------------------Basic Arithmetic----------------------------    

#----------------------------------------Integer division--------------------------- 
def lesson4():
    global EntryBox9
    
    
    
    Lbl8 = Label(root,
                text = "The division taught to you in the previous topic,\n" 
                 "Basic Arithmetic, the symbol used was a single slash \ \n"
                 "For this lesson, you will learn another type of division, which is integer division.\n"
                 "Integers are whole numbers (without decimals). Similar to this, integer division divides \n"
                 "the numbers but only takes the whole number of the answer and disregards the decimals.\n"
                 "It uses the symbol of double slash “//” ")
    
    Lbl8.pack()
    
    Q9 = Label(root,
                 text = "3 divided by 2 is 1.5. This is the answer when a single slash “/” was used \n"
               "but when integer division was used using the double slash “//” the decimal, .5 was not considered in the output,\n"
               "which is why the output is 1.\n"
               "Recreate the program using integer division",
                 background = "#ffffff")
    Q9.pack()
    
    EntryBox9 = Entry(root, width = 50)
    EntryBox9.pack()
    B8 = Button(root, text = "Enter", command = Integerdivision)
    B8.pack()
    
    B9 = Button(root, text = "Next Lesson", command = lesson2)
    B9.pack()
    
    
def Integerdivision():
    global EntryBox9
    
   
    
    if EntryBox9.get() == "3//2": 
        Lbldef7 = Label(root, text = "1, correct!")
        Lbldef7.pack()
    elif EntryBox1.get() == "":
        Lbldef8 = Label(root, text = "I couldn't see your answer...")
        Lbldef8.pack()
    else:
        Lbldef9 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef9.pack()
        
#----------------------------------------Integer division--------------------------- 
#----------------------------------------------------Math module---------------------
def lesson5():
    global EntryBox10
    
    
    
    Lbl9 = Label(root,
                text = "There are special codes that can be accessed by importing. One of them is the Math module.\n" 
                        "Step 1: Import the Math Module.Type import math.\n"
                        "Step 2: In order to see all the objects under the Math module, type dir(math).\n"
                        "Step 3: In order to use objects from the Math Module, you can either: a.math module or b. use from math import\n"
                        "Step 4: If you would want to know the function of the objects you can use help.\n")
    
    Lbl9.pack()
    
    Q10 = Label(root,
                 text = " Using the Math Module, calculate the hypotenuse of a right triangle\n"
                           "with a=5 and b=8. Use the Pythagorean Theorem,",
                 background = "#ffffff")
    Q10.pack()
    
    EntryBox10 = Entry(root, width = 50)
    EntryBox10.pack()
    B10 = Button(root, text = "Enter", command = mathmodule)
    B10.pack()
    
    B11 = Button(root, text = "Next Lesson", command = lesson2)
    B11.pack()
    
def mathmodule():
    global EntryBox10
    
   
    
    if EntryBox10.get() == "((5**2)+(8**2))**0.5": 
        Lbldef10 = Label(root, text = "9.43 units, correct!")
        Lbldef10.pack()
    elif EntryBox10.get() == "":
        Lbldef9 = Label(root, text = "I couldn't see your answer...")
        Lbldef9.pack()
    else:
        Lbldef10 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef10.pack()
#----------------------------------------------------Math module---------------------

#---------------------------------------------------Variables-------------------

def lesson6():
    global EntryBox11
    
    
    
    Lbl10 = Label(root,
                text = "You can store a specific value or object with the use of a variable.\n"
                         "You should also bear in mind that all numbers, functions, modules and files are considered as objects.Example:\n"
                        "import math\n"
                        "y=0.7\n"
                        "math.sin(y)**2+ math.cos(y)**2\n"
                        "The variable y has a value of 0.7 and was used to the mathematical equation to get the answer 1.0.")
    
    Lbl10.pack()
    
    Q11 = Label(root,
                 text = "y=?\n"
                        "\n"
                        "y + 222\n"
                        "What should be the value of y to get the answer 333?",
                 background = "#ffffff")
    Q11.pack()
    
    EntryBox11 = Entry(root, width = 50)
    EntryBox11.pack()
    B11 = Button(root, text = "Enter", command = variables)
    B11.pack()
    
    B12 = Button(root, text = "Next Lesson", command = lesson2)
    B12.pack()
    
def variables():
    global EntryBox11
    
   
    
    if EntryBox11.get() == "111": 
        Lbldef11 = Label(root, text = "Correct!")
        Lbldef11.pack()
    elif EntryBox10.get() == "":
        Lbldef10 = Label(root, text = "I couldn't see your answer...")
        Lbldef10.pack()
    else:
        Lbldef11 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef11.pack()

#---------------------------------------------------Variables-------------------

#-------------------------------------------------Increment-----------------

def lesson7():
    global EntryBox12
    
    
    
    Lbl11 = Label(root,
                text = "There is no x++ expression in python, instead use +=, -=, *=. The expression a+=b is equivalent to the expression a = a + b. Example:\n"
                        "x = 0\n"
                        "x += 1\n"
                        "print (x)\n"
                        "output: 1\n"
                        "Starting from the variable x = 0, the value will add 1 to the value of x because of the expression x+=1. "
                        )
    
    Lbl11.pack()
    
    Q12 = Label(root,
                 text = "What will be the answer to the expression\n"
                        " x=1\n"
                        "x += 1\n"
                        "x *=10\n"
                        "print (x)",

                 background = "#ffffff")
    Q12.pack()
    
    EntryBox12 = Entry(root, width = 50)
    EntryBox12.pack()
    B12 = Button(root, text = "Enter", command = increment)
    B12.pack()
    
    B13 = Button(root, text = "Next Lesson", command = lesson2)
    B13.pack()
    
def increment():
    global EntryBox12
    
   
    
    if EntryBox12.get() == "20": 
        Lbldef12 = Label(root, text = "Correct!")
        Lbldef12.pack()
    elif EntryBox12.get() == "":
        Lbldef11 = Label(root, text = "I couldn't see your answer...")
        Lbldef11.pack()
    else:
        Lbldef12 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef12.pack()
#-------------------------------------------------Increment-----------------

def lesson8():
    global EntryBox13
    
    
    
    Lbl12 = Label(root,
                text = 
"The if statements will only execute the instruction or code if the condition is true.\n"
 "The if statements should contain the condition statement and end with a colon (if condition:)\n"
"The code is indented on the next line.\n"
"\n"
"The else statement will execute the code if it did not satisfy the first condition (if condition).\n"
"The else statements should contain the else keyword followed by colon (else :).\n"
"Like the if statement, the code is also indented on the next line.\n"
"\n"
"The elif statement always follows an if or another elif statement.\n" 
"This statement provides another condition that is checked only if all of the previous conditions were false.\n"
"The elif statements should contain the elif keyword, a condition that evaluates to true or false, and end with a colon(:).\n"
"The code is indented on the next line."
                        )
    
    Lbl12.pack()
    
    Q13 = Label(root,
                 text = "e=7\n"
"f=7\n"
"\n"
"if e<f:\n"
"    print(\"e is less than f\")\n"
"\n"
"_______:\n"
"    print(\"e is equal to f\")\n"
"\n"
"else:\n"
"    print(\"e is greater than f\")\n"
"\n"
"output: e is equal to f"
"\n"
"Complete the program.(Hint: elif statement)"
,

                 background = "#ffffff")
    Q13.pack()
    
    EntryBox13 = Entry(root, width = 50)
    EntryBox13.pack()
    B13 = Button(root, text = "Enter", command = increment)
    B13.pack()
    
    B14 = Button(root, text = "Next Lesson", command = lesson2)
    B14.pack()
    
def increment():
    global EntryBox13
    
   
    
    if EntryBox13.get() == "elif e==f": 
        Lbldef13 = Label(root, text = "Correct!")
        Lbldef13.pack()
    elif EntryBox13.get() == "":
        Lbldef12 = Label(root, text = "I couldn't see your answer...")
        Lbldef12.pack()
    else:
        Lbldef13 = Label(root, text = "Hmm... Try again, there's a lil bit of error there!")
        Lbldef13.pack()



    
    
def TrueorFalse():
    global EntryBox3
    
    if EntryBox3.get() == "True":
        Lbldef7 = Label(root, text = "Correct!")
        Lbldef7.pack()
    else:
        Lbldef8 = Label(root, text = "Please check your answer")
        Lbldef8.pack()
    
        
B1 = Button(root, text = "Enter", command = exercise1)
B1.pack()
B2 = Button(root, text = "Next Lesson", command = lesson2)
B2.pack()

root.mainloop()

# %%
int(5.3)
# Out:
# 5

# %%
user_input = input("Enter something:")

try:
   val = int(user_input)
except ValueError:
   print("That's not an int!")
# Out:
# Enter something:dfs
# That's not an int!

# %%
import tkinter as tk

root = tk.Tk()
root.geometry("300x200")


def onclick(event=None):
    print("You clicked the button")

root.bind('<Return>', onclick)

button = tk.Button(root, text="click me", command=onclick)
button.pack()

root.mainloop()
# Out:
# You clicked the button
# You clicked the button
# You clicked the button
# You clicked the button
# You clicked the button

# %%
5 > 10
# Out:
# False
