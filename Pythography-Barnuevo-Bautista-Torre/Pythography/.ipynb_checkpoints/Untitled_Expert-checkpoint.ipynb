# %%
from tkinter import *

root = Tk()
root.title("Expert")
root.geometry("700x750")
root.config(background = "#ffffff")

Eimage2 = PhotoImage(file = "expert2.png")
EsmallImage2 = Eimage2.subsample(1, 1)
ElblImage2 = Label(root, image=EsmallImage2, background="#ffffff")
def OperationsMutableOnly():
    global ELbl3
    global ElblImage2
    global EB2
    
    ELbl1.destroy()
    ELbl2.destroy()
    ElblImage1.destroy()
    EB1.destroy()
    
    ELbl3 = Label(root, text = "Operations (Mutable Only):\n",background = "#ffffff")
    ELbl3.pack()
    
    ElblImage2.pack()
    
    EB2 = Button(root, text = "Next Lesson: Strings Addition (Concatenation)", command = Elesson2)
    EB2.pack()

ELbl1 = Label(root,
             text = "A sequence is a collection of objects that are positionally ordered.\n"
              "Their order is from left to right. The objects are stored and fetched depending on their relative position.\n"
              "This sequence data types includes  strings, lists, range objects returned by range(), and tuples.\n"
              "Some common operations can work both for mutable and immutable sequences.",
             background = "#ffffff")
ELbl1.pack()

ELbl2 = Label(root, text = "Operations (Both Mutable and Immutable):\n", background = "#ffffff")
ELbl2.pack(pady=(20, 10))

Eimage1 = PhotoImage(file = "expert1.png")
EsmallImage1 = Eimage1.subsample(1, 1)
ElblImage1 = Label(root, image=EsmallImage1, background="#ffffff")
ElblImage1.pack()

EB1 = Button(root, text = "Next", command = OperationsMutableOnly)
EB1.pack()

#----------------------------Strings-----------------------
Eimage3 = PhotoImage(file = "expert3.png")
EsmallImage3 = Eimage3.subsample(1, 1)
ElblImage3 = Label(root, image=EsmallImage3, background="#ffffff")

def Elesson2():
    global ELbl3, ELbl4, ELbl5, ELbl6
    global EEntryBox1
    global ElblImage2, ElblImage3
    global EB2, EB3, EB4
    global Eframe1
    
    ELbl3.destroy()
    ElblImage2.destroy()
    EB2.destroy()
    
    ELbl4 = Label(root,
                text = "Strings\n"
                  "Addition (Concatenation)",
                background = "#ffffff")
    ELbl4.pack()
    
    ELbl5 = Label(root,
                text = "A program can record textual information as well as arbitrary collections of bytes with the use of strings.\n"
                  "In Python, just enclose the character in single quotes ('') or double quotes (" ").")
    ELbl5.pack()
    
    ElblImage3.pack()
    
    ELbl6 = Label(root,
                text = "What would be the output of the program above?\n"
                        "a. Hello Philippines\n"
                        "   Hello World!\n"
                        "b. Hello World!\n"
                        "   Hello Philippines\n",
                background = "#ffffff")
    ELbl6.pack()
    
    EEntryBox1 = Entry(root, width = 50)
    EEntryBox1.pack()
    EB3 = Button(root, text = "Enter", command = Strings)
    EB3.pack()
    EB4 = Button(root, text = "Next Lesson: Multiplication (Repetition)", command = Elesson2_1, state = DISABLED)
    EB4.pack()
    Eframe1 = Frame(root)
    Eframe1.pack()

def Strings():
    global EEntryBox1
    global Eframe1
    global EB4
    
    if EEntryBox1.get() == "a":
        ELbldef1 = Label(Eframe1, text = "Correct!")
        ELbldef1.pack()
        EB4.config(state = NORMAL)
    elif EEntryBox1.get() == "b":
        ELbldef2 = Label(Eframe1, text = "Incorrect")
        ELbldef2.pack()
    else:
        ELbldef3 = Label(Eframe1, text = "I don't recognize that answer.")
        ELbldef3.pack()
        
#--------------------Multiplication (Repetition)----------------------------

Eimage4 = PhotoImage(file = "expert4.png")
EsmallImage4 = Eimage4.subsample(1, 1)
ElblImage4 = Label(root, image=EsmallImage4, background="#ffffff")

def Elesson2_1():
    global ELbl4, ELbl5, ELbl6, ELbl7, ELbl8
    global ElblImage3, ElblImage4
    global EEntryBox1, EEntryBox2
    global EB3, EB4, EB5, EB6
    global EQ1
    global Eframe1, Eframe2
    
    ELbl4.destroy()
    ELbl5.destroy()
    ElblImage3.destroy()
    ELbl6.destroy()
    EEntryBox1.destroy()
    EB3.destroy()
    EB4.destroy()
    Eframe1.destroy()
    
    ELbl7 = Label(root,
                 text = "Multiplication (Repetition)")
    ELbl7.pack()
    ELbl8 = Label(root,
                 text = "In Python, you can have your string multiplied by a multiplier(of int data type). \n"
                  "The output will display the original string repeated by the amount of multiplier.",
                 background = "#ffffff")
    ELbl8.pack()
    
    ElblImage4.pack()
    
    EQ1 = Label(root,
                text= "What would be the output of the program above?\n"
                        "a. Pythology Pythology Pythology  Learn Python\n"
                        "b. PythologyPythologyPythologyLearnPython\n"
                        "c. Pythology Pythology Learn Python")
    EQ1.pack()
    
    EEntryBox2 = Entry(root, width = 50)
    EEntryBox2.pack()
    EB5 = Button(root, text = "Enter", command = multiplication)
    EB5.pack()
    EB6 = Button(root, text = "Next Lesson: Indexing", command = Elesson3, state = DISABLED) 
    EB6.pack()
    Eframe2 = Frame(root)
    Eframe2.pack()
    
def multiplication():
    global EEntryBox2
    global Eframe2
    global EB6
    
    if EEntryBox2.get() == "a":
        ELbldef4 = Label(Eframe2, text = "Correct!")
        ELbldef4.pack()
        EB6.config(state = NORMAL)
    else:
        ELbldef5 = Label(Eframe2, text = "Please check your answer")
        ELbldef5.pack()

#--------------------Multiplication (Repetition)-----------------------------

#--------------------Indexing----------------------------
Eimage5 = PhotoImage(file = "expert5.png")
EsmallImage5 = Eimage5.subsample(1, 1)
ElblImage5 = Label(root, image=EsmallImage5, background="#ffffff")

def Elesson3():
    global ELbl7, ELbl8, ELbl9, ELbl10
    global ElblImage4, ElblImage5
    global EQ1, EQ2
    global EEntryBox22, EEntryBox3
    global EB5, EB6, EB7, EB8
    global Eframe2, Eframe3
    
    ELbl7.destroy()
    ELbl8.destroy()
    ElblImage4.destroy()
    EQ1.destroy()
    EEntryBox2.destroy()
    EB5.destroy()
    EB6.destroy()
    Eframe2.destroy()
    
    ELbl9 = Label(root,
                 text = "Indexing")
    ELbl9.pack()
    ELbl10 = Label(root,
                 text = "To access a specific letter in a word, indexing can be used. For example, str[index] will give an output of the character at the position index in the string str.\n"
                  "The index starts at 0 meaning the first character has an index of 0.\n"
                  "Example:",
                 background = "#ffffff")
    ELbl10.pack()
    
    ElblImage5.pack()
    
    EQ2 = Label(root,
                text= 
"hello = \"Pythology\"\n"
"print(hello[5])\n"
"\n"
"What would be the output of the program?")
    EQ2.pack()
    
    EEntryBox3 = Entry(root, width = 50)
    EEntryBox3.pack()
    EB7 = Button(root, text = "Enter", command = Indexing)
    EB7.pack()
    EB8 = Button(root, text = "Next Lesson: Slicing", command = Elesson4, state = DISABLED) 
    EB8.pack()
    Eframe3 = Frame(root)
    Eframe3.pack()
    
def Indexing():
    global EEntryBox3
    global Eframe3
    global EB8
    
    if EEntryBox3.get() == "l":
        ELbldef6 = Label(Eframe3, text = "Correct!")
        ELbldef6.pack()
        EB8.config(state = NORMAL)
    else:
        ELbldef7 = Label(Eframe3, text = "Please check your answer")
        ELbldef7.pack()
        
#-------------------Indexing------------------------------

#-------------------SLICING-----------------------------
Eimage6 = PhotoImage(file = "expert6.png")
EsmallImage6 = Eimage6.subsample(1, 1)
ElblImage6 = Label(root, image=EsmallImage6, background="#ffffff")

def Elesson4():
    global ELbl9, ELbl10, ELbl11, ELbl12
    global ElblImage5, ElblImage6
    global EEntryBox3, EEntryBox4
    global EQ2, EQ3
    global EB7, EB8, EB9, EB10
    global Eframe3, Eframe4
    
    ELbl9.destroy()
    ELbl10.destroy()
    ElblImage5.destroy()
    EQ2.destroy()
    EEntryBox3.destroy()
    EB7.destroy()
    EB8.destroy()
    Eframe3.destroy()
    
    ELbl11 = Label(root,
                 text = "Slicing")
    ELbl11.pack()
    ELbl12 = Label(root,
                 text = "In slicing, you need to put two indices(numbers) separated by a colon(:). Syntax: str[ind1:ind2]\n"
                "- str[start:end]`  items start through end-1\n"   
                "- str[start:]`        items start through the rest of the array\n"   
                "- str[:end]`          items from the beginning through end-1 \n"  
                "- str[:]`                a copy of the whole array " 
                ,
                 background = "#ffffff")
    ELbl12.pack()
    
    ElblImage6.pack()
    
    EQ3 = Label(root,
                text= "Enter what the output of the program is:")
    EQ3.pack()
    
    EEntryBox4 = Entry(root, width = 50)
    EEntryBox4.pack()
    EB9 = Button(root, text = "Enter", command = slicing)
    EB9.pack()
    EB10 = Button(root, text = "Next Lesson: String Length", command = Elesson5, state = DISABLED) 
    EB10.pack()
    Eframe4 = Frame(root)
    Eframe4.pack()
    
def slicing():
    global EEntryBox4
    global Eframe4
    global EB10
    
    if EEntryBox4.get() == "Project P":
        ELbldef8 = Label(Eframe4, text = "Correct!")
        ELbldef8.pack()
        EB10.config(state = NORMAL)
    else:
        ELbldef9 = Label(Eframe4, text = "Please check your answer")
        ELbldef9.pack()
        
#--------------------SLICING-----------------------------

    
#-------------------String Length-----------------------------
Eimage7 = PhotoImage(file = "expert7.png")
EsmallImage7 = Eimage7.subsample(1, 1)
ElblImage7 = Label(root, image=EsmallImage7, background="#ffffff")

Eimage8 = PhotoImage(file = "expert8.png")
EsmallImage8 = Eimage8.subsample(1, 1)
ElblImage8 = Label(root, image=EsmallImage8, background="#ffffff")

def Elesson5():
    global ELbl11, ELbl12, ELbl13, ELbl14
    global ElblImage6, ElblImage7, ElblImage8
    global EQ3, EQ4
    global EEntryBox4, EEntryBox5
    global EB9, EB10, EB11, EB12
    global Eframe4, Eframe5
    
    ELbl11.destroy()
    ELbl12.destroy()
    ElblImage6.destroy()
    EQ3.destroy()
    EEntryBox4.destroy()
    EB9.destroy()
    EB10.destroy()
    Eframe4.destroy()
    
    ELbl13 = Label(root,
                 text = "Slicing")
    ELbl13.pack()
    ELbl14 = Label(root,
                 text = "The len() function is used in order to count the number of characters that a string contains.",
                 background = "#ffffff")
    ELbl14.pack()
    
    ElblImage7.pack()
    
    EQ4 = Label(root,
                text= "Count the number of characters below.")
    EQ4.pack()
    
    ElblImage8.pack()
    
    EEntryBox5 = Entry(root, width = 50)
    EEntryBox5.pack()
    EB11 = Button(root, text = "Enter", command = StringLength)
    EB11.pack()
    EB12 = Button(root, text = "Next Lesson: Backslash", command = Elesson6, state = DISABLED) 
    EB12.pack()
    Eframe5 = Frame(root)
    Eframe5.pack()
    
def StringLength():
    global EEntryBox5
    global Eframe5
    global EB12
    
    if EEntryBox5.get() == "17":
        ELbldef10 = Label(Eframe5, text = "Correct!")
        ELbldef10.pack()
        EB12.config(state = NORMAL)
    else:
        ELbldef11 = Label(Eframe5, text = "Please check your answer")
        ELbldef11.pack()
        
#-------------------String Length-----------------------------

#-------------------backslash-----------------------------
Eimage9 = PhotoImage(file = "expert9.png")
EsmallImage9 = Eimage9.subsample(1, 1)
ElblImage9 = Label(root, image=EsmallImage9, background="#ffffff")

def Elesson6():
    global ELbl13, ELbl14, ELbl15, ELbl16
    global ElblImage7, ElblImage8, ElblImage9
    global EQ4
    global EEntryBox5, EEntryBox6
    global EB11, EB12, EB13, EB14
    global Eframe5, Eframe6
    
    ELbl13.destroy()
    ELbl14.destroy()
    ElblImage7.destroy()
    EQ4.destroy()
    ElblImage8.destroy()
    EEntryBox5.destroy()
    EB11.destroy()
    EB12.destroy()
    Eframe5.destroy()
    
    ELbl15 = Label(root,
                 text = "Back Slash")
    ELbl15.pack()
    ELbl16 = Label(root,
                 text = "This is used if you want to put single or double quotation marks. \n"
                   "The symbol '\n' is used to add a line break to the string.",
                 background = "#ffffff")
    ELbl16.pack()
    
    ElblImage9.pack()
    
    EEntryBox6 = Entry(root, width = 50)
    EEntryBox6.pack()
    EB13 = Button(root, text = "Enter", command = backslash)
    EB13.pack()
    EB14= Button(root, text = "Next Lesson: Range Object", command = Elesson7, state = DISABLED) 
    EB14.pack()
    Eframe6 = Frame(root)
    Eframe6.pack()
    
def backslash():
    global EEntryBox6
    global Eframe6
    global EB14
    
    if EEntryBox6.get() == "a" :
        ELbldef12 = Label(Eframe6, text = "Correct!")
        ELbldef12.pack()
        EB14.config(state = NORMAL)
    else:
        ELbldef13 = Label(Eframe6, text = "Please check your answer")
        ELbldef13.pack()
    
#-------------------backslash-----------------------------

#-------------------Rangeobject-----------------------------
Eimage10 = PhotoImage(file = "expert10.png")
EsmallImage10 = Eimage10.subsample(1, 1)
ElblImage10 = Label(root, image=EsmallImage10, background="#ffffff")

Eimage11 = PhotoImage(file = "expert11.png")
EsmallImage11 = Eimage11.subsample(1, 1)
ElblImage11 = Label(root, image=EsmallImage11, background="#ffffff")

Eimage12 = PhotoImage(file = "expert12.png")
EsmallImage12 = Eimage12.subsample(1, 1)
ElblImage12 = Label(root, image=EsmallImage12, background="#ffffff")

Eimage13 = PhotoImage(file = "expert13.png")
EsmallImage13 = Eimage13.subsample(1, 1)
ElblImage13 = Label(root, image=EsmallImage13, background="#ffffff")

def Elesson7():
    global ELbl15, ELbl16, ELbl17, ELbl18
    global ElblImage9, ElblImage10, ElblImage11, ElblImage12, ElblImage13
    global EEntryBox6, EEntryBox7
    global EB13, EB14, EB15, EB16
    global Eframe6, Eframe7
    global EQ5
    
    ELbl15.destroy()
    ELbl16.destroy()
    ElblImage9.destroy()
    EEntryBox6.destroy()
    EB13.destroy()
    EB14.destroy()
    Eframe6.destroy()
    
    ELbl17 = Label(root,
                 text = "Range Object")
    ELbl17.pack()
    ELbl18 = Label(root,
                 text = "The range type is representing an immutable sequence of numbers and is used in for loops. \n"
                   "The range() function enables to make a range type object.\n"
                   "Examples:",
                 background = "#ffffff")
    ELbl18.pack()
    
    ElblImage10.pack()
    ElblImage11.pack()
    ElblImage12.pack()
    
    EQ5 = Label(root,
                text="Create a program that will display numbers 1 to 10")
    EQ5.pack()
    
    ElblImage13.pack()
    
    EEntryBox7 = Entry(root, width = 50)
    EEntryBox7.pack()
    EB15 = Button(root, text = "Enter", command = rangeobject)
    EB15.pack()
    EB16= Button(root, text = "Next Lesson: Manipulating Lists", command = Elesson8, state = DISABLED) 
    EB16.pack()
    Eframe7 = Frame(root)
    Eframe7.pack()
    
def rangeobject():
    global EEntryBox7
    global Eframe7
    global EB16
    
    if EEntryBox7.get() == "b":
        ELbldef14 = Label(Eframe7, text = "Correct!")
        ELbldef14.pack()
        EB16.config(state = NORMAL)
    else:
        ELbldef15 = Label(Eframe7, text = "Please check your answer")
        ELbldef15.pack()


#-------------------Range object-----------------------------

#-------------------manipulatinglist-----------------------------

Eimage14 = PhotoImage(file = "expert14.png")
EsmallImage14 = Eimage14.subsample(1, 1)
ElblImage14 = Label(root, image=EsmallImage14, background="#ffffff")

Eimage15 = PhotoImage(file = "expert15.png")
EsmallImage15 = Eimage15.subsample(1, 1)
ElblImage15 = Label(root, image=EsmallImage15, background="#ffffff")

Eimage16 = PhotoImage(file = "expert16.png")
EsmallImage16 = Eimage16.subsample(1, 1)
ElblImage16 = Label(root, image=EsmallImage16, background="#ffffff")

def Elesson8():
    global ELbl17, ELbl18, ELbl19, ELbl20, ELbl21
    global ElblImage10, ElblImage11, ElblImage12, ElblImage13, ElblImage14, ElblImage15, ElblImage16
    global EQ5
    global EEntryBox7
    global EB15, EB16, EB17
    global Eframe7
    
    ELbl17.destroy()
    ELbl18.destroy()
    ElblImage10.destroy()
    ElblImage11.destroy()
    ElblImage12.destroy()
    EQ5.destroy()
    ElblImage13.destroy()
    EEntryBox7.destroy()
    EB15.destroy()
    EB16.destroy()
    Eframe7.destroy()
                    
    
    ELbl19 = Label(root,
                 text = "Manipulating List")
    ELbl19.pack()
    ELbl20 = Label(root,
                 text = "To arrange the list alphabetically, use listName.sort()",
                 background = "#ffffff")
    ELbl20.pack()
    
    ElblImage14.pack()
    
    ELbl21 = Label(root,
                 text = "To remove an element, use listName.pop(index) while to add an element, use listName.append(“desired element to be added”)",
                 background = "#ffffff")
    ELbl21.pack()
    
    ElblImage15.pack()
    ElblImage16.pack()

    EB17 = Button(root, text = "Next Lesson: Manipulating Lists (Part 2)", command = Elesson8_2) 
    EB17.pack()
    
Eimage17 = PhotoImage(file = "expert17.png")
EsmallImage17 = Eimage17.subsample(1, 1)
ElblImage17 = Label(root, image=EsmallImage17, background="#ffffff")

Eimage18 = PhotoImage(file = "expert18.png")
EsmallImage18 = Eimage18.subsample(1, 1)
ElblImage18 = Label(root, image=EsmallImage18, background="#ffffff")

def Elesson8_2():
    global ELbl19, ELbl20, ELbl21, ELbl22, ELbl23
    global ElblImge14, ElblImage15, ElblImage16, ElblImage17, ElblImage18
    global EB17, EB18
    
    ELbl19.destroy()
    ELbl20.destroy()
    ElblImage14.destroy()
    ELbl21.destroy()
    ElblImage15.destroy()
    ElblImage16.destroy()
    EB17.destroy()
    
    ELbl22 = Label(root,
                 text = "Lists can also be combined into a single list through using (+)",
                 background = "#ffffff")
    ELbl22.pack()
    
    ElblImage17.pack()
    
    ELbl23 = Label(root,
                 text = "A group of lists can also be created by using the variable used in the separate lists as elements in the new list.",
                 background = "#ffffff")
    ELbl23.pack()
    
    ElblImage18.pack()
    
    EB18= Button(root, text = "Last Lesson: Raw Strings", command = Elesson9) 
    EB18.pack()
    
#------------------manipulatinglist-----------------------------

#-------------------Raw Strings-----------------------------
Eimage19 = PhotoImage(file = "expert19.png")
EsmallImage19 = Eimage19.subsample(1, 1)
ElblImage19 = Label(root, image=EsmallImage19, background="#ffffff")

def Elesson9():
    global ELbl22, ELbl23
    global ElblImage17, ElblImage18
    global EB18
    
    ELbl22.destroy()
    ElblImage17.destroy()
    ELbl23.destroy()
    ElblImage18.destroy()
    EB18.destroy()
    
    ELbl24 = Label(root,
                 text = "Raw Strings")
    ELbl24.pack()
    ELbl25 = Label(root,
                 text = "A programmer can make a raw string by placing a letter (r) before the beginning quotation mark of a string. \n"
                   "This completely ignores all escape characters and prints any backslash that appears in the string.",
                 background = "#ffffff")
    ELbl25.pack()
   
    ElblImage19.pack()

    EB18 = Button(root, text = "END TUTORIAL", command = root.destroy) 
    EB18.pack()
                    
                    
root.mainloop()
