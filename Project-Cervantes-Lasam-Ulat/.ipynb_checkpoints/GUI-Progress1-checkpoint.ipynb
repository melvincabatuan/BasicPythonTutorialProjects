# %%
from tkinter import *

# %%
def nameAndSection():
    namsec = Tk()
    myLabel = Label(namsec, text="Please Enter Your Name").grid(row=0)
    name = Entry(namsec, width=50).grid(row=1)
    myLabel2 = Label(namsec, text="Please Enter Your Section").grid(row=2)
    section = Entry(namsec, width=50).grid(row=3)
    but= Button(namsec, text="Enter", command=lambda:[survey1(),namsec.destroy()]).grid(row=4)

# %%
def survey1():
    test = Tk()
    scoreCheck=0
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 1 \n\n_____ are arrays of bytes representing unicode characters.").grid(row=0)
    Radiobutton(test, text="float", variable=r, value=1).grid(row=1)
    Radiobutton(test, text="integer", variable=r, value=2).grid(row=2)
    Radiobutton(test, text="string", variable=r, value=3).grid(row=3)
    Radiobutton(test, text="variable", variable=r, value=4).grid(row=4)
    but = Button(test, text="Enter", command=lambda:[test.destroy(),survey2(checker3(r.get(),scoreCheck))]).grid(row=5)

# %%
def survey2(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 2 \n\nA _____ is a storage location in memory that is represented by a name.").pack()
    Radiobutton(test, text="float", variable=r, value=1).pack()
    Radiobutton(test, text="integer", variable=r, value=2).pack()
    Radiobutton(test, text="string", variable=r, value=3).pack()
    Radiobutton(test, text="variable", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[survey3(checker4(r.get(),s)),test.destroy()]).pack()

# %%
def survey3(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 3 \n\n_____ is a whole number, positive or negative, without decimals, of unlimited length.").pack()
    Radiobutton(test, text="float", variable=r, value=1).pack()
    Radiobutton(test, text="integer", variable=r, value=2).pack()
    Radiobutton(test, text="string", variable=r, value=3).pack()
    Radiobutton(test, text="variable", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[survey4(checker2(r.get(),s)),test.destroy()]).pack()

# %%
def survey4(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 4 \n\n______ is a number containing one or more decimals.").pack()
    Radiobutton(test, text="float", variable=r, value=1).pack()
    Radiobutton(test, text="integer", variable=r, value=2).pack()
    Radiobutton(test, text="string", variable=r, value=3).pack()
    Radiobutton(test, text="variable", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[survey5(checker1(r.get(),s)),test.destroy()]).pack()

# %%
def survey5(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 5 \n\nA _______ is shows a diagram of how a program's process take place.").pack()
    Radiobutton(test, text="PowerPoint", variable=r, value=1).pack()
    Radiobutton(test, text="Pie Chart", variable=r, value=2).pack()
    Radiobutton(test, text="Gantt Chart", variable=r, value=3).pack()
    Radiobutton(test, text="Flowchart", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[survey6(checker4(r.get(),s)),test.destroy()]).pack()

# %%
def survey6(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 6 \n\nErrors caused by improper use of commands and functions are called ______.").pack()
    Radiobutton(test, text="syntaxerror", variable=r, value=1).pack()
    Radiobutton(test, text="assertionerror", variable=r, value=2).pack()
    Radiobutton(test, text="attributeerror", variable=r, value=3).pack()
    Radiobutton(test, text="nameerror", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[survey7(checker1(r.get(),s)),test.destroy()]).pack()

# %%
def survey7(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 7 \n\nWhich one of these is NOT a programming language?").pack()
    Radiobutton(test, text="JavaScript", variable=r, value=1).pack()
    Radiobutton(test, text="C", variable=r, value=2).pack()
    Radiobutton(test, text="HTML", variable=r, value=3).pack()
    Radiobutton(test, text="Java", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[survey8(checker3(r.get(),s)),test.destroy()]).pack()

# %%
def survey8(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 8 \n\nTRUE or FALSE. Does the operator 'a+=b' mean 'a=a+b'.").pack()
    Radiobutton(test, text="TRUE", variable=r, value=1).pack()
    Radiobutton(test, text="FALSE", variable=r, value=2).pack()
    but = Button(test, text="Enter", command=lambda:[survey9(checker1(r.get(),s)),test.destroy()]).pack()

# %%
def survey9(s):
    test = Tk()
    r = IntVar()
    q1 = Label(test, text="QUESTION 9 \n\nTRUE or FALSE. The XOR operator, or \"Exclusive OR\", is a Boolean operator wherein the value is TRUE if p and q are both true and FALSE if one of them is false.").pack()
    Radiobutton(test, text="TRUE", variable=r, value=1).pack()
    Radiobutton(test, text="FALSE", variable=r, value=2).pack()
    but = Button(test, text="Enter", command=lambda:[survey10(checker2(r.get(),s)),test.destroy()]).pack()

# %%
def survey10(s):
    test = Tk()
    r = IntVar()
    r.set("1")
    q1 = Label(test, text="QUESTION 10 \n\nWhat is the keyword for making loops?").pack()
    Radiobutton(test, text="for", variable=r, value=1).pack()
    Radiobutton(test, text="when", variable=r, value=2).pack()
    Radiobutton(test, text="if", variable=r, value=3).pack()
    Radiobutton(test, text="else", variable=r, value=4).pack()
    but = Button(test, text="Enter", command=lambda:[Scoring(checker1(r.get(),s)),test.destroy()]).pack()

# %%
def checker1(value,s):
    if value==1:
        s+=1
    return s

# %%
def checker2(value,s):
    if value==2:
        s+=1
    return s

# %%
def checker3(value,s):
    if value==3:
        s+=1
    return s

# %%
def checker4(value,s):
    if value==4:
        s+=1
    return s

# %%
def Scoring(scoreCheck):
    score = Tk()
    myLabel = Label(score, text="Your score is " + str(scoreCheck) + "/10").pack()
    
    if scoreCheck >= 8:
        myLablel2 = Label(score, text="You are an EXPERT Programmer").pack()
        reviewer = Button(score,text="Expert Reviewer",command=lambda:[score.destroy(),expertmodule()]).pack()
    elif (scoreCheck <=7) and (scoreCheck > 5):
        myLablel2 = Label(score, text="You are an INTERMEDIATE Programmer").pack()
        reviewer = Button(score,text=" Intermmediate Reviewer",command=lambda:[score.destroy(),intermmediatemodule()]).pack()
    else:
        myLablel2 = Label(score, text="You are a BEGINNER Programmer").pack()
        reviewer = Button(score,text="Beginner Reviewer",command=lambda:[score.destroy(),beginnermodule()]).pack()

# %%
root = Tk()

# %%
maintxt1 = Label(root, text="Hello, Welcome to your personalized learning system!")
maintxt1.grid(row=1,column=1)
maintxt2 = Label(root, text="Would you like to review about Python?")
maintxt2.grid(row=2,column=1)

# %%
butyes = Button(root,text="Yes",command=lambda:[nameAndSection(),root.destroy()])
butyes.grid(row=3,column=0)
butno = Button(root,text="No",command=root.destroy)
butno.grid(row=3, column=2)

# %%
def beginnermodule():

    import tkinter as tk
    
    root = tk.Tk()
    S = tk.Scrollbar(root)
    T = tk.Text(root, width=150)
    S.pack(side=tk.RIGHT, fill=tk.Y)
    T.pack(side=tk.LEFT, fill=tk.Y)
    S.config(command=T.yview)
    T.config(yscrollcommand=S.set)
    
    
    quote = """Programming Crash Course
LBYCPA1
What is Programming/Coding:
	Programming/Coding is a method in which you give the computer instructions through inputting commands in a certain programming language to perform specific operations and complete given tasks. These operations could range from the basic mathematical operations such as addition, subtraction, division and multiplication to solving math problems such as looking for the are of a triangle or looking for the derivative of limits. 
Different Programming Languages:
	Listed below are a list of the most commonly used programming languages and their highlights.
1.)	Python
•	Active community support and rapid development
•	Batteries are included language
•	Easy-to-learn, clear syntax
•	Extensible to a greater degree
•	Free, open source, cross-platform
•	High-level language with high readability and reliability
•	Object-oriented nature
•	Python programs are easy to modify for supporting different database engines
•	Used for prototyping and testing code that is later to be implemented using other programming languages
2.)	C++
•	A wide range of applications, varying from simple GUI applications to vivid 3D games and real-time mathematical simulations
•	Efficient, fast, and powerful
•	Highly portable, a top choice for multi-device, multi-platform development
•	Object-oriented programming language leveraging classes, data abstraction and encapsulation, inheritance, and polymorphism
•	Rich function library
•	Supports exception handling and function overloading
3.)	Java
•	Designed for distributed computing
•	Easy to compile, debug, learn, and write
•	High degree of robustness
•	Multi threaded, capable of performing different tasks simultaneously within a program
•	Object-oriented, allows the creation of modular programs and reusable code
•	Platform-independent, easy to migrate from one system to another
•	Supports automatic memory allocation and garbage collection
Two types of programming: 
Procedural Programming- Procedural programming is the first programming paradigm that a new developer/programmer will learn. It includes all the fundamentals of programming. This is where the developer will learn the basics of programming. 
Functional Programming- Functional programming is the programming paradigm that tries to bind several different operations into pure mathematical functions. It is a declarative style of programming that focuses on what the developer should solve rather than how the developer should solve the problem.



I.	Beginner:
1.	Data Types – Data types are the classification/categorization of data items. Data types represent a kind of value that determines what operations could be and could not be performed on the available data. Examples of Data types are the Numeric, non-numeric and Boolean will be discussed below. However Data types may vary to the Programming Language that is being used. 

i.	 C++ and Java Data Types:
Type	Keyword	Value range which can be represented by the Data Type
Character	char	-128 to 127 OR 0 to 255
Number	Int	-32,768 to 32,767 OR -2,147,483,648 to 2,147,483,647
Small Number	Short	-32,768 to 32,767
Long Number	Long	-2,147,483,648 to 2,147,483,647
Decimal Number	float	1.2E-38 to 3.4E+38 until 6 decimal places

ii.	Python Data Types:
	Numeric – A numeric value is any representation of data which has numerical values. There are three types of numbers in Python: 
o	Integer: Any Positive or Negative whole numbers (No Fractions)
o	Float: Any Real Number with a floating-point representation in which a fraction is denoted by a decimal or scientific notation. 
o	Complex Number: A number with a real and imaginary component represented as “x + yj”. In which x and y are float values and j is -1. (Imaginary numbers like the square root of – values).

	Boolean – A Data Type with two values including True and False. These are represented with “True” and “False”. Inputting “true” and “false” with lower case letter would be considered an error.
o	True
o	False

	Sequence – A sequence is an ordered collection of similar or different data types. Python has several built-in sequence data types:
o	String: A string value is a the collection of one or more characters compiled into single, double or even triple quotes depending on the requirement of the program or the developers choice.
o	List: A list is an organized compilation/collection of data that don’t necessarily have to be the same type and are enclosed in square brackets.
o	Tuple: A Tuple is an organized compilation/collection of data that don’t necessarily have to be the same type, but is instead enclosed in parentheses. 

	Dictionary – A dictionary is an unordered compilation and collection of data in a key: value pair form. Data compiled in a dictionary is enclosed in a pair of curly brackets. 

2.	Variables – Variables are used to store information to be referenced and manipulated in a computer program. Variables could be changed to represent data. They could be used to label data with descriptive names to make it easier for the developer to understand the program. It is easier to consider variables as containers to hold certain information to be assigned by the developer. The purpose of a variable is to label and store data in memory. It can be referenced and utilized throughout the whole program/code.

i.	Examples:
	Python
o	Input variables (a & b)
a = 100
b = 200

print “Value of a = ” , a
print “Value of b= ”, b
print “Value of a= ”, a, “ and value of b= ”, b

o	Output (Executed Program)
Value of a = 100
Value of b = 200
Value of a = 100 and Value of b =200






	Java 
o	Input
public class DemoJava {
   public static void main(String []args) {
      int a;
      int b;
   
      a = 10;
      b = 20;
   
      System.out.println("Value of a = " + a);
      System.out.println("Value of b = " + b);
      System.out.println("Value of a = " + a + " and value of b = " + b);     
   }
}
o	Output
Value of a = 10
Value of b = 20
Value of a = 10 and value of b = 20


3.	Boolean Logic – Boolean Logic is a form of algebra that revolves around the Boolean Operators: “Or”, “And”, and “Not”. The Core of Boolean Logic is the idea that all values are either True or False. The use of Boolean Logic allows the creation of complex audience definitions.

i.	Boolean Logic Boolean Expressions:
Operator	Name of Operator	What the Operator Means	Example
&&	And	True if and only if both sides are true	Wet && cold
||	Or 	True if Either side is true	Rich || famous
!	not	Changes True to false, and false to true	! happy
^	Exclusive or	True if either side is true	Walking ^ ridingBus







Boolean Logic Mathematical Operations:



ii.	Boolean Logic Mathematical Operations:
Operator	Name of Operator
<	Less than
<=	Less than or equal to
= =	Equal to
!=	Not equal to
>=	Greater than or equal to
>	Greater than


Sources:
 https://hackr.io/blog/what-is-programming
 https://www.javatips.net/blog/c-vs-java-vs-python-a-comparison
 https://hackr.io/blog/procedural-programming
 https://www.tutorialspoint.com/computer_programming/computer_programming_data_types.htm
 https://www.tutorialsteacher.com/python/python-data-types
 https://whatis.techtarget.com/definition/variable
 https://launchschool.com/books/ruby/read/variables
 https://www.tutorialspoint.com/computer_programming/computer_programming_variables.htm
 https://www.lotame.com/what-is-boolean-logic/
 https://www.cis.upenn.edu/~matuszek/General/JavaSyntax/boolean-expressions.html
http://www.truebasic.com/node/1035
 http://www2.lawrence.edu/fast/GREGGJ/CMSC150/013Decisions.html
 https://www.guru99.com/c-loop-statement.html
 https://techterms.com/definition/array
 https://www.techopedia.com/definition/16373/debugging

"""
    
    T.insert(tk.END, quote)
    tk.mainloop()

# %%
def intermmediatemodule():

    import tkinter as tk
    import tkFont
    
    root = tk.Tk()

    S = tk.Scrollbar(root)
    T = tk.Text(root, width=150)
    S.pack(side=tk.RIGHT, fill=tk.Y)
    T.pack(side=tk.LEFT, fill=tk.Y)
    S.config(command=T.yview)
    T.config(yscrollcommand=S.set)
    
    
    quote = """Programming Crash Course
LBYCPA1
What is Programming/Coding:
	Programming/Coding is a method in which you give the computer instructions through inputting commands in a certain programming language to perform specific operations and complete given tasks. These operations could range from the basic mathematical operations such as addition, subtraction, division and multiplication to solving math problems such as looking for the are of a triangle or looking for the derivative of limits. 
Different Programming Languages:
	Listed below are a list of the most commonly used programming languages and their highlights.
1.)	Python
•	Active community support and rapid development
•	Batteries are included language
•	Easy-to-learn, clear syntax
•	Extensible to a greater degree
•	Free, open source, cross-platform
•	High-level language with high readability and reliability
•	Object-oriented nature
•	Python programs are easy to modify for supporting different database engines
•	Used for prototyping and testing code that is later to be implemented using other programming languages
2.)	C++
•	A wide range of applications, varying from simple GUI applications to vivid 3D games and real-time mathematical simulations
•	Efficient, fast, and powerful
•	Highly portable, a top choice for multi-device, multi-platform development
•	Object-oriented programming language leveraging classes, data abstraction and encapsulation, inheritance, and polymorphism
•	Rich function library
•	Supports exception handling and function overloading
3.)	Java
•	Designed for distributed computing
•	Easy to compile, debug, learn, and write
•	High degree of robustness
•	Multi threaded, capable of performing different tasks simultaneously within a program
•	Object-oriented, allows the creation of modular programs and reusable code
•	Platform-independent, easy to migrate from one system to another
•	Supports automatic memory allocation and garbage collection
Two types of programming: 
Procedural Programming- Procedural programming is the first programming paradigm that a new developer/programmer will learn. It includes all the fundamentals of programming. This is where the developer will learn the basics of programming. 
Functional Programming- Functional programming is the programming paradigm that tries to bind several different operations into pure mathematical functions. It is a declarative style of programming that focuses on what the developer should solve rather than how the developer should solve the problem.




II.	Intermediate
1.	Decision Structures - A decision structure is a construct in a program. It allowas the program to make a decision and change its behavior based on that decision. The decision is made based on the outcome of a logical test. A logical test is a calculation in which the outcome is either true of false.

i.	If Statements – http://www2.lawrence.edu/fast/GREGGJ/CMSC150/013Decisions.html
ii.	Comparison Test – 
iii.	Nested If Statements – 
iv.	Chained if-else Statements – 
v.	Compound Tests
vi.	DeMorgan’s Law and Compound Tests –
vii.	Precedence Rules and Logical Combinations – 

2.	Loops Structures – A Loop is a program that executes the sequence of statements several times until the stated condition becomes false. A loop consists of two parts, a body of a loop and a control statement. The control statement is a combination of conditions that direct the body of the loop to execute until the specified condition becomes false. The purpose of a loop is to repeat the same code several times. This will make it easier for the program and shortens the code that has to be written.

i.	Loops
o	Entry Controlled Loop – An entry-controlled loop checks the conditions before executing the body of the loop. An entry-controlled loop can also be called as a “pre-checking loop”.

o	Exit Controlled Loop – An exit-controlled loop checks the conditions after executing the body of the loop. An exit-controlled loop can also be called as a “post-checking loop”.
o	The control conditions of a loop should be specific and well defined in order to function properly. Otherwise the loop will execute an infinite number of times and will not be terminated. The loop that does not stop executing and processing statements is called an “Infinite Loop” or “Endless loop”. The following are characteristics of an infinite loop:
	No termination condition is stated.
	The specified conditions were not met.
	The condition determines whether the loop body will be executed or not.
	“C” programming language provides three types of loop structures:
	While loop
	Do-while loop
	For loop

ii.	Types of Loops
o	While loop
o	Do-while loop
o	For Loop
o	**Break Statement**
o	**Continue Statement**


Sources:
 https://hackr.io/blog/what-is-programming
 https://www.javatips.net/blog/c-vs-java-vs-python-a-comparison
 https://hackr.io/blog/procedural-programming
 https://www.tutorialspoint.com/computer_programming/computer_programming_data_types.htm
 https://www.tutorialsteacher.com/python/python-data-types
 https://whatis.techtarget.com/definition/variable
 https://launchschool.com/books/ruby/read/variables
 https://www.tutorialspoint.com/computer_programming/computer_programming_variables.htm
 https://www.lotame.com/what-is-boolean-logic/
 https://www.cis.upenn.edu/~matuszek/General/JavaSyntax/boolean-expressions.html
http://www.truebasic.com/node/1035
 http://www2.lawrence.edu/fast/GREGGJ/CMSC150/013Decisions.html
 https://www.guru99.com/c-loop-statement.html
 https://techterms.com/definition/array
 https://www.techopedia.com/definition/16373/debugging

"""
    
    T.insert(tk.END, quote)
    tk.mainloop()

# %%
def expertmodule():

    import tkinter as tk

    root = tk.Tk()
    S = tk.Scrollbar(root)
    T = tk.Text(root, width=150)
    S.pack(side=tk.RIGHT, fill=tk.Y)
    T.pack(side=tk.LEFT, fill=tk.Y)
    S.config(command=T.yview)
    T.config(yscrollcommand=S.set)
    quote = """Programming Crash Course
LBYCPA1
What is Programming/Coding:
	Programming/Coding is a method in which you give the computer instructions through inputting commands in a certain programming language to perform specific operations and complete given tasks. These operations could range from the basic mathematical operations such as addition, subtraction, division and multiplication to solving math problems such as looking for the are of a triangle or looking for the derivative of limits. 
Different Programming Languages:
	Listed below are a list of the most commonly used programming languages and their highlights.
1.)	Python
•	Active community support and rapid development
•	Batteries are included language
•	Easy-to-learn, clear syntax
•	Extensible to a greater degree
•	Free, open source, cross-platform
•	High-level language with high readability and reliability
•	Object-oriented nature
•	Python programs are easy to modify for supporting different database engines
•	Used for prototyping and testing code that is later to be implemented using other programming languages
2.)	C++
•	A wide range of applications, varying from simple GUI applications to vivid 3D games and real-time mathematical simulations
•	Efficient, fast, and powerful
•	Highly portable, a top choice for multi-device, multi-platform development
•	Object-oriented programming language leveraging classes, data abstraction and encapsulation, inheritance, and polymorphism
•	Rich function library
•	Supports exception handling and function overloading
3.)	Java
•	Designed for distributed computing
•	Easy to compile, debug, learn, and write
•	High degree of robustness
•	Multi threaded, capable of performing different tasks simultaneously within a program
•	Object-oriented, allows the creation of modular programs and reusable code
•	Platform-independent, easy to migrate from one system to another
•	Supports automatic memory allocation and garbage collection
Two types of programming: 
Procedural Programming- Procedural programming is the first programming paradigm that a new developer/programmer will learn. It includes all the fundamentals of programming. This is where the developer will learn the basics of programming. 
Functional Programming- Functional programming is the programming paradigm that tries to bind several different operations into pure mathematical functions. It is a declarative style of programming that focuses on what the developer should solve rather than how the developer should solve the problem.


III.	Expert
1.	Arrays
i.	An array is a data structure that contains a group of elements. Typically these elements are all of the same data type, such as an integer or string. Arrays are commonly used in computer programs to organize data so that a related set of values can be easily sorted or searched.
ii.	Example of an Array
arrayname[0] = "This ";
arrayname[1] = "is ";
arrayname[2] = "pretty simple.";
print arrayname[0];
print arrayname[1];
print arrayname[2];





2.	Modules
i.	Modules also known as Modular Programming is the process of subdividing a computer program into separate sub-programs.
ii.	 A module is a separate software component. It can often be used in a variety of applications and functions with other components of the system. Similar functions are grouped in the same unit of programming code and separate functions are developed as separate units of code so that the code can be reused by other applications.

3.	Debugging Techniques
i.	Definition – Debugging, also known as debug, is the routine process of locating and removing computer program bugs, errors or abnormalities, which is methodically handled by software programmers via debugging tools. Debugging checks, detects and corrects errors or bugs to allow proper program operation according to set specifications.

ii.	Debugging Techniques/Strategies
	Incremental and bottom-up program development
	One of the most effective ways to localize errors is to develop the program incrementally, and test it often, after adding each piece of code. It is highly likely that if there is an error, it occurs in the last piece of code that you wrote. With incremental program development, the last portion of code is small; the search for bugs is therefore limited to small code fragments. An added benefit is that small code increments will likely lead to few errors, so the programmer is not overwhelmed with long lists of errors. 
 
Bottom-up development maximizes the benefits of incremental development. With bottom-up development, once a piece of code has been successfully tested, its behavior won't change when more code is incrementally added later. Existing code doesn't rely on the new parts being added, so if an error occurs, it must be in the newly added code (unless the old parts weren't tested well enough).
 
	Instrument program to log information. 
	Typically, print statements are inserted. Although the printed information is effective in some cases, it can also become difficult to inspect when the volume of logged information becomes huge. In those cases, automated scripts may be needed to sift through the data and report the relevant parts in a more compact format. Visualization tools can also help understanding the printed data. For instance, to debug a program that manipulates graphs, it may be useful to use a graph visualization tool (such as ATT's graphviz) and print information in the appropriate format (.dot files for graphviz). 
 
	Instrument program with assertions.
	 Assertions check if the program indeed maintains the properties or invariants that your code relies on. Because the program stops as soon as it an assertion fails, it's likely that the point where the program stops is much closer to the cause, and is a good indicator of what the problem is. An example of assertion checking is the repOK() function that verifies if the representation invariant holds at function boundaries. Note that checking invariants or conditions is the basis of defensive programming. The difference is that the number of checks is usually increased during debugging for those parts of the program that are suspected to contain errors. 
 
	Use debuggers.
	 If a debugger is available, it can replace the manual instrumentation using print statements or assertions. Setting breakpoints in the program, stepping into and over functions, watching program expressions, and inspecting the memory contents at selected points during the execution will give all  the needed run-time information without generating large, hard-to-read log files.
 
	Backtracking. 
	One option is to start from the point where to problem occurred and go back through the code to see how that might have happened. 
 
	Binary search. 
	The backtracking approach will fail if the error is far from the symptom. A better approach is to explore the code using a divide-and-conquer approach, to quickly pin down the bug. For example, starting from a large piece of code, place a check halfway through the code. If the error doesn't show up at that point, it means the bug occurs in the second half; otherwise, it is in the first half. Thus, the code that needs inspection has been reduced to half. Repeating the process a few times will quickly lead to the actual problem. 
 
	Problem simplification. 
	A similar approach is to gradually eliminate portions of the code that are not relevant to the bug. For instance, if a function fun f() = (g();h();k()) yields an error, try eliminating the calls to g, h, and k successively (by commenting them out), to determine which is the erroneous one. Then simplify the code in the body of buggy function, and so on. Continuing this process, the code gets simpler and simpler. The bug will eventually become evident. A similar technique can be applied to simplify data rather than code. If the size of the input data is too large, repeatedly cut parts of it and check if the bug is still present. When the data set is small enough, the cause may be easier to understand.
 
	A scientific method: form hypotheses. 
	A related approach is as follows: inspect the test case results; form a hypothesis that is consistent with the observed data; and then design and run a simple test to refute the hypothesis. If the hypothesis has been refuted, derive another hypothesis and continue the process. In some sense, this is also a simplification process: it reduces the number of possible hypotheses at each step. But unlike the above simplification techniques, which are mostly mechanical, this process is driven by active thinking about an explanation. A good approach is to try to come with the simplest hypotheses and the simplest corresponding test cases. 
 
Consider, for example, a function palindrome(s:string):bool, and suppose that palindrome("able was I ere I saw elba") returns an incorrect value of false. Here are several possible hypotheses for this failure. Maybe palindrome fails for inputs with spaces (test " "); maybe it fails for programs with upper case letters (try "I"); maybe it fails for inputs of odd length greater than one (try "ere"), and so on.  Forming and testing these hypotheses one after another can lead the programmer to the source of the problem.
 
	Bug clustering. 
	If a large number of errors are being reported, it is useful to group them into classes of related bugs (or similar bugs), and examine only one bug from each class. The intuition is that bugs from each class have the same cause (or a similar cause). Therefore, fixing a bug with automatically fix all the other bugs from the same class (or will make it obvious how to fix them).
 
	Error-detection tools. 
	Such tools can help programmers quickly identify violations of certain classes of errors. For instance, tools that check safety properties can verify that file accesses in a program obey the open-read/write-close file sequence; that the code correctly manipulates locks; or that the program always accesses valid memory. Such tools are either dynamic (they instrument the program to find errors at run-time), or use static analysis (look for errors at compile-time). For instance, Purify is a popular dynamic tool that instruments programs to identify memory errors, such as invalid accesses or memory leaks. Examples of static tools include ESC Java and Spec#, which use theorem proving approaches to check more general user specifications (pre and post-conditions, or invariants); or tools from a recent company Coverity that use dataflow analysis to detect violations of safety properties. Such tools can dramatically increase productivity, but checking  is restricted to a particular domain or class of properties. There is also an associated learning curve, although that is usually low. Currently, there are relatively few such tools and this is more an (active) area of research.


Sources:
 https://hackr.io/blog/what-is-programming
 https://www.javatips.net/blog/c-vs-java-vs-python-a-comparison
 https://hackr.io/blog/procedural-programming
 https://www.tutorialspoint.com/computer_programming/computer_programming_data_types.htm
 https://www.tutorialsteacher.com/python/python-data-types
 https://whatis.techtarget.com/definition/variable
 https://launchschool.com/books/ruby/read/variables
 https://www.tutorialspoint.com/computer_programming/computer_programming_variables.htm
 https://www.lotame.com/what-is-boolean-logic/
 https://www.cis.upenn.edu/~matuszek/General/JavaSyntax/boolean-expressions.html
http://www.truebasic.com/node/1035
 http://www2.lawrence.edu/fast/GREGGJ/CMSC150/013Decisions.html
 https://www.guru99.com/c-loop-statement.html
 https://techterms.com/definition/array
 https://www.techopedia.com/definition/16373/debugging

"""
    T.insert(tk.END, quote)
    tk.mainloop()

# %%
root.mainloop()
